# %% [markdown]
# # Migrate MongoDB database from `nmdc-schema` `v11.15.0` to `v11.15.1`
#
# This migration is a [no-op](https://en.wikipedia.org/wiki/NOP_(code)) (nothing to do).

# %%
# Do nothing.
pass
