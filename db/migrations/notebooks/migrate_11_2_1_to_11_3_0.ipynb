# %% [markdown]
# # Migrate MongoDB database from `nmdc-schema` `v11.2.1` to `v11.3.0`

# %% [markdown]
# There are no migrators associated with any schema changes between schema versions `v11.2.1` and `v11.3.0`. So, this notebook is a "no op" (i.e. "no operation").

# %%
# no op
