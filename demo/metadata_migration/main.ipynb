# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

from dotenv import load_dotenv
from pymongo import MongoClient
from pymongo.errors import OperationFailure

load_dotenv("../../.env.localhost")

admin_client = MongoClient(
    host=os.getenv("MONGO_HOST"),
    username=os.getenv("MONGO_USERNAME"),
    password=os.getenv("MONGO_PASSWORD"),
    directConnection=True, # connect to host as a standalone, rather than to entire replicaset
)
reader_client = MongoClient(
    host=os.getenv("MONGO_HOST"),
    username=os.getenv("MONGO_READONLY_USERNAME"),
    password=os.getenv("MONGO_READONLY_PASSWORD"),
    directConnection=True, # connect to host as a standalone, rather than to entire replicaset
)

mdb_src = reader_client[os.getenv("MONGO_DBNAME")]
mdb_tgt = admin_client[os.getenv("MONGO_DBNAME") + "-next"]


try:
    mdb_src.study_set.insert_one({"_id": "foobar"})
    print("NOT OK")
    mdb_src.study_set.delete_one({"_id": "foobar"})
    print("state restored")
    raise Exception("can write to `mdb_src`!")
except OperationFailure:
    pass

# %% [markdown]
# No output from above? Good!

# %%
"""Utils"""

from copy import deepcopy
import pkg_resources
from pprint import pprint
import time

import fastjsonschema
from toolz import dissoc

def strip_oid(doc):
    return dissoc(doc, "_id")

def nmdc_schema_collection_names() -> set:
    return {
        k for k, v in get_nmdc_jsonschema_dict()["$defs"]["Database"]["properties"].items()
        if v.get("items",{}).get("$ref")
    }

def present_src_collections(mdb) -> list:
    return sorted(
        n for n in (nmdc_schema_collection_names() & set(mdb_src.list_collection_names()))
        if mdb_src[n].estimated_document_count()
    )

# %%
"""Monkey-patch schema in light of expected metadata/schema modifications."""

from nmdc_runtime.util import get_nmdc_jsonschema_dict

def without_id_patterns(nmdc_jsonschema):
    rv = deepcopy(nmdc_jsonschema)
    for cls_, spec in rv["$defs"].items():
        if "properties" in spec:
            if "id" in spec["properties"]:
                spec["properties"]["id"].pop("pattern", None)
    return rv


# SCHEMA_DEFS_PATCHES = {
#     "Entity1": {
#         "attribute1": {
#                "description": "Lorem ipsum",
#                "type": "string"
#         },
#         "attribute2": {
#                "items": {
#                   "$ref": "#/$defs/Entity2"
#                },
#                "type": "array"
#         }
#     },
# }

# def patch_schema_defs(nmdc_jsonschema, patches=SCHEMA_DEFS_PATCHES):
#     rv = deepcopy(nmdc_jsonschema)
#     defs = rv["$defs"]
#     for cls_, spec in patches.items():
#         if cls_ not in defs:
#             raise Exception(f"Class not present, so cannot patch: {cls_}")
#         elif "properties" not in defs[cls_]:
#             defs[cls_]["properties"] = spec
#         else:
#             for k, v in spec.items():
#                 defs[cls_]["properties"][k] = v
#     return rv

print(pkg_resources.get_distribution("nmdc_schema").version)

nmdc_jsonschema_validate = fastjsonschema.compile(
    without_id_patterns(get_nmdc_jsonschema_dict())
)
# Out:
# 7.4.11

# %% [markdown]
# Reference for anticipated migration logic/config: https://github.com/microbiomedata/nmdc-schema/blob/v7.4.10/nmdc_schema/migrate_3_2_to_7.py

# %%
from inspect import signature
import re

from toolz import assoc, assoc_in, dissoc


id_pattern = re.compile(r"(PO|ENVO):\d+")
curie_pattern = re.compile(r"[A-Za-z]\w+:\w+")


def ensure_term_id(v):
    if not ("term" in v or "has_raw_value" in v):
        raise Exception(f"needs `term` or `has_raw_value`")
    if not (m := re.search(id_pattern, v["has_raw_value"])):
        raise Exception(f'{v["has_raw_value"]} does not match a known ID pattern')
    
    return assoc(v, "term", {"id": v["has_raw_value"]})


def uppercase_curie_prefixes(v):
    if not isinstance(v, list):
        raise Exception("list expected")
    if not all(":" in elt for elt in v):
        raise Exception("CURIEs expected")
    
    rv = []
    for elt in v:
        prefix, localpart = elt.split(":", maxsplit=1)
        rv.append(prefix.upper() + ":" + localpart)
    return rv


def lowercase_curie_prefixes(v):
    if not isinstance(v, list):
        raise Exception("list expected")
    if not all(":" in elt for elt in v):
        raise Exception("CURIEs expected")
    
    rv = []
    for elt in v:
        prefix, localpart = elt.split(":", maxsplit=1)
        rv.append(prefix.lower() + ":" + localpart)
    return rv


def ensure_curies(v):
    """
    >>> ensure_curies(['HTTPS://identifiers.org/gold:Gs0144557'])
    ['gold:Gs0144557']
    """
    if not isinstance(v, list):
        raise Exception("list expected")
    if not all(":" in elt for elt in v):
        raise Exception("CURIE-ables expected")

    return [re.search(curie_pattern, elt).group(0) for elt in v]


def ensure_depth_via_depth2(v, d):
    if "depth" not in d:
        raise Exception("no `depth` field")
    
    depth = d["depth"]
    return {"depth": depth, "depth2": None}


def remove_type_field(v):
    return dissoc(v, "type")


def ensure_number_in_meters(v):
    if isinstance(v, dict):
        assert "has_unit" in v, "no units"
        assert v["has_unit"] in ("meter", "metre"), "not meters"
        return v["has_numeric_value"]
    assert isinstance(v, int | float), "not a number"
    return v


def ensure_gold_sequencing_project_identifiers(v, d):
    if not isinstance(v, list):
        raise Exception("list expected")
    if "gold_sequencing_project_identifiers" not in d:
        return v

    rv = []
    for elt in v:
        if elt.lower().startswith("gold:gb"):
            if d["id"].lower().startswith("gold:gp"):
                rv.append(d["id"])
            else:
                raise Exception("no avaialable substitute")
        else:
            rv.append(elt)
    return {"gold_sequencing_project_identifiers": rv}


def rename_num_tRNA(v):
    return [
        change_fieldname(elt, "num_tRNA", "num_t_rna")
        for elt in v if "num_tRNA" in elt
    ]


fieldname_replacements = {
    "biosample_set": {
        "INSDC_biosample_identifiers": "insdc_biosample_identifiers",
        # # "part_of": "sample_link",
        "identifier": "samp_name",
        "GOLD_sample_identifiers": "gold_biosample_identifiers",
        "env_broad_scale": [ensure_term_id, remove_type_field],
        "env_local_scale": [ensure_term_id, remove_type_field],
        "env_medium": [ensure_term_id, remove_type_field],
        # depends on `dict`s being ordered in python 3.8+
        "gold_biosample_identifiers": [uppercase_curie_prefixes],
        "depth2": [ensure_depth_via_depth2],
        "lat_lon": [remove_type_field],
        "elev": [ensure_number_in_meters],
        "insdc_biosample_identifiers": [lowercase_curie_prefixes],
    },
    "study_set": {
        "GOLD_study_identifiers": "gold_study_identifiers",
        "gold_study_identifiers": [ensure_curies, uppercase_curie_prefixes],
    },
    "omics_processing_set": {
        "GOLD_sequencing_project_identifiers": "gold_sequencing_project_identifiers",
        "gold_sequencing_project_identifiers": [
            ensure_gold_sequencing_project_identifiers,
            uppercase_curie_prefixes,
        ],
    },
    "mags_activity_set": {
        "mags_list": [rename_num_tRNA],
        "lowDepth_contig_num": "low_depth_contig_num",
    },
    "metagenome_assembly_set": {
        "ctg_L50": "ctg_l50",
        "ctg_L90": "ctg_l90",
        "ctg_N50": "ctg_n50",
        "ctg_N90": "ctg_n90",
        "scaf_L50": "scaf_l50",
        "scaf_L90": "scaf_l90",
        "scaf_N50": "scaf_n50",
        "scaf_N90": "scaf_n90",
        "scaf_l_gt50K": "scaf_l_gt50k",
        "scaf_n_gt50K": "scaf_n_gt50k",
        "scaf_pct_gt50K": "scaf_pct_gt50k",
    },
    # "read_qc_analysis_activity_set": {
    #     "output_read_bases": "output_base_count",
    #     "input_read_bases": "input_base_count",
    # },
}

biosample_id_routing = {
    "emsl": "emsl_biosample_identifiers",
    "gold": "gold_biosample_identifiers",
    "igsn": "igsn_biosample_identifiers",
    "img.taxon": "img_identifiers"
}


def change_fieldname(d, fieldname, replacement):
    return dissoc(assoc(d, replacement, d[fieldname]), fieldname)


def replace_fields(d, context):
    assert "collection_name" in context
    for fieldname, replacement in fieldname_replacements[context["collection_name"]].items():
        if fieldname in d:
            if isinstance(replacement, list):
                assert all(callable(r) for r in replacement), "replacement-list must be all functions"
                for rfun in replacement:
                    n_params = len(signature(rfun).parameters)
                    if n_params == 1:
                        d = assoc(d, fieldname, rfun(d[fieldname]))
                    elif n_params == 2:
                        mapping_updates = rfun(d[fieldname], d)
                        for k, v in mapping_updates.items():
                            d = dissoc(d, k) if v is None else assoc(d, k, v)
                    else:
                        raise Exception("replaced fn takes too many parameters")
            else:
                d = change_fieldname(d, fieldname, replacement)
    return d


def iter_validate(mdb=None, collection_name=None, limit=0, xform=None):
    print(f"validating {collection_name}...")
    for d in mdb_src[collection_name].find(limit=limit):
        d = strip_oid(d)
        if xform:
            d = xform(d, {"collection_name": collection_name})
        try:
            _ = nmdc_jsonschema_validate({collection_name: [d]})
        except fastjsonschema.JsonSchemaException as e:
            print(d["id"])
            print(e)
            #pprint(d)
            #raise e
            return

# %% [markdown]
# # replacements

# %%
collections = present_src_collections(mdb_src)
print(collections)

tic = time.time()

for coll_name in collections:
    if coll_name in fieldname_replacements:
        iter_validate(mdb_src, coll_name, xform=replace_fields)
    else:
        iter_validate(mdb_src, coll_name, xform=None)

print(f"Took approx. {time.time() - tic} seconds")
# Out:
# ['biosample_set', 'data_object_set', 'mags_activity_set', 'metabolomics_analysis_activity_set', 'metagenome_annotation_activity_set', 'metagenome_assembly_set', 'metaproteomics_analysis_activity_set', 'metatranscriptome_activity_set', 'nom_analysis_activity_set', 'omics_processing_set', 'read_qc_analysis_activity_set', 'study_set']
# validating biosample_set...
# validating data_object_set...
# validating mags_activity_set...
# validating metabolomics_analysis_activity_set...
# validating metagenome_annotation_activity_set...
# validating metagenome_assembly_set...
# validating metaproteomics_analysis_activity_set...
# validating metatranscriptome_activity_set...
# validating nom_analysis_activity_set...
# validating omics_processing_set...
# validating read_qc_analysis_activity_set...
# validating study_set...
# Took approx. 95.99997806549072 seconds

# %% [markdown]
# ## mongodump and mongorestore

# %%
from datetime import datetime, timezone
from pathlib import Path
import time

today = datetime.now(timezone.utc).strftime("%Y-%m-%d")
print(f"ensuring ~/nmdcdb-mongodump/{today} directory for exports")
today_dir = Path("~/nmdcdb-mongodump").expanduser().joinpath(today)
os.makedirs(str(today_dir), exist_ok=True)

collections_excluded = (
    set(mdb_src.list_collection_names())
    - set(collections + ["functional_annotation_agg"])
)
collections_excluded_str = " ".join(
    ["--excludeCollection=" + c for c in collections_excluded]
)
# Out:
# ensuring ~/nmdcdb-mongodump/2023-03-01 directory for exports

# %%
tic = time.time()

# !mongodump --host {os.getenv("MONGO_HOST")} \
     -u {os.getenv("MONGO_READONLY_USERNAME")} \
     -p {os.getenv("MONGO_READONLY_PASSWORD")} \
     --authenticationDatabase admin \
     -d {os.getenv("MONGO_DBNAME")} \
     {collections_excluded_str} \
     -o {today_dir}

print(f"Took approx. {time.time() - tic} seconds")
# Out:
# 2023-03-01T13:54:16.971-0500	writing nmdc.data_object_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/data_object_set.bson
# 2023-03-01T13:54:17.049-0500	writing nmdc.read_qc_analysis_activity_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/read_qc_analysis_activity_set.bson
# 2023-03-01T13:54:17.496-0500	writing nmdc.functional_annotation_agg to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/functional_annotation_agg.bson
# 2023-03-01T13:54:17.499-0500	writing nmdc.omics_processing_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/omics_processing_set.bson
# 2023-03-01T13:54:18.620-0500	done dumping nmdc.read_qc_analysis_activity_set (1058 documents)
# 2023-03-01T13:54:18.624-0500	[........................]            nmdc.data_object_set    101/40858  (0.2%)
# 2023-03-01T13:54:18.624-0500	[........................]  nmdc.functional_annotation_agg  101/3046840  (0.0%)
# 2023-03-01T13:54:18.624-0500	[#.......................]       nmdc.omics_processing_set     101/1927  (5.2%)
# 2023-03-01T13:54:18.624-0500
# 2023-03-01T13:54:21.624-0500	[........................]            nmdc.data_object_set    101/40858  (0.2%)
# 2023-03-01T13:54:21.624-0500	[........................]  nmdc.functional_annotation_agg  101/3046840  (0.0%)
# 2023-03-01T13:54:21.624-0500	[#.......................]       nmdc.omics_processing_set     101/1927  (5.2%)
# 2023-03-01T13:54:21.624-0500
# 2023-03-01T13:54:22.640-0500	writing nmdc.metagenome_assembly_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/metagenome_assembly_set.bson
# 2023-03-01T13:54:22.747-0500	[########################]  nmdc.omics_processing_set  1927/1927  (100.0%)
# 2023-03-01T13:54:22.747-0500	done dumping nmdc.omics_processing_set (1927 documents)
# 2023-03-01T13:54:24.322-0500	writing nmdc.nom_analysis_activity_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/nom_analysis_activity_set.bson
# 2023-03-01T13:54:24.624-0500	[........................]            nmdc.data_object_set    101/40858  (0.2%)
# 2023-03-01T13:54:24.624-0500	[........................]  nmdc.functional_annotation_agg  101/3046840  (0.0%)
# 2023-03-01T13:54:24.624-0500	[........................]    nmdc.metagenome_assembly_set       0/1056  (0.0%)
# 2023-03-01T13:54:24.624-0500
# 2023-03-01T13:54:27.340-0500	[########################]  nmdc.metagenome_assembly_set  1056/1056  (100.0%)
# 2023-03-01T13:54:27.340-0500	done dumping nmdc.metagenome_assembly_set (1056 documents)
# 2023-03-01T13:54:27.624-0500	[........................]            nmdc.data_object_set    101/40858   (0.2%)
# 2023-03-01T13:54:27.624-0500	[........................]  nmdc.functional_annotation_agg  101/3046840   (0.0%)
# 2023-03-01T13:54:27.624-0500	[##......................]  nmdc.nom_analysis_activity_set      101/838  (12.1%)
# 2023-03-01T13:54:27.624-0500
# 2023-03-01T13:54:28.029-0500	writing nmdc.metagenome_annotation_activity_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/metagenome_annotation_activity_set.bson
# 2023-03-01T13:54:28.030-0500	[########################]  nmdc.nom_analysis_activity_set  838/838  (100.0%)
# 2023-03-01T13:54:28.030-0500	done dumping nmdc.nom_analysis_activity_set (838 documents)
# 2023-03-01T13:54:28.712-0500	writing nmdc.mags_activity_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/mags_activity_set.bson
# 2023-03-01T13:54:29.532-0500	[########################]  nmdc.data_object_set  40858/40858  (100.0%)
# 2023-03-01T13:54:29.532-0500	done dumping nmdc.data_object_set (40858 documents)
# 2023-03-01T13:54:29.892-0500	done dumping nmdc.metagenome_annotation_activity_set (818 documents)
# 2023-03-01T13:54:30.006-0500	writing nmdc.biosample_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/biosample_set.bson
# 2023-03-01T13:54:30.006-0500	writing nmdc.metabolomics_analysis_activity_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/metabolomics_analysis_activity_set.bson
# 2023-03-01T13:54:30.624-0500	[........................]           nmdc.functional_annotation_agg  110279/3046840   (3.6%)
# 2023-03-01T13:54:30.624-0500	[###.....................]                   nmdc.mags_activity_set         101/761  (13.3%)
# 2023-03-01T13:54:30.624-0500	[###.....................]                       nmdc.biosample_set         101/753  (13.4%)
# 2023-03-01T13:54:30.624-0500	[........................]  nmdc.metabolomics_analysis_activity_set           0/209   (0.0%)
# 2023-03-01T13:54:30.624-0500
# 2023-03-01T13:54:30.807-0500	[########################]  nmdc.mags_activity_set  761/761  (100.0%)
# 2023-03-01T13:54:30.807-0500	done dumping nmdc.mags_activity_set (761 documents)
# 2023-03-01T13:54:31.033-0500	[########################]  nmdc.biosample_set  753/753  (100.0%)
# 2023-03-01T13:54:31.033-0500	done dumping nmdc.biosample_set (753 documents)
# 2023-03-01T13:54:31.163-0500	writing nmdc.metatranscriptome_activity_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/metatranscriptome_activity_set.bson
# 2023-03-01T13:54:31.479-0500	writing nmdc.metaproteomics_analysis_activity_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/metaproteomics_analysis_activity_set.bson
# 2023-03-01T13:54:32.080-0500	done dumping nmdc.metatranscriptome_activity_set (55 documents)
# 2023-03-01T13:54:32.783-0500	writing nmdc.study_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/study_set.bson
# 2023-03-01T13:54:33.624-0500	[........................]             nmdc.functional_annotation_agg  110279/3046840   (3.6%)
# 2023-03-01T13:54:33.624-0500	[###########.............]    nmdc.metabolomics_analysis_activity_set         101/209  (48.3%)
# 2023-03-01T13:54:33.624-0500	[........................]  nmdc.metaproteomics_analysis_activity_set            0/52   (0.0%)
# 2023-03-01T13:54:33.624-0500
# 2023-03-01T13:54:34.788-0500	done dumping nmdc.study_set (9 documents)
# 2023-03-01T13:54:36.294-0500	[########################]  nmdc.metabolomics_analysis_activity_set  209/209  (100.0%)
# 2023-03-01T13:54:36.295-0500	done dumping nmdc.metabolomics_analysis_activity_set (209 documents)
# 2023-03-01T13:54:36.625-0500	[........................]             nmdc.functional_annotation_agg  110279/3046840  (3.6%)
# 2023-03-01T13:54:36.625-0500	[........................]  nmdc.metaproteomics_analysis_activity_set            0/52  (0.0%)
# 2023-03-01T13:54:36.625-0500
# 2023-03-01T13:54:39.625-0500	[#.......................]             nmdc.functional_annotation_agg  219943/3046840  (7.2%)
# 2023-03-01T13:54:39.625-0500	[........................]  nmdc.metaproteomics_analysis_activity_set            0/52  (0.0%)
# 2023-03-01T13:54:39.625-0500
# 2023-03-01T13:54:42.625-0500	[#.......................]             nmdc.functional_annotation_agg  219943/3046840   (7.2%)
# 2023-03-01T13:54:42.625-0500	[######..................]  nmdc.metaproteomics_analysis_activity_set           15/52  (28.8%)
# 2023-03-01T13:54:42.625-0500
# 2023-03-01T13:54:45.625-0500	[#.......................]             nmdc.functional_annotation_agg  219943/3046840   (7.2%)
# 2023-03-01T13:54:45.625-0500	[######..................]  nmdc.metaproteomics_analysis_activity_set           15/52  (28.8%)
# 2023-03-01T13:54:45.625-0500
# 2023-03-01T13:54:48.625-0500	[##......................]             nmdc.functional_annotation_agg  329607/3046840  (10.8%)
# 2023-03-01T13:54:48.625-0500	[#########...............]  nmdc.metaproteomics_analysis_activity_set           21/52  (40.4%)
# 2023-03-01T13:54:48.625-0500
# 2023-03-01T13:54:51.625-0500	[###.....................]             nmdc.functional_annotation_agg  439271/3046840  (14.4%)
# 2023-03-01T13:54:51.625-0500	[############............]  nmdc.metaproteomics_analysis_activity_set           26/52  (50.0%)
# 2023-03-01T13:54:51.625-0500
# 2023-03-01T13:54:54.625-0500	[###.....................]             nmdc.functional_annotation_agg  439271/3046840  (14.4%)
# 2023-03-01T13:54:54.625-0500	[############............]  nmdc.metaproteomics_analysis_activity_set           26/52  (50.0%)
# 2023-03-01T13:54:54.625-0500
# 2023-03-01T13:54:57.625-0500	[####....................]             nmdc.functional_annotation_agg  548935/3046840  (18.0%)
# 2023-03-01T13:54:57.625-0500	[#############...........]  nmdc.metaproteomics_analysis_activity_set           30/52  (57.7%)
# 2023-03-01T13:54:57.625-0500
# 2023-03-01T13:55:00.625-0500	[####....................]             nmdc.functional_annotation_agg  548935/3046840  (18.0%)
# 2023-03-01T13:55:00.625-0500	[#############...........]  nmdc.metaproteomics_analysis_activity_set           30/52  (57.7%)
# 2023-03-01T13:55:00.625-0500
# 2023-03-01T13:55:03.625-0500	[#####...................]             nmdc.functional_annotation_agg  658599/3046840  (21.6%)
# 2023-03-01T13:55:03.625-0500	[################........]  nmdc.metaproteomics_analysis_activity_set           35/52  (67.3%)
# 2023-03-01T13:55:03.625-0500
# 2023-03-01T13:55:06.626-0500	[#####...................]             nmdc.functional_annotation_agg  658599/3046840  (21.6%)
# 2023-03-01T13:55:06.626-0500	[##################......]  nmdc.metaproteomics_analysis_activity_set           40/52  (76.9%)
# 2023-03-01T13:55:06.626-0500
# 2023-03-01T13:55:09.625-0500	[######..................]             nmdc.functional_annotation_agg  768263/3046840  (25.2%)
# 2023-03-01T13:55:09.625-0500	[##################......]  nmdc.metaproteomics_analysis_activity_set           40/52  (76.9%)
# 2023-03-01T13:55:09.625-0500
# 2023-03-01T13:55:12.626-0500	[######..................]             nmdc.functional_annotation_agg  768263/3046840  (25.2%)
# 2023-03-01T13:55:12.626-0500	[###################.....]  nmdc.metaproteomics_analysis_activity_set           43/52  (82.7%)
# 2023-03-01T13:55:12.626-0500
# 2023-03-01T13:55:15.626-0500	[######..................]             nmdc.functional_annotation_agg  877927/3046840  (28.8%)
# 2023-03-01T13:55:15.626-0500	[####################....]  nmdc.metaproteomics_analysis_activity_set           45/52  (86.5%)
# 2023-03-01T13:55:15.626-0500
# 2023-03-01T13:55:18.626-0500	[#######.................]             nmdc.functional_annotation_agg  987591/3046840  (32.4%)
# 2023-03-01T13:55:18.626-0500	[#####################...]  nmdc.metaproteomics_analysis_activity_set           46/52  (88.5%)
# 2023-03-01T13:55:18.626-0500
# 2023-03-01T13:55:21.626-0500	[#######.................]             nmdc.functional_annotation_agg  987591/3046840  (32.4%)
# 2023-03-01T13:55:21.626-0500	[#####################...]  nmdc.metaproteomics_analysis_activity_set           47/52  (90.4%)
# 2023-03-01T13:55:21.626-0500
# 2023-03-01T13:55:24.626-0500	[#######.................]             nmdc.functional_annotation_agg  987591/3046840  (32.4%)
# 2023-03-01T13:55:24.626-0500	[#####################...]  nmdc.metaproteomics_analysis_activity_set           47/52  (90.4%)
# 2023-03-01T13:55:24.626-0500
# 2023-03-01T13:55:27.626-0500	[########................]             nmdc.functional_annotation_agg  1097255/3046840  (36.0%)
# 2023-03-01T13:55:27.626-0500	[######################..]  nmdc.metaproteomics_analysis_activity_set            48/52  (92.3%)
# 2023-03-01T13:55:27.626-0500
# 2023-03-01T13:55:30.626-0500	[########................]             nmdc.functional_annotation_agg  1141054/3046840  (37.5%)
# 2023-03-01T13:55:30.626-0500	[######################..]  nmdc.metaproteomics_analysis_activity_set            49/52  (94.2%)
# 2023-03-01T13:55:30.626-0500
# 2023-03-01T13:55:33.626-0500	[#########...............]             nmdc.functional_annotation_agg  1206919/3046840  (39.6%)
# 2023-03-01T13:55:33.626-0500	[######################..]  nmdc.metaproteomics_analysis_activity_set            49/52  (94.2%)
# 2023-03-01T13:55:33.626-0500
# 2023-03-01T13:55:36.626-0500	[##########..............]             nmdc.functional_annotation_agg  1316583/3046840  (43.2%)
# 2023-03-01T13:55:36.626-0500	[#######################.]  nmdc.metaproteomics_analysis_activity_set            50/52  (96.2%)
# 2023-03-01T13:55:36.626-0500
# 2023-03-01T13:55:39.627-0500	[##########..............]             nmdc.functional_annotation_agg  1316583/3046840  (43.2%)
# 2023-03-01T13:55:39.627-0500	[#######################.]  nmdc.metaproteomics_analysis_activity_set            50/52  (96.2%)
# 2023-03-01T13:55:39.627-0500
# 2023-03-01T13:55:42.626-0500	[##########..............]             nmdc.functional_annotation_agg  1316583/3046840  (43.2%)
# 2023-03-01T13:55:42.626-0500	[#######################.]  nmdc.metaproteomics_analysis_activity_set            51/52  (98.1%)
# 2023-03-01T13:55:42.626-0500
# 2023-03-01T13:55:45.626-0500	[###########.............]             nmdc.functional_annotation_agg  1426247/3046840  (46.8%)
# 2023-03-01T13:55:45.626-0500	[#######################.]  nmdc.metaproteomics_analysis_activity_set            51/52  (98.1%)
# 2023-03-01T13:55:45.626-0500
# 2023-03-01T13:55:45.659-0500	[########################]  nmdc.metaproteomics_analysis_activity_set  52/52  (100.0%)
# 2023-03-01T13:55:45.659-0500	done dumping nmdc.metaproteomics_analysis_activity_set (52 documents)
# 2023-03-01T13:55:48.626-0500	[############............]  nmdc.functional_annotation_agg  1535911/3046840  (50.4%)
# 2023-03-01T13:55:51.626-0500	[############............]  nmdc.functional_annotation_agg  1645575/3046840  (54.0%)
# 2023-03-01T13:55:54.627-0500	[############............]  nmdc.functional_annotation_agg  1645575/3046840  (54.0%)
# 2023-03-01T13:55:57.627-0500	[#############...........]  nmdc.functional_annotation_agg  1755239/3046840  (57.6%)
# 2023-03-01T13:56:00.627-0500	[##############..........]  nmdc.functional_annotation_agg  1864903/3046840  (61.2%)
# 2023-03-01T13:56:03.627-0500	[###############.........]  nmdc.functional_annotation_agg  1974567/3046840  (64.8%)
# 2023-03-01T13:56:06.627-0500	[################........]  nmdc.functional_annotation_agg  2084231/3046840  (68.4%)
# 2023-03-01T13:56:09.627-0500	[#################.......]  nmdc.functional_annotation_agg  2193895/3046840  (72.0%)
# 2023-03-01T13:56:12.627-0500	[##################......]  nmdc.functional_annotation_agg  2303559/3046840  (75.6%)
# 2023-03-01T13:56:15.627-0500	[###################.....]  nmdc.functional_annotation_agg  2413223/3046840  (79.2%)
# 2023-03-01T13:56:18.627-0500	[###################.....]  nmdc.functional_annotation_agg  2522887/3046840  (82.8%)
# 2023-03-01T13:56:21.627-0500	[#####################...]  nmdc.functional_annotation_agg  2742215/3046840  (90.0%)
# 2023-03-01T13:56:24.628-0500	[#####################...]  nmdc.functional_annotation_agg  2742215/3046840  (90.0%)
# 2023-03-01T13:56:27.628-0500	[######################..]  nmdc.functional_annotation_agg  2851879/3046840  (93.6%)
# 2023-03-01T13:56:30.628-0500	[#######################.]  nmdc.functional_annotation_agg  2961543/3046840  (97.2%)
# 2023-03-01T13:56:33.628-0500	[#######################.]  nmdc.functional_annotation_agg  2961543/3046840  (97.2%)
# 2023-03-01T13:56:34.413-0500	[########################]  nmdc.functional_annotation_agg  3046840/3046840  (100.0%)
# 2023-03-01T13:56:34.413-0500	done dumping nmdc.functional_annotation_agg (3046840 documents)
# Took approx. 142.14642596244812 seconds

# %%
tic = time.time()

# !mongorestore --host {os.getenv("MONGO_HOST")} \
     -u {os.getenv("MONGO_USERNAME")} \
     -p {os.getenv("MONGO_PASSWORD")} \
     --authenticationDatabase admin \
     -d {os.getenv("MONGO_DBNAME") + "-next"} \
     --drop \
     {today_dir / os.getenv("MONGO_DBNAME")}

print(f"Took approx. {time.time() - tic} seconds")
# Out:
# 2023-03-01T13:56:39.906-0500	The --db and --collection flags are deprecated for this use-case; please use --nsInclude instead, i.e. with --nsInclude=${DATABASE}.${COLLECTION}
# 2023-03-01T13:56:39.907-0500	building a list of collections to restore from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc dir
# 2023-03-01T13:56:39.908-0500	reading metadata for nmdc-next.functional_annotation_agg from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/functional_annotation_agg.metadata.json
# 2023-03-01T13:56:39.909-0500	reading metadata for nmdc-next.mags_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/mags_activity_set.metadata.json
# 2023-03-01T13:56:39.909-0500	reading metadata for nmdc-next.metagenome_annotation_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/metagenome_annotation_activity_set.metadata.json
# 2023-03-01T13:56:39.909-0500	reading metadata for nmdc-next.metatranscriptome_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/metatranscriptome_activity_set.metadata.json
# 2023-03-01T13:56:39.909-0500	reading metadata for nmdc-next.omics_processing_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/omics_processing_set.metadata.json
# 2023-03-01T13:56:39.909-0500	reading metadata for nmdc-next.read_qc_analysis_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/read_qc_analysis_activity_set.metadata.json
# 2023-03-01T13:56:39.909-0500	reading metadata for nmdc-next.biosample_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/biosample_set.metadata.json
# 2023-03-01T13:56:39.909-0500	reading metadata for nmdc-next.data_object_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/data_object_set.metadata.json
# 2023-03-01T13:56:39.910-0500	reading metadata for nmdc-next.metaproteomics_analysis_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/metaproteomics_analysis_activity_set.metadata.json
# 2023-03-01T13:56:39.910-0500	reading metadata for nmdc-next.nom_analysis_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/nom_analysis_activity_set.metadata.json
# 2023-03-01T13:56:39.910-0500	reading metadata for nmdc-next.study_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/study_set.metadata.json
# 2023-03-01T13:56:39.910-0500	reading metadata for nmdc-next.metabolomics_analysis_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/metabolomics_analysis_activity_set.metadata.json
# 2023-03-01T13:56:39.910-0500	reading metadata for nmdc-next.metagenome_assembly_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/metagenome_assembly_set.metadata.json
# 2023-03-01T13:56:39.991-0500	dropping collection nmdc-next.data_object_set before restoring
# 2023-03-01T13:56:39.991-0500	dropping collection nmdc-next.functional_annotation_agg before restoring
# 2023-03-01T13:56:39.991-0500	dropping collection nmdc-next.metaproteomics_analysis_activity_set before restoring
# 2023-03-01T13:56:39.991-0500	dropping collection nmdc-next.metabolomics_analysis_activity_set before restoring
# 2023-03-01T13:56:40.570-0500	restoring nmdc-next.functional_annotation_agg from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/functional_annotation_agg.bson
# 2023-03-01T13:56:40.579-0500	restoring nmdc-next.data_object_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/data_object_set.bson
# 2023-03-01T13:56:40.622-0500	restoring nmdc-next.metaproteomics_analysis_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/metaproteomics_analysis_activity_set.bson
# 2023-03-01T13:56:40.680-0500	restoring nmdc-next.metabolomics_analysis_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/metabolomics_analysis_activity_set.bson
# 2023-03-01T13:56:42.621-0500	[........................]             nmdc-next.functional_annotation_agg    283KB/424MB    (0.1%)
# 2023-03-01T13:56:42.621-0500	[........................]                       nmdc-next.data_object_set   210KB/14.4MB    (1.4%)
# 2023-03-01T13:56:42.621-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-03-01T13:56:42.621-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-03-01T13:56:42.621-0500
# 2023-03-01T13:56:45.620-0500	[........................]             nmdc-next.functional_annotation_agg    425KB/424MB    (0.1%)
# 2023-03-01T13:56:45.620-0500	[........................]                       nmdc-next.data_object_set   418KB/14.4MB    (2.8%)
# 2023-03-01T13:56:45.620-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-03-01T13:56:45.620-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-03-01T13:56:45.620-0500
# 2023-03-01T13:56:48.620-0500	[........................]             nmdc-next.functional_annotation_agg    850KB/424MB    (0.2%)
# 2023-03-01T13:56:48.620-0500	[#.......................]                       nmdc-next.data_object_set   990KB/14.4MB    (6.7%)
# 2023-03-01T13:56:48.620-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-03-01T13:56:48.620-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-03-01T13:56:48.620-0500
# 2023-03-01T13:56:51.620-0500	[........................]             nmdc-next.functional_annotation_agg   1.11MB/424MB    (0.3%)
# 2023-03-01T13:56:51.620-0500	[##......................]                       nmdc-next.data_object_set  1.61MB/14.4MB   (11.2%)
# 2023-03-01T13:56:51.620-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-03-01T13:56:51.620-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-03-01T13:56:51.620-0500
# 2023-03-01T13:56:54.620-0500	[........................]             nmdc-next.functional_annotation_agg   1.80MB/424MB    (0.4%)
# 2023-03-01T13:56:54.620-0500	[####....................]                       nmdc-next.data_object_set  2.65MB/14.4MB   (18.4%)
# 2023-03-01T13:56:54.620-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-03-01T13:56:54.620-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-03-01T13:56:54.620-0500
# 2023-03-01T13:56:57.621-0500	[........................]             nmdc-next.functional_annotation_agg   2.35MB/424MB    (0.6%)
# 2023-03-01T13:56:57.621-0500	[#####...................]                       nmdc-next.data_object_set  3.31MB/14.4MB   (23.0%)
# 2023-03-01T13:56:57.621-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-03-01T13:56:57.621-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-03-01T13:56:57.621-0500
# 2023-03-01T13:57:00.621-0500	[........................]             nmdc-next.functional_annotation_agg   2.77MB/424MB    (0.7%)
# 2023-03-01T13:57:00.621-0500	[#######.................]                       nmdc-next.data_object_set  4.20MB/14.4MB   (29.2%)
# 2023-03-01T13:57:00.621-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-03-01T13:57:00.621-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-03-01T13:57:00.621-0500
# 2023-03-01T13:57:03.621-0500	[........................]             nmdc-next.functional_annotation_agg   3.32MB/424MB    (0.8%)
# 2023-03-01T13:57:03.621-0500	[########................]                       nmdc-next.data_object_set  5.29MB/14.4MB   (36.8%)
# 2023-03-01T13:57:03.621-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-03-01T13:57:03.621-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-03-01T13:57:03.621-0500
# 2023-03-01T13:57:06.621-0500	[........................]             nmdc-next.functional_annotation_agg   3.87MB/424MB    (0.9%)
# 2023-03-01T13:57:06.621-0500	[##########..............]                       nmdc-next.data_object_set  6.04MB/14.4MB   (42.0%)
# 2023-03-01T13:57:06.621-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-03-01T13:57:06.621-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-03-01T13:57:06.621-0500
# 2023-03-01T13:57:09.621-0500	[........................]             nmdc-next.functional_annotation_agg   4.29MB/424MB    (1.0%)
# 2023-03-01T13:57:09.621-0500	[###########.............]                       nmdc-next.data_object_set  6.81MB/14.4MB   (47.4%)
# 2023-03-01T13:57:09.621-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-03-01T13:57:09.621-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-03-01T13:57:09.621-0500
# 2023-03-01T13:57:12.621-0500	[........................]             nmdc-next.functional_annotation_agg   4.98MB/424MB    (1.2%)
# 2023-03-01T13:57:12.621-0500	[############............]                       nmdc-next.data_object_set  7.56MB/14.4MB   (52.6%)
# 2023-03-01T13:57:12.621-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-03-01T13:57:12.621-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-03-01T13:57:12.621-0500
# 2023-03-01T13:57:15.621-0500	[........................]             nmdc-next.functional_annotation_agg   5.53MB/424MB    (1.3%)
# 2023-03-01T13:57:15.621-0500	[##############..........]                       nmdc-next.data_object_set  8.71MB/14.4MB   (60.6%)
# 2023-03-01T13:57:15.621-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-03-01T13:57:15.621-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-03-01T13:57:15.621-0500
# 2023-03-01T13:57:18.622-0500	[........................]             nmdc-next.functional_annotation_agg   5.95MB/424MB    (1.4%)
# 2023-03-01T13:57:18.622-0500	[###############.........]                       nmdc-next.data_object_set  9.09MB/14.4MB   (63.3%)
# 2023-03-01T13:57:18.622-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-03-01T13:57:18.622-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-03-01T13:57:18.622-0500
# 2023-03-01T13:57:21.081-0500	[########################]  nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-03-01T13:57:21.081-0500	finished restoring nmdc-next.metabolomics_analysis_activity_set (209 documents, 0 failures)
# 2023-03-01T13:57:21.081-0500	dropping collection nmdc-next.mags_activity_set before restoring
# 2023-03-01T13:57:21.622-0500	[........................]             nmdc-next.functional_annotation_agg   6.64MB/424MB   (1.6%)
# 2023-03-01T13:57:21.622-0500	[#################.......]                       nmdc-next.data_object_set  10.2MB/14.4MB  (70.9%)
# 2023-03-01T13:57:21.622-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB  (22.2%)
# 2023-03-01T13:57:21.622-0500
# 2023-03-01T13:57:21.722-0500	restoring nmdc-next.mags_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/mags_activity_set.bson
# 2023-03-01T13:57:24.621-0500	[........................]             nmdc-next.functional_annotation_agg   7.19MB/424MB    (1.7%)
# 2023-03-01T13:57:24.621-0500	[##################......]                       nmdc-next.data_object_set  11.2MB/14.4MB   (78.0%)
# 2023-03-01T13:57:24.621-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-03-01T13:57:24.621-0500	[########################]                     nmdc-next.mags_activity_set  5.04MB/5.04MB  (100.0%)
# 2023-03-01T13:57:24.621-0500
# 2023-03-01T13:57:27.621-0500	[........................]             nmdc-next.functional_annotation_agg   7.61MB/424MB    (1.8%)
# 2023-03-01T13:57:27.621-0500	[###################.....]                       nmdc-next.data_object_set  11.6MB/14.4MB   (80.4%)
# 2023-03-01T13:57:27.621-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-03-01T13:57:27.621-0500	[########################]                     nmdc-next.mags_activity_set  5.04MB/5.04MB  (100.0%)
# 2023-03-01T13:57:27.621-0500
# 2023-03-01T13:57:30.622-0500	[........................]             nmdc-next.functional_annotation_agg   8.30MB/424MB    (2.0%)
# 2023-03-01T13:57:30.622-0500	[#####################...]                       nmdc-next.data_object_set  12.7MB/14.4MB   (88.0%)
# 2023-03-01T13:57:30.622-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-03-01T13:57:30.622-0500	[########################]                     nmdc-next.mags_activity_set  5.04MB/5.04MB  (100.0%)
# 2023-03-01T13:57:30.622-0500
# 2023-03-01T13:57:33.622-0500	[........................]             nmdc-next.functional_annotation_agg   8.85MB/424MB    (2.1%)
# 2023-03-01T13:57:33.622-0500	[######################..]                       nmdc-next.data_object_set  13.4MB/14.4MB   (93.0%)
# 2023-03-01T13:57:33.622-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-03-01T13:57:33.622-0500	[########################]                     nmdc-next.mags_activity_set  5.04MB/5.04MB  (100.0%)
# 2023-03-01T13:57:33.622-0500
# 2023-03-01T13:57:33.655-0500	[########################]  nmdc-next.mags_activity_set  5.04MB/5.04MB  (100.0%)
# 2023-03-01T13:57:33.655-0500	finished restoring nmdc-next.mags_activity_set (761 documents, 0 failures)
# 2023-03-01T13:57:33.655-0500	dropping collection nmdc-next.metagenome_assembly_set before restoring
# 2023-03-01T13:57:34.306-0500	restoring nmdc-next.metagenome_assembly_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/metagenome_assembly_set.bson
# 2023-03-01T13:57:36.621-0500	[........................]             nmdc-next.functional_annotation_agg   9.40MB/424MB    (2.2%)
# 2023-03-01T13:57:36.621-0500	[########################]                       nmdc-next.data_object_set  14.4MB/14.4MB  (100.0%)
# 2023-03-01T13:57:36.621-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-03-01T13:57:36.621-0500	[######################..]               nmdc-next.metagenome_assembly_set  1.06MB/1.11MB   (95.3%)
# 2023-03-01T13:57:36.621-0500
# 2023-03-01T13:57:37.577-0500	[########################]  nmdc-next.data_object_set  14.4MB/14.4MB  (100.0%)
# 2023-03-01T13:57:37.577-0500	finished restoring nmdc-next.data_object_set (40858 documents, 0 failures)
# 2023-03-01T13:57:37.577-0500	dropping collection nmdc-next.omics_processing_set before restoring
# 2023-03-01T13:57:37.754-0500	[########################]  nmdc-next.metagenome_assembly_set  1.11MB/1.11MB  (100.0%)
# 2023-03-01T13:57:37.754-0500	finished restoring nmdc-next.metagenome_assembly_set (1056 documents, 0 failures)
# 2023-03-01T13:57:37.754-0500	dropping collection nmdc-next.metagenome_annotation_activity_set before restoring
# 2023-03-01T13:57:38.225-0500	restoring nmdc-next.omics_processing_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/omics_processing_set.bson
# 2023-03-01T13:57:38.495-0500	restoring nmdc-next.metagenome_annotation_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/metagenome_annotation_activity_set.bson
# 2023-03-01T13:57:39.622-0500	[........................]             nmdc-next.functional_annotation_agg   10.1MB/424MB    (2.4%)
# 2023-03-01T13:57:39.622-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-03-01T13:57:39.622-0500	[########################]                  nmdc-next.omics_processing_set  1.05MB/1.05MB  (100.0%)
# 2023-03-01T13:57:39.622-0500	[########################]    nmdc-next.metagenome_annotation_activity_set  1.03MB/1.03MB  (100.0%)
# 2023-03-01T13:57:39.622-0500
# 2023-03-01T13:57:40.990-0500	[########################]  nmdc-next.omics_processing_set  1.05MB/1.05MB  (100.0%)
# 2023-03-01T13:57:40.990-0500	finished restoring nmdc-next.omics_processing_set (1927 documents, 0 failures)
# 2023-03-01T13:57:40.990-0500	dropping collection nmdc-next.biosample_set before restoring
# 2023-03-01T13:57:40.998-0500	[########################]  nmdc-next.metagenome_annotation_activity_set  1.03MB/1.03MB  (100.0%)
# 2023-03-01T13:57:40.998-0500	finished restoring nmdc-next.metagenome_annotation_activity_set (818 documents, 0 failures)
# 2023-03-01T13:57:40.998-0500	dropping collection nmdc-next.read_qc_analysis_activity_set before restoring
# 2023-03-01T13:57:41.641-0500	restoring nmdc-next.biosample_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/biosample_set.bson
# 2023-03-01T13:57:41.778-0500	restoring nmdc-next.read_qc_analysis_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/read_qc_analysis_activity_set.bson
# 2023-03-01T13:57:42.622-0500	[........................]             nmdc-next.functional_annotation_agg   10.7MB/424MB    (2.5%)
# 2023-03-01T13:57:42.622-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-03-01T13:57:42.622-0500	[########################]                         nmdc-next.biosample_set  1008KB/1008KB  (100.0%)
# 2023-03-01T13:57:42.622-0500	[######################..]         nmdc-next.read_qc_analysis_activity_set    658KB/696KB   (94.5%)
# 2023-03-01T13:57:42.622-0500
# 2023-03-01T13:57:44.172-0500	[########################]  nmdc-next.biosample_set  1008KB/1008KB  (100.0%)
# 2023-03-01T13:57:44.172-0500	finished restoring nmdc-next.biosample_set (753 documents, 0 failures)
# 2023-03-01T13:57:44.172-0500	dropping collection nmdc-next.nom_analysis_activity_set before restoring
# 2023-03-01T13:57:44.598-0500	[########################]  nmdc-next.read_qc_analysis_activity_set  696KB/696KB  (100.0%)
# 2023-03-01T13:57:44.598-0500	finished restoring nmdc-next.read_qc_analysis_activity_set (1058 documents, 0 failures)
# 2023-03-01T13:57:44.598-0500	dropping collection nmdc-next.study_set before restoring
# 2023-03-01T13:57:45.159-0500	restoring nmdc-next.nom_analysis_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/nom_analysis_activity_set.bson
# 2023-03-01T13:57:45.446-0500	restoring nmdc-next.study_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/study_set.bson
# 2023-03-01T13:57:45.622-0500	[........................]             nmdc-next.functional_annotation_agg   11.2MB/424MB    (2.6%)
# 2023-03-01T13:57:45.622-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-03-01T13:57:45.622-0500	[########################]             nmdc-next.nom_analysis_activity_set    356KB/356KB  (100.0%)
# 2023-03-01T13:57:45.622-0500	[########################]                             nmdc-next.study_set  56.3KB/56.3KB  (100.0%)
# 2023-03-01T13:57:45.622-0500
# 2023-03-01T13:57:45.838-0500	[########################]  nmdc-next.study_set  56.3KB/56.3KB  (100.0%)
# 2023-03-01T13:57:45.838-0500	finished restoring nmdc-next.study_set (9 documents, 0 failures)
# 2023-03-01T13:57:45.838-0500	dropping collection nmdc-next.metatranscriptome_activity_set before restoring
# 2023-03-01T13:57:46.201-0500	[########################]  nmdc-next.nom_analysis_activity_set  356KB/356KB  (100.0%)
# 2023-03-01T13:57:46.201-0500	finished restoring nmdc-next.nom_analysis_activity_set (838 documents, 0 failures)
# 2023-03-01T13:57:46.776-0500	restoring nmdc-next.metatranscriptome_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc/metatranscriptome_activity_set.bson
# 2023-03-01T13:57:47.114-0500	finished restoring nmdc-next.metatranscriptome_activity_set (55 documents, 0 failures)
# 2023-03-01T13:57:48.622-0500	[........................]             nmdc-next.functional_annotation_agg  12.0MB/424MB   (2.8%)
# 2023-03-01T13:57:48.622-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set  43.9MB/198MB  (22.2%)
# 2023-03-01T13:57:48.622-0500
# 2023-03-01T13:57:51.622-0500	[........................]             nmdc-next.functional_annotation_agg  12.9MB/424MB   (3.0%)
# 2023-03-01T13:57:51.622-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set  43.9MB/198MB  (22.2%)
# 2023-03-01T13:57:51.622-0500
# 2023-03-01T13:57:54.622-0500	[........................]             nmdc-next.functional_annotation_agg  13.7MB/424MB   (3.2%)
# 2023-03-01T13:57:54.622-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set  43.9MB/198MB  (22.2%)
# 2023-03-01T13:57:54.622-0500
# 2023-03-01T13:57:57.623-0500	[........................]             nmdc-next.functional_annotation_agg  14.5MB/424MB   (3.4%)
# 2023-03-01T13:57:57.623-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set  43.9MB/198MB  (22.2%)
# 2023-03-01T13:57:57.623-0500
# 2023-03-01T13:58:00.622-0500	[........................]             nmdc-next.functional_annotation_agg  15.5MB/424MB   (3.7%)
# 2023-03-01T13:58:00.622-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set  43.9MB/198MB  (22.2%)
# 2023-03-01T13:58:00.622-0500
# 2023-03-01T13:58:03.623-0500	[........................]             nmdc-next.functional_annotation_agg  16.1MB/424MB   (3.8%)
# 2023-03-01T13:58:03.623-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set  43.9MB/198MB  (22.2%)
# 2023-03-01T13:58:03.623-0500
# 2023-03-01T13:58:06.622-0500	[........................]             nmdc-next.functional_annotation_agg  17.2MB/424MB   (4.1%)
# 2023-03-01T13:58:06.622-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set   109MB/198MB  (55.1%)
# 2023-03-01T13:58:06.622-0500
# 2023-03-01T13:58:09.623-0500	[#.......................]             nmdc-next.functional_annotation_agg  18.0MB/424MB   (4.2%)
# 2023-03-01T13:58:09.623-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set   109MB/198MB  (55.1%)
# 2023-03-01T13:58:09.623-0500
# 2023-03-01T13:58:12.623-0500	[#.......................]             nmdc-next.functional_annotation_agg  18.7MB/424MB   (4.4%)
# 2023-03-01T13:58:12.623-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set   109MB/198MB  (55.1%)
# 2023-03-01T13:58:12.623-0500
# 2023-03-01T13:58:15.623-0500	[#.......................]             nmdc-next.functional_annotation_agg  19.6MB/424MB   (4.6%)
# 2023-03-01T13:58:15.623-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set   109MB/198MB  (55.1%)
# 2023-03-01T13:58:15.623-0500
# 2023-03-01T13:58:18.623-0500	[#.......................]             nmdc-next.functional_annotation_agg  20.4MB/424MB   (4.8%)
# 2023-03-01T13:58:18.623-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set   109MB/198MB  (55.1%)
# 2023-03-01T13:58:18.623-0500
# 2023-03-01T13:58:21.623-0500	[#.......................]             nmdc-next.functional_annotation_agg  21.2MB/424MB   (5.0%)
# 2023-03-01T13:58:21.623-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set   109MB/198MB  (55.1%)
# 2023-03-01T13:58:21.623-0500
# 2023-03-01T13:58:24.623-0500	[#.......................]             nmdc-next.functional_annotation_agg  21.9MB/424MB   (5.2%)
# 2023-03-01T13:58:24.623-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set   109MB/198MB  (55.1%)
# 2023-03-01T13:58:24.623-0500
# 2023-03-01T13:58:27.623-0500	[#.......................]             nmdc-next.functional_annotation_agg  22.8MB/424MB   (5.4%)
# 2023-03-01T13:58:27.623-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set   109MB/198MB  (55.1%)
# 2023-03-01T13:58:27.623-0500
# 2023-03-01T13:58:30.623-0500	[#.......................]             nmdc-next.functional_annotation_agg  23.5MB/424MB   (5.5%)
# 2023-03-01T13:58:30.623-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set   109MB/198MB  (55.1%)
# 2023-03-01T13:58:30.623-0500
# 2023-03-01T13:58:33.623-0500	[#.......................]             nmdc-next.functional_annotation_agg  24.4MB/424MB   (5.8%)
# 2023-03-01T13:58:33.623-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set   109MB/198MB  (55.1%)
# 2023-03-01T13:58:33.623-0500
# 2023-03-01T13:58:36.623-0500	[#.......................]             nmdc-next.functional_annotation_agg  25.4MB/424MB   (6.0%)
# 2023-03-01T13:58:36.623-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set   109MB/198MB  (55.1%)
# 2023-03-01T13:58:36.623-0500
# 2023-03-01T13:58:39.624-0500	[#.......................]             nmdc-next.functional_annotation_agg  26.1MB/424MB   (6.2%)
# 2023-03-01T13:58:39.624-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set   109MB/198MB  (55.1%)
# 2023-03-01T13:58:39.624-0500
# 2023-03-01T13:58:42.623-0500	[#.......................]             nmdc-next.functional_annotation_agg  26.9MB/424MB   (6.4%)
# 2023-03-01T13:58:42.623-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set   109MB/198MB  (55.1%)
# 2023-03-01T13:58:42.623-0500
# 2023-03-01T13:58:45.624-0500	[#.......................]             nmdc-next.functional_annotation_agg  27.8MB/424MB   (6.5%)
# 2023-03-01T13:58:45.624-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set   109MB/198MB  (55.1%)
# 2023-03-01T13:58:45.624-0500
# 2023-03-01T13:58:48.624-0500	[#.......................]             nmdc-next.functional_annotation_agg  28.5MB/424MB   (6.7%)
# 2023-03-01T13:58:48.624-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set   109MB/198MB  (55.1%)
# 2023-03-01T13:58:48.624-0500
# 2023-03-01T13:58:51.624-0500	[#.......................]             nmdc-next.functional_annotation_agg  29.2MB/424MB   (6.9%)
# 2023-03-01T13:58:51.624-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set   109MB/198MB  (55.1%)
# 2023-03-01T13:58:51.624-0500
# 2023-03-01T13:58:54.624-0500	[#.......................]             nmdc-next.functional_annotation_agg  30.1MB/424MB    (7.1%)
# 2023-03-01T13:58:54.624-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T13:58:54.624-0500
# 2023-03-01T13:58:57.624-0500	[#.......................]             nmdc-next.functional_annotation_agg  31.0MB/424MB    (7.3%)
# 2023-03-01T13:58:57.624-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T13:58:57.624-0500
# 2023-03-01T13:59:00.624-0500	[#.......................]             nmdc-next.functional_annotation_agg  31.5MB/424MB    (7.4%)
# 2023-03-01T13:59:00.624-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T13:59:00.624-0500
# 2023-03-01T13:59:03.624-0500	[#.......................]             nmdc-next.functional_annotation_agg  32.5MB/424MB    (7.7%)
# 2023-03-01T13:59:03.624-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T13:59:03.624-0500
# 2023-03-01T13:59:06.624-0500	[#.......................]             nmdc-next.functional_annotation_agg  33.3MB/424MB    (7.9%)
# 2023-03-01T13:59:06.624-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T13:59:06.624-0500
# 2023-03-01T13:59:09.624-0500	[#.......................]             nmdc-next.functional_annotation_agg  34.2MB/424MB    (8.1%)
# 2023-03-01T13:59:09.624-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T13:59:09.624-0500
# 2023-03-01T13:59:12.624-0500	[#.......................]             nmdc-next.functional_annotation_agg  34.9MB/424MB    (8.2%)
# 2023-03-01T13:59:12.625-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T13:59:12.625-0500
# 2023-03-01T13:59:15.624-0500	[##......................]             nmdc-next.functional_annotation_agg  35.7MB/424MB    (8.4%)
# 2023-03-01T13:59:15.624-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T13:59:15.624-0500
# 2023-03-01T13:59:18.624-0500	[##......................]             nmdc-next.functional_annotation_agg  36.5MB/424MB    (8.6%)
# 2023-03-01T13:59:18.624-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T13:59:18.624-0500
# 2023-03-01T13:59:21.624-0500	[##......................]             nmdc-next.functional_annotation_agg  37.4MB/424MB    (8.8%)
# 2023-03-01T13:59:21.624-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T13:59:21.624-0500
# 2023-03-01T13:59:24.624-0500	[##......................]             nmdc-next.functional_annotation_agg  38.2MB/424MB    (9.0%)
# 2023-03-01T13:59:24.624-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T13:59:24.624-0500
# 2023-03-01T13:59:27.625-0500	[##......................]             nmdc-next.functional_annotation_agg  39.0MB/424MB    (9.2%)
# 2023-03-01T13:59:27.625-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T13:59:27.625-0500
# 2023-03-01T13:59:30.625-0500	[##......................]             nmdc-next.functional_annotation_agg  39.8MB/424MB    (9.4%)
# 2023-03-01T13:59:30.625-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T13:59:30.625-0500
# 2023-03-01T13:59:33.625-0500	[##......................]             nmdc-next.functional_annotation_agg  40.7MB/424MB    (9.6%)
# 2023-03-01T13:59:33.625-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T13:59:33.625-0500
# 2023-03-01T13:59:36.625-0500	[##......................]             nmdc-next.functional_annotation_agg  41.6MB/424MB    (9.8%)
# 2023-03-01T13:59:36.625-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T13:59:36.625-0500
# 2023-03-01T13:59:39.626-0500	[##......................]             nmdc-next.functional_annotation_agg  42.4MB/424MB   (10.0%)
# 2023-03-01T13:59:39.626-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T13:59:39.626-0500
# 2023-03-01T13:59:42.625-0500	[##......................]             nmdc-next.functional_annotation_agg  43.4MB/424MB   (10.2%)
# 2023-03-01T13:59:42.625-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T13:59:42.625-0500
# 2023-03-01T13:59:45.625-0500	[##......................]             nmdc-next.functional_annotation_agg  44.1MB/424MB   (10.4%)
# 2023-03-01T13:59:45.625-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T13:59:45.625-0500
# 2023-03-01T13:59:48.625-0500	[##......................]             nmdc-next.functional_annotation_agg  45.0MB/424MB   (10.6%)
# 2023-03-01T13:59:48.625-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T13:59:48.625-0500
# 2023-03-01T13:59:51.625-0500	[##......................]             nmdc-next.functional_annotation_agg  45.9MB/424MB   (10.8%)
# 2023-03-01T13:59:51.625-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T13:59:51.625-0500
# 2023-03-01T13:59:54.625-0500	[##......................]             nmdc-next.functional_annotation_agg  46.6MB/424MB   (11.0%)
# 2023-03-01T13:59:54.625-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T13:59:54.625-0500
# 2023-03-01T13:59:57.625-0500	[##......................]             nmdc-next.functional_annotation_agg  47.3MB/424MB   (11.1%)
# 2023-03-01T13:59:57.625-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T13:59:57.625-0500
# 2023-03-01T14:00:00.625-0500	[##......................]             nmdc-next.functional_annotation_agg  48.1MB/424MB   (11.3%)
# 2023-03-01T14:00:00.625-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T14:00:00.625-0500
# 2023-03-01T14:00:03.626-0500	[##......................]             nmdc-next.functional_annotation_agg  48.9MB/424MB   (11.5%)
# 2023-03-01T14:00:03.626-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T14:00:03.626-0500
# 2023-03-01T14:00:06.626-0500	[##......................]             nmdc-next.functional_annotation_agg  49.6MB/424MB   (11.7%)
# 2023-03-01T14:00:06.626-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T14:00:06.626-0500
# 2023-03-01T14:00:09.626-0500	[##......................]             nmdc-next.functional_annotation_agg  50.3MB/424MB   (11.9%)
# 2023-03-01T14:00:09.626-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T14:00:09.626-0500
# 2023-03-01T14:00:12.626-0500	[##......................]             nmdc-next.functional_annotation_agg  51.2MB/424MB   (12.1%)
# 2023-03-01T14:00:12.626-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T14:00:12.626-0500
# 2023-03-01T14:00:15.626-0500	[##......................]             nmdc-next.functional_annotation_agg  51.7MB/424MB   (12.2%)
# 2023-03-01T14:00:15.626-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T14:00:15.626-0500
# 2023-03-01T14:00:18.626-0500	[##......................]             nmdc-next.functional_annotation_agg  52.6MB/424MB   (12.4%)
# 2023-03-01T14:00:18.626-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T14:00:18.626-0500
# 2023-03-01T14:00:21.626-0500	[###.....................]             nmdc-next.functional_annotation_agg  53.4MB/424MB   (12.6%)
# 2023-03-01T14:00:21.626-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T14:00:21.626-0500
# 2023-03-01T14:00:24.626-0500	[###.....................]             nmdc-next.functional_annotation_agg  54.1MB/424MB   (12.8%)
# 2023-03-01T14:00:24.626-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T14:00:24.626-0500
# 2023-03-01T14:00:27.626-0500	[###.....................]             nmdc-next.functional_annotation_agg  54.9MB/424MB   (12.9%)
# 2023-03-01T14:00:27.626-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T14:00:27.626-0500
# 2023-03-01T14:00:30.626-0500	[###.....................]             nmdc-next.functional_annotation_agg  55.8MB/424MB   (13.1%)
# 2023-03-01T14:00:30.626-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set   198MB/198MB  (100.0%)
# 2023-03-01T14:00:30.626-0500
# 2023-03-01T14:00:30.834-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-03-01T14:00:30.834-0500	finished restoring nmdc-next.metaproteomics_analysis_activity_set (52 documents, 0 failures)
# 2023-03-01T14:00:33.626-0500	[###.....................]  nmdc-next.functional_annotation_agg  58.3MB/424MB  (13.7%)
# 2023-03-01T14:00:36.627-0500	[###.....................]  nmdc-next.functional_annotation_agg  60.9MB/424MB  (14.4%)
# 2023-03-01T14:00:39.626-0500	[###.....................]  nmdc-next.functional_annotation_agg  63.3MB/424MB  (14.9%)
# 2023-03-01T14:00:42.627-0500	[###.....................]  nmdc-next.functional_annotation_agg  65.6MB/424MB  (15.5%)
# 2023-03-01T14:00:45.626-0500	[###.....................]  nmdc-next.functional_annotation_agg  68.4MB/424MB  (16.1%)
# 2023-03-01T14:00:48.627-0500	[####....................]  nmdc-next.functional_annotation_agg  70.8MB/424MB  (16.7%)
# 2023-03-01T14:00:51.627-0500	[####....................]  nmdc-next.functional_annotation_agg  73.3MB/424MB  (17.3%)
# 2023-03-01T14:00:54.627-0500	[####....................]  nmdc-next.functional_annotation_agg  76.1MB/424MB  (17.9%)
# 2023-03-01T14:00:57.627-0500	[####....................]  nmdc-next.functional_annotation_agg  78.5MB/424MB  (18.5%)
# 2023-03-01T14:01:00.627-0500	[####....................]  nmdc-next.functional_annotation_agg  80.4MB/424MB  (19.0%)
# 2023-03-01T14:01:03.627-0500	[####....................]  nmdc-next.functional_annotation_agg  82.6MB/424MB  (19.5%)
# 2023-03-01T14:01:06.627-0500	[####....................]  nmdc-next.functional_annotation_agg  85.5MB/424MB  (20.2%)
# 2023-03-01T14:01:09.627-0500	[####....................]  nmdc-next.functional_annotation_agg  88.2MB/424MB  (20.8%)
# 2023-03-01T14:01:12.627-0500	[#####...................]  nmdc-next.functional_annotation_agg  90.4MB/424MB  (21.3%)
# 2023-03-01T14:01:15.627-0500	[#####...................]  nmdc-next.functional_annotation_agg  93.1MB/424MB  (21.9%)
# 2023-03-01T14:01:18.627-0500	[#####...................]  nmdc-next.functional_annotation_agg  95.9MB/424MB  (22.6%)
# 2023-03-01T14:01:21.628-0500	[#####...................]  nmdc-next.functional_annotation_agg  98.2MB/424MB  (23.2%)
# 2023-03-01T14:01:24.628-0500	[#####...................]  nmdc-next.functional_annotation_agg  101MB/424MB  (23.7%)
# 2023-03-01T14:01:27.628-0500	[#####...................]  nmdc-next.functional_annotation_agg  104MB/424MB  (24.4%)
# 2023-03-01T14:01:30.628-0500	[#####...................]  nmdc-next.functional_annotation_agg  106MB/424MB  (25.0%)
# 2023-03-01T14:01:33.628-0500	[######..................]  nmdc-next.functional_annotation_agg  109MB/424MB  (25.6%)
# 2023-03-01T14:01:36.628-0500	[######..................]  nmdc-next.functional_annotation_agg  111MB/424MB  (26.2%)
# 2023-03-01T14:01:39.628-0500	[######..................]  nmdc-next.functional_annotation_agg  114MB/424MB  (26.8%)
# 2023-03-01T14:01:42.628-0500	[######..................]  nmdc-next.functional_annotation_agg  116MB/424MB  (27.4%)
# 2023-03-01T14:01:45.628-0500	[######..................]  nmdc-next.functional_annotation_agg  119MB/424MB  (28.0%)
# 2023-03-01T14:01:48.628-0500	[######..................]  nmdc-next.functional_annotation_agg  121MB/424MB  (28.6%)
# 2023-03-01T14:01:51.628-0500	[#######.................]  nmdc-next.functional_annotation_agg  124MB/424MB  (29.2%)
# 2023-03-01T14:01:54.628-0500	[#######.................]  nmdc-next.functional_annotation_agg  127MB/424MB  (29.9%)
# 2023-03-01T14:01:57.628-0500	[#######.................]  nmdc-next.functional_annotation_agg  129MB/424MB  (30.4%)
# 2023-03-01T14:02:00.629-0500	[#######.................]  nmdc-next.functional_annotation_agg  131MB/424MB  (30.9%)
# 2023-03-01T14:02:03.629-0500	[#######.................]  nmdc-next.functional_annotation_agg  134MB/424MB  (31.5%)
# 2023-03-01T14:02:06.629-0500	[#######.................]  nmdc-next.functional_annotation_agg  136MB/424MB  (32.1%)
# 2023-03-01T14:02:09.629-0500	[#######.................]  nmdc-next.functional_annotation_agg  139MB/424MB  (32.7%)
# 2023-03-01T14:02:12.629-0500	[########................]  nmdc-next.functional_annotation_agg  142MB/424MB  (33.4%)
# 2023-03-01T14:02:15.629-0500	[########................]  nmdc-next.functional_annotation_agg  144MB/424MB  (33.9%)
# 2023-03-01T14:02:18.629-0500	[########................]  nmdc-next.functional_annotation_agg  147MB/424MB  (34.5%)
# 2023-03-01T14:02:21.629-0500	[########................]  nmdc-next.functional_annotation_agg  149MB/424MB  (35.2%)
# 2023-03-01T14:02:24.629-0500	[########................]  nmdc-next.functional_annotation_agg  152MB/424MB  (35.8%)
# 2023-03-01T14:02:27.629-0500	[########................]  nmdc-next.functional_annotation_agg  154MB/424MB  (36.3%)
# 2023-03-01T14:02:30.629-0500	[########................]  nmdc-next.functional_annotation_agg  157MB/424MB  (36.9%)
# 2023-03-01T14:02:33.630-0500	[#########...............]  nmdc-next.functional_annotation_agg  159MB/424MB  (37.5%)
# 2023-03-01T14:02:36.629-0500	[#########...............]  nmdc-next.functional_annotation_agg  162MB/424MB  (38.1%)
# 2023-03-01T14:02:39.630-0500	[#########...............]  nmdc-next.functional_annotation_agg  164MB/424MB  (38.8%)
# 2023-03-01T14:02:42.630-0500	[#########...............]  nmdc-next.functional_annotation_agg  167MB/424MB  (39.3%)
# 2023-03-01T14:02:45.630-0500	[#########...............]  nmdc-next.functional_annotation_agg  169MB/424MB  (39.9%)
# 2023-03-01T14:02:48.630-0500	[#########...............]  nmdc-next.functional_annotation_agg  172MB/424MB  (40.6%)
# 2023-03-01T14:02:51.630-0500	[#########...............]  nmdc-next.functional_annotation_agg  174MB/424MB  (41.1%)
# 2023-03-01T14:02:54.630-0500	[##########..............]  nmdc-next.functional_annotation_agg  177MB/424MB  (41.7%)
# 2023-03-01T14:02:57.630-0500	[##########..............]  nmdc-next.functional_annotation_agg  180MB/424MB  (42.4%)
# 2023-03-01T14:03:00.630-0500	[##########..............]  nmdc-next.functional_annotation_agg  182MB/424MB  (42.9%)
# 2023-03-01T14:03:03.630-0500	[##########..............]  nmdc-next.functional_annotation_agg  184MB/424MB  (43.5%)
# 2023-03-01T14:03:06.630-0500	[##########..............]  nmdc-next.functional_annotation_agg  187MB/424MB  (44.1%)
# 2023-03-01T14:03:09.630-0500	[##########..............]  nmdc-next.functional_annotation_agg  190MB/424MB  (44.7%)
# 2023-03-01T14:03:12.630-0500	[##########..............]  nmdc-next.functional_annotation_agg  192MB/424MB  (45.3%)
# 2023-03-01T14:03:15.630-0500	[###########.............]  nmdc-next.functional_annotation_agg  195MB/424MB  (46.0%)
# 2023-03-01T14:03:18.631-0500	[###########.............]  nmdc-next.functional_annotation_agg  198MB/424MB  (46.6%)
# 2023-03-01T14:03:21.631-0500	[###########.............]  nmdc-next.functional_annotation_agg  200MB/424MB  (47.1%)
# 2023-03-01T14:03:24.631-0500	[###########.............]  nmdc-next.functional_annotation_agg  203MB/424MB  (47.7%)
# 2023-03-01T14:03:27.631-0500	[###########.............]  nmdc-next.functional_annotation_agg  205MB/424MB  (48.3%)
# 2023-03-01T14:03:30.631-0500	[###########.............]  nmdc-next.functional_annotation_agg  207MB/424MB  (48.9%)
# 2023-03-01T14:03:33.631-0500	[###########.............]  nmdc-next.functional_annotation_agg  210MB/424MB  (49.6%)
# 2023-03-01T14:03:36.631-0500	[############............]  nmdc-next.functional_annotation_agg  213MB/424MB  (50.1%)
# 2023-03-01T14:03:39.631-0500	[############............]  nmdc-next.functional_annotation_agg  215MB/424MB  (50.7%)
# 2023-03-01T14:03:42.631-0500	[############............]  nmdc-next.functional_annotation_agg  218MB/424MB  (51.4%)
# 2023-03-01T14:03:45.631-0500	[############............]  nmdc-next.functional_annotation_agg  220MB/424MB  (51.9%)
# 2023-03-01T14:03:48.632-0500	[############............]  nmdc-next.functional_annotation_agg  223MB/424MB  (52.5%)
# 2023-03-01T14:03:51.634-0500	[############............]  nmdc-next.functional_annotation_agg  225MB/424MB  (53.2%)
# 2023-03-01T14:03:54.632-0500	[############............]  nmdc-next.functional_annotation_agg  228MB/424MB  (53.8%)
# 2023-03-01T14:03:57.632-0500	[#############...........]  nmdc-next.functional_annotation_agg  230MB/424MB  (54.3%)
# 2023-03-01T14:04:00.632-0500	[#############...........]  nmdc-next.functional_annotation_agg  233MB/424MB  (55.0%)
# 2023-03-01T14:04:03.632-0500	[#############...........]  nmdc-next.functional_annotation_agg  236MB/424MB  (55.6%)
# 2023-03-01T14:04:06.632-0500	[#############...........]  nmdc-next.functional_annotation_agg  238MB/424MB  (56.2%)
# 2023-03-01T14:04:09.633-0500	[#############...........]  nmdc-next.functional_annotation_agg  241MB/424MB  (56.9%)
# 2023-03-01T14:04:12.633-0500	[#############...........]  nmdc-next.functional_annotation_agg  244MB/424MB  (57.5%)
# 2023-03-01T14:04:15.633-0500	[#############...........]  nmdc-next.functional_annotation_agg  246MB/424MB  (58.0%)
# 2023-03-01T14:04:18.632-0500	[##############..........]  nmdc-next.functional_annotation_agg  248MB/424MB  (58.4%)
# 2023-03-01T14:04:21.633-0500	[##############..........]  nmdc-next.functional_annotation_agg  250MB/424MB  (59.0%)
# 2023-03-01T14:04:24.632-0500	[##############..........]  nmdc-next.functional_annotation_agg  252MB/424MB  (59.5%)
# 2023-03-01T14:04:27.632-0500	[##############..........]  nmdc-next.functional_annotation_agg  255MB/424MB  (60.2%)
# 2023-03-01T14:04:30.633-0500	[##############..........]  nmdc-next.functional_annotation_agg  257MB/424MB  (60.6%)
# 2023-03-01T14:04:33.633-0500	[##############..........]  nmdc-next.functional_annotation_agg  259MB/424MB  (61.0%)
# 2023-03-01T14:04:36.633-0500	[##############..........]  nmdc-next.functional_annotation_agg  261MB/424MB  (61.5%)
# 2023-03-01T14:04:39.633-0500	[##############..........]  nmdc-next.functional_annotation_agg  263MB/424MB  (62.1%)
# 2023-03-01T14:04:42.633-0500	[###############.........]  nmdc-next.functional_annotation_agg  265MB/424MB  (62.6%)
# 2023-03-01T14:04:45.633-0500	[###############.........]  nmdc-next.functional_annotation_agg  268MB/424MB  (63.3%)
# 2023-03-01T14:04:48.633-0500	[###############.........]  nmdc-next.functional_annotation_agg  271MB/424MB  (63.8%)
# 2023-03-01T14:04:51.633-0500	[###############.........]  nmdc-next.functional_annotation_agg  273MB/424MB  (64.4%)
# 2023-03-01T14:04:54.633-0500	[###############.........]  nmdc-next.functional_annotation_agg  276MB/424MB  (65.0%)
# 2023-03-01T14:04:57.633-0500	[###############.........]  nmdc-next.functional_annotation_agg  278MB/424MB  (65.6%)
# 2023-03-01T14:05:00.634-0500	[###############.........]  nmdc-next.functional_annotation_agg  280MB/424MB  (66.1%)
# 2023-03-01T14:05:03.634-0500	[################........]  nmdc-next.functional_annotation_agg  283MB/424MB  (66.7%)
# 2023-03-01T14:05:06.633-0500	[################........]  nmdc-next.functional_annotation_agg  286MB/424MB  (67.3%)
# 2023-03-01T14:05:09.634-0500	[################........]  nmdc-next.functional_annotation_agg  288MB/424MB  (67.9%)
# 2023-03-01T14:05:12.634-0500	[################........]  nmdc-next.functional_annotation_agg  291MB/424MB  (68.6%)
# 2023-03-01T14:05:15.635-0500	[################........]  nmdc-next.functional_annotation_agg  293MB/424MB  (69.1%)
# 2023-03-01T14:05:18.634-0500	[################........]  nmdc-next.functional_annotation_agg  295MB/424MB  (69.6%)
# 2023-03-01T14:05:21.634-0500	[################........]  nmdc-next.functional_annotation_agg  298MB/424MB  (70.3%)
# 2023-03-01T14:05:24.634-0500	[#################.......]  nmdc-next.functional_annotation_agg  301MB/424MB  (70.9%)
# 2023-03-01T14:05:27.634-0500	[#################.......]  nmdc-next.functional_annotation_agg  303MB/424MB  (71.5%)
# 2023-03-01T14:05:30.634-0500	[#################.......]  nmdc-next.functional_annotation_agg  306MB/424MB  (72.1%)
# 2023-03-01T14:05:33.635-0500	[#################.......]  nmdc-next.functional_annotation_agg  308MB/424MB  (72.7%)
# 2023-03-01T14:05:36.634-0500	[#################.......]  nmdc-next.functional_annotation_agg  311MB/424MB  (73.3%)
# ...
# 2023-03-01T14:07:06.637-0500	[#####################...]  nmdc-next.functional_annotation_agg  386MB/424MB  (91.1%)
# 2023-03-01T14:07:09.637-0500	[#####################...]  nmdc-next.functional_annotation_agg  388MB/424MB  (91.6%)
# 2023-03-01T14:07:12.637-0500	[######################..]  nmdc-next.functional_annotation_agg  391MB/424MB  (92.2%)
# 2023-03-01T14:07:15.638-0500	[######################..]  nmdc-next.functional_annotation_agg  394MB/424MB  (92.9%)
# 2023-03-01T14:07:18.637-0500	[######################..]  nmdc-next.functional_annotation_agg  396MB/424MB  (93.4%)
# 2023-03-01T14:07:21.638-0500	[######################..]  nmdc-next.functional_annotation_agg  399MB/424MB  (94.1%)
# 2023-03-01T14:07:24.638-0500	[######################..]  nmdc-next.functional_annotation_agg  402MB/424MB  (94.8%)
# 2023-03-01T14:07:27.637-0500	[######################..]  nmdc-next.functional_annotation_agg  404MB/424MB  (95.2%)
# 2023-03-01T14:07:30.638-0500	[#######################.]  nmdc-next.functional_annotation_agg  406MB/424MB  (95.8%)
# 2023-03-01T14:07:33.638-0500	[#######################.]  nmdc-next.functional_annotation_agg  409MB/424MB  (96.4%)
# 2023-03-01T14:07:36.638-0500	[#######################.]  nmdc-next.functional_annotation_agg  411MB/424MB  (97.0%)
# 2023-03-01T14:07:39.637-0500	[#######################.]  nmdc-next.functional_annotation_agg  414MB/424MB  (97.6%)
# 2023-03-01T14:07:42.638-0500	[#######################.]  nmdc-next.functional_annotation_agg  417MB/424MB  (98.2%)
# 2023-03-01T14:07:45.638-0500	[#######################.]  nmdc-next.functional_annotation_agg  419MB/424MB  (98.7%)
# 2023-03-01T14:07:48.638-0500	[#######################.]  nmdc-next.functional_annotation_agg  421MB/424MB  (99.3%)
# 2023-03-01T14:07:51.638-0500	[########################]  nmdc-next.functional_annotation_agg  424MB/424MB  (100.0%)
# 2023-03-01T14:07:51.689-0500	[########################]  nmdc-next.functional_annotation_agg  424MB/424MB  (100.0%)
# 2023-03-01T14:07:51.689-0500	finished restoring nmdc-next.functional_annotation_agg (3046840 documents, 0 failures)
# 2023-03-01T14:07:51.689-0500	restoring indexes for collection nmdc-next.study_set from metadata
# 2023-03-01T14:07:51.689-0500	restoring indexes for collection nmdc-next.data_object_set from metadata
# 2023-03-01T14:07:51.689-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"data_object_type", "v":2}, Key:primitive.D{primitive.E{Key:"data_object_type", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:51.689-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"file_size_bytes", "v":2}, Key:primitive.D{primitive.E{Key:"file_size_bytes", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:51.689-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"url", "v":2}, Key:primitive.D{primitive.E{Key:"url", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:51.689-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:51.690-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"md5_checksum", "v":2}, Key:primitive.D{primitive.E{Key:"md5_checksum", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:51.690-0500	restoring indexes for collection nmdc-next.metabolomics_analysis_activity_set from metadata
# 2023-03-01T14:07:51.690-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:51.690-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"was_informed_by_1", "v":2}, Key:primitive.D{primitive.E{Key:"was_informed_by", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:51.690-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ended_at_time_1", "v":2}, Key:primitive.D{primitive.E{Key:"ended_at_time", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:51.690-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"has_credit_associations.applies_to_person.orcid", "v":2}, Key:primitive.D{primitive.E{Key:"has_credit_associations.applies_to_person.orcid", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:51.690-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:51.690-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"has_credit_associations.applies_to_person.name", "v":2}, Key:primitive.D{primitive.E{Key:"has_credit_associations.applies_to_person.name", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:51.690-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"has_credit_associations.applied_roles", "v":2}, Key:primitive.D{primitive.E{Key:"has_credit_associations.applied_roles", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:51.690-0500	restoring indexes for collection nmdc-next.metaproteomics_analysis_activity_set from metadata
# 2023-03-01T14:07:51.690-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"was_informed_by_1", "v":2}, Key:primitive.D{primitive.E{Key:"was_informed_by", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:51.690-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:51.690-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ended_at_time_1", "v":2}, Key:primitive.D{primitive.E{Key:"ended_at_time", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.713-0500	restoring indexes for collection nmdc-next.mags_activity_set from metadata
# 2023-03-01T14:07:52.713-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.713-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ended_at_time_1", "v":2}, Key:primitive.D{primitive.E{Key:"ended_at_time", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.713-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"was_informed_by_1", "v":2}, Key:primitive.D{primitive.E{Key:"was_informed_by", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.715-0500	restoring indexes for collection nmdc-next.metagenome_annotation_activity_set from metadata
# 2023-03-01T14:07:52.715-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ended_at_time_1", "v":2}, Key:primitive.D{primitive.E{Key:"ended_at_time", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.715-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.715-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"was_informed_by_1", "v":2}, Key:primitive.D{primitive.E{Key:"was_informed_by", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.715-0500	restoring indexes for collection nmdc-next.omics_processing_set from metadata
# 2023-03-01T14:07:52.715-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"has_output", "v":2}, Key:primitive.D{primitive.E{Key:"has_output", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.715-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"has_input", "v":2}, Key:primitive.D{primitive.E{Key:"has_input", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.715-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"instrument_name", "v":2}, Key:primitive.D{primitive.E{Key:"instrument_name", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.715-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ended_at_time_1", "v":2}, Key:primitive.D{primitive.E{Key:"ended_at_time", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.715-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.715-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"alternative_identifiers", "v":2}, Key:primitive.D{primitive.E{Key:"alternative_identifiers", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.760-0500	restoring indexes for collection nmdc-next.biosample_set from metadata
# 2023-03-01T14:07:52.760-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ecosystem_type", "v":2}, Key:primitive.D{primitive.E{Key:"ecosystem_type", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.760-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ecosystem_subtype", "v":2}, Key:primitive.D{primitive.E{Key:"ecosystem_subtype", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.760-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"lat_lon.latitude", "v":2}, Key:primitive.D{primitive.E{Key:"lat_lon.latitude", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.760-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"env_broad_scale.has_raw_value", "v":2}, Key:primitive.D{primitive.E{Key:"env_broad_scale.has_raw_value", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.760-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"collection_date.has_raw_value", "v":2}, Key:primitive.D{primitive.E{Key:"collection_date.has_raw_value", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.760-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"specific_ecosystem", "v":2}, Key:primitive.D{primitive.E{Key:"specific_ecosystem", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.761-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"part_of_1", "v":2}, Key:primitive.D{primitive.E{Key:"part_of", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.761-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ecosystem", "v":2}, Key:primitive.D{primitive.E{Key:"ecosystem", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.761-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"env_local_scale.has_raw_value", "v":2}, Key:primitive.D{primitive.E{Key:"env_local_scale.has_raw_value", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.761-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"env_medium.has_raw_value", "v":2}, Key:primitive.D{primitive.E{Key:"env_medium.has_raw_value", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.761-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"alternative_identifiers", "v":2}, Key:primitive.D{primitive.E{Key:"alternative_identifiers", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.761-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ecosystem_category", "v":2}, Key:primitive.D{primitive.E{Key:"ecosystem_category", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.761-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"lat_lon.longitude", "v":2}, Key:primitive.D{primitive.E{Key:"lat_lon.longitude", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:52.761-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:53.291-0500	restoring indexes for collection nmdc-next.nom_analysis_activity_set from metadata
# 2023-03-01T14:07:53.291-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:53.291-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"was_informed_by_1", "v":2}, Key:primitive.D{primitive.E{Key:"was_informed_by", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:53.291-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ended_at_time_1", "v":2}, Key:primitive.D{primitive.E{Key:"ended_at_time", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:53.955-0500	restoring indexes for collection nmdc-next.metagenome_assembly_set from metadata
# 2023-03-01T14:07:53.955-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"was_informed_by_1", "v":2}, Key:primitive.D{primitive.E{Key:"was_informed_by", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:53.955-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ended_at_time_1", "v":2}, Key:primitive.D{primitive.E{Key:"ended_at_time", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:53.955-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:53.955-0500	restoring indexes for collection nmdc-next.functional_annotation_agg from metadata
# 2023-03-01T14:07:53.955-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"metagenome_id2", "v":2}, Key:primitive.D{primitive.E{Key:"metagenome_annotation_id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:54.092-0500	restoring indexes for collection nmdc-next.metatranscriptome_activity_set from metadata
# 2023-03-01T14:07:54.092-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:54.092-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"was_informed_by_1", "v":2}, Key:primitive.D{primitive.E{Key:"was_informed_by", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:54.092-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ended_at_time_1", "v":2}, Key:primitive.D{primitive.E{Key:"ended_at_time", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:54.248-0500	restoring indexes for collection nmdc-next.read_qc_analysis_activity_set from metadata
# 2023-03-01T14:07:54.248-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:54.248-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"was_informed_by_1", "v":2}, Key:primitive.D{primitive.E{Key:"was_informed_by", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:07:54.248-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ended_at_time_1", "v":2}, Key:primitive.D{primitive.E{Key:"ended_at_time", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-03-01T14:08:00.039-0500	3095234 document(s) restored successfully. 0 document(s) failed to restore.
# Took approx. 681.4387848377228 seconds
