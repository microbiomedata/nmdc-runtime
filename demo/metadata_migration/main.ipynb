# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

from dotenv import load_dotenv
from pymongo import MongoClient
from pymongo.errors import OperationFailure

load_dotenv("../../.env.localhost")

admin_client = MongoClient(
    host=os.getenv("MONGO_HOST"),
    username=os.getenv("MONGO_USERNAME"),
    password=os.getenv("MONGO_PASSWORD"),
    directConnection=True, # connect to host as a standalone, rather than to entire replicaset
)
reader_client = MongoClient(
    host=os.getenv("MONGO_HOST"),
    username=os.getenv("MONGO_READONLY_USERNAME"),
    password=os.getenv("MONGO_READONLY_PASSWORD"),
    directConnection=True, # connect to host as a standalone, rather than to entire replicaset
)

mdb_src = reader_client[os.getenv("MONGO_DBNAME")]
mdb_tgt = admin_client[os.getenv("MONGO_DBNAME") + "-next"]


try:
    mdb_src.study_set.insert_one({"_id": "foobar"})
    print("NOT OK")
    mdb_src.study_set.delete_one({"_id": "foobar"})
    print("state restored")
    raise Exception("can write to `mdb_src`!")
except OperationFailure:
    pass

# %% [markdown]
# No output from above? Good!

# %%
"""Utils"""

from copy import deepcopy
import pkg_resources
from pprint import pprint
import time

import fastjsonschema
from toolz import dissoc

def strip_oid(doc):
    return dissoc(doc, "_id")

def nmdc_schema_collection_names() -> set:
    return {
        k for k, v in get_nmdc_jsonschema_dict()["$defs"]["Database"]["properties"].items()
        if v.get("items",{}).get("$ref")
    }

def present_src_collections(mdb) -> list:
    return sorted(
        n for n in (nmdc_schema_collection_names() & set(mdb_src.list_collection_names()))
        if mdb_src[n].estimated_document_count()
    )

# %%
"""Monkey-patch schema in light of expected metadata/schema modifications."""

from nmdc_runtime.util import get_nmdc_jsonschema_dict

def without_id_patterns(nmdc_jsonschema):
    rv = deepcopy(nmdc_jsonschema)
    for cls_, spec in rv["$defs"].items():
        if "properties" in spec:
            if "id" in spec["properties"]:
                spec["properties"]["id"].pop("pattern", None)
    return rv


# SCHEMA_DEFS_PATCHES = {
#     "Entity1": {
#         "attribute1": {
#                "description": "Lorem ipsum",
#                "type": "string"
#         },
#         "attribute2": {
#                "items": {
#                   "$ref": "#/$defs/Entity2"
#                },
#                "type": "array"
#         }
#     },
# }

# def patch_schema_defs(nmdc_jsonschema, patches=SCHEMA_DEFS_PATCHES):
#     rv = deepcopy(nmdc_jsonschema)
#     defs = rv["$defs"]
#     for cls_, spec in patches.items():
#         if cls_ not in defs:
#             raise Exception(f"Class not present, so cannot patch: {cls_}")
#         elif "properties" not in defs[cls_]:
#             defs[cls_]["properties"] = spec
#         else:
#             for k, v in spec.items():
#                 defs[cls_]["properties"][k] = v
#     return rv

print(pkg_resources.get_distribution("nmdc_schema").version)

nmdc_jsonschema_validate = fastjsonschema.compile(
    without_id_patterns(get_nmdc_jsonschema_dict())
)
# Out:
# 7.4.11

# %% [markdown]
# Reference for anticipated migration logic/config: https://github.com/microbiomedata/nmdc-schema/blob/v7.4.10/nmdc_schema/migrate_3_2_to_7.py

# %%
from inspect import signature
import re

from toolz import assoc, assoc_in, dissoc


id_pattern = re.compile(r"(PO|ENVO):\d+")
curie_pattern = re.compile(r"[A-Za-z]\w+:\w+")


def ensure_term_id(v):
    if not ("term" in v or "has_raw_value" in v):
        raise Exception(f"needs `term` or `has_raw_value`")
    if not (m := re.search(id_pattern, v["has_raw_value"])):
        raise Exception(f'{v["has_raw_value"]} does not match a known ID pattern')
    
    return assoc(v, "term", {"id": v["has_raw_value"]})


def uppercase_curie_prefixes(v):
    if not isinstance(v, list):
        raise Exception("list expected")
    if not all(":" in elt for elt in v):
        raise Exception("CURIEs expected")
    
    rv = []
    for elt in v:
        prefix, localpart = elt.split(":", maxsplit=1)
        rv.append(prefix.upper() + ":" + localpart)
    return rv


def lowercase_curie_prefixes(v):
    if not isinstance(v, list):
        raise Exception("list expected")
    if not all(":" in elt for elt in v):
        raise Exception("CURIEs expected")
    
    rv = []
    for elt in v:
        prefix, localpart = elt.split(":", maxsplit=1)
        rv.append(prefix.lower() + ":" + localpart)
    return rv


def ensure_curies(v):
    """
    >>> ensure_curies(['HTTPS://identifiers.org/gold:Gs0144557'])
    ['gold:Gs0144557']
    """
    if not isinstance(v, list):
        raise Exception("list expected")
    if not all(":" in elt for elt in v):
        raise Exception("CURIE-ables expected")

    return [re.search(curie_pattern, elt).group(0) for elt in v]


def ensure_depth_via_depth2(v, d):
    if "depth" not in d:
        raise Exception("no `depth` field")
    
    depth = d["depth"]
    return {"depth": depth, "depth2": None}


def remove_type_field(v):
    return dissoc(v, "type")


def ensure_number_in_meters(v):
    if isinstance(v, dict):
        assert "has_unit" in v, "no units"
        assert v["has_unit"] in ("meter", "metre"), "not meters"
        return v["has_numeric_value"]
    assert isinstance(v, int | float), "not a number"
    return v


def ensure_gold_sequencing_project_identifiers(v, d):
    if not isinstance(v, list):
        raise Exception("list expected")
    if "gold_sequencing_project_identifiers" not in d:
        return v

    rv = []
    for elt in v:
        if elt.lower().startswith("gold:gb"):
            if d["id"].lower().startswith("gold:gp"):
                rv.append(d["id"])
            else:
                raise Exception("no avaialable substitute")
        else:
            rv.append(elt)
    return {"gold_sequencing_project_identifiers": rv}


def rename_num_tRNA(v):
    return [
        change_fieldname(elt, "num_tRNA", "num_t_rna")
        for elt in v if "num_tRNA" in elt
    ]


fieldname_replacements = {
    "biosample_set": {
        "INSDC_biosample_identifiers": "insdc_biosample_identifiers",
        # # "part_of": "sample_link",
        "identifier": "samp_name",
        "GOLD_sample_identifiers": "gold_biosample_identifiers",
        "env_broad_scale": [ensure_term_id, remove_type_field],
        "env_local_scale": [ensure_term_id, remove_type_field],
        "env_medium": [ensure_term_id, remove_type_field],
        # depends on `dict`s being ordered in python 3.8+
        "gold_biosample_identifiers": [uppercase_curie_prefixes],
        "depth2": [ensure_depth_via_depth2],
        "lat_lon": [remove_type_field],
        "elev": [ensure_number_in_meters],
        "insdc_biosample_identifiers": [lowercase_curie_prefixes],
    },
    "study_set": {
        "GOLD_study_identifiers": "gold_study_identifiers",
        "gold_study_identifiers": [ensure_curies, uppercase_curie_prefixes],
    },
    "omics_processing_set": {
        "GOLD_sequencing_project_identifiers": "gold_sequencing_project_identifiers",
        "gold_sequencing_project_identifiers": [
            ensure_gold_sequencing_project_identifiers,
            uppercase_curie_prefixes,
        ],
    },
    "mags_activity_set": {
        "mags_list": [rename_num_tRNA],
        "lowDepth_contig_num": "low_depth_contig_num",
    },
    "metagenome_assembly_set": {
        "ctg_L50": "ctg_l50",
        "ctg_L90": "ctg_l90",
        "ctg_N50": "ctg_n50",
        "ctg_N90": "ctg_n90",
        "scaf_L50": "scaf_l50",
        "scaf_L90": "scaf_l90",
        "scaf_N50": "scaf_n50",
        "scaf_N90": "scaf_n90",
        "scaf_l_gt50K": "scaf_l_gt50k",
        "scaf_n_gt50K": "scaf_n_gt50k",
        "scaf_pct_gt50K": "scaf_pct_gt50k",
    },
    # "read_qc_analysis_activity_set": {
    #     "output_read_bases": "output_base_count",
    #     "input_read_bases": "input_base_count",
    # },
}

biosample_id_routing = {
    "emsl": "emsl_biosample_identifiers",
    "gold": "gold_biosample_identifiers",
    "igsn": "igsn_biosample_identifiers",
    "img.taxon": "img_identifiers"
}


def change_fieldname(d, fieldname, replacement):
    return dissoc(assoc(d, replacement, d[fieldname]), fieldname)


def replace_fields(d, context):
    assert "collection_name" in context
    for fieldname, replacement in fieldname_replacements[context["collection_name"]].items():
        if fieldname in d:
            if isinstance(replacement, list):
                assert all(callable(r) for r in replacement), "replacement-list must be all functions"
                for rfun in replacement:
                    n_params = len(signature(rfun).parameters)
                    if n_params == 1:
                        d = assoc(d, fieldname, rfun(d[fieldname]))
                    elif n_params == 2:
                        mapping_updates = rfun(d[fieldname], d)
                        for k, v in mapping_updates.items():
                            d = dissoc(d, k) if v is None else assoc(d, k, v)
                    else:
                        raise Exception("replaced fn takes too many parameters")
            else:
                d = change_fieldname(d, fieldname, replacement)
    return d


def iter_validate(mdb=None, collection_name=None, limit=0, xform=None):
    print(f"validating {collection_name}...")
    validated = []
    for d in mdb_src[collection_name].find(limit=limit):
        d = strip_oid(d)
        if xform:
            d = xform(d, {"collection_name": collection_name})
        try:
            _ = nmdc_jsonschema_validate({collection_name: [d]})
        except fastjsonschema.JsonSchemaException as e:
            print(d["id"])
            print(e)
            #pprint(d)
            #raise e
            return None
        validated.append(d)
    return validated

# %% [markdown]
# # replacements

# %%
from pymongo.operations import InsertOne

collections = present_src_collections(mdb_src)

tic = time.time()

write_ops = []

for coll_name in collections:
    if coll_name in fieldname_replacements:
        validated = iter_validate(mdb_src, coll_name, xform=replace_fields)
    else:
        validated = iter_validate(mdb_src, coll_name, xform=None)
    if validated is not None:
        mdb_tgt[coll_name].drop()
        result = mdb_tgt[coll_name].bulk_write([InsertOne(d) for d in validated])
        print(f"inserted {result.inserted_count} docs")

print(f"Took approx. {time.time() - tic} seconds")
# Out:
# validating biosample_set...
# inserted 753 docs
# validating data_object_set...
# inserted 40858 docs
# validating mags_activity_set...
# inserted 761 docs
# validating metabolomics_analysis_activity_set...
# inserted 209 docs
# validating metagenome_annotation_activity_set...
# inserted 818 docs
# validating metagenome_assembly_set...
# inserted 1056 docs
# validating metaproteomics_analysis_activity_set...
# inserted 52 docs
# validating metatranscriptome_activity_set...
# inserted 55 docs
# validating nom_analysis_activity_set...
# inserted 838 docs
# validating omics_processing_set...
# inserted 1927 docs
# validating read_qc_analysis_activity_set...
# inserted 1058 docs
# validating study_set...
# inserted 9 docs
# Took approx. 296.2571940422058 seconds

# %% [markdown]
# ## mongodump and mongorestore

# %%
from datetime import datetime, timezone
from pathlib import Path
import time

collections = present_src_collections(mdb_src)

today = datetime.now(timezone.utc).strftime("%Y-%m-%d")
print(f"ensuring ~/nmdcdb-mongodump/{today} directory for exports")
today_dir = Path("~/nmdcdb-mongodump").expanduser().joinpath(today)
os.makedirs(str(today_dir), exist_ok=True)

collections_excluded = set(mdb_tgt.list_collection_names()) - set(collections)

collections_excluded_str = " ".join(
    ["--excludeCollection=" + c for c in collections_excluded]
)
# Out:
# ensuring ~/nmdcdb-mongodump/2023-03-01 directory for exports

# %%
tic = time.time()

# !mongodump --host {os.getenv("MONGO_HOST")} \
     -u {os.getenv("MONGO_USERNAME")} \
     -p {os.getenv("MONGO_PASSWORD")} \
     --authenticationDatabase admin \
     -d {os.getenv("MONGO_DBNAME") + "-next"} \
     {collections_excluded_str} \
     -o {today_dir}

print(f"Took approx. {time.time() - tic} seconds")
# Out:
# 2023-03-01T16:54:10.331-0500	writing nmdc-next.omics_processing_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc-next/omics_processing_set.bson
# 2023-03-01T16:54:10.622-0500	writing nmdc-next.read_qc_analysis_activity_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc-next/read_qc_analysis_activity_set.bson
# 2023-03-01T16:54:10.701-0500	writing nmdc-next.data_object_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc-next/data_object_set.bson
# 2023-03-01T16:54:11.300-0500	writing nmdc-next.metagenome_assembly_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc-next/metagenome_assembly_set.bson
# 2023-03-01T16:54:12.192-0500	[........................]           nmdc-next.omics_processing_set  0/1927  (0.0%)
# 2023-03-01T16:54:12.193-0500	[........................]  nmdc-next.read_qc_analysis_activity_set  0/1058  (0.0%)
# 2023-03-01T16:54:12.193-0500
# 2023-03-01T16:54:15.192-0500	[#.......................]           nmdc-next.omics_processing_set   101/1927  (5.2%)
# 2023-03-01T16:54:15.192-0500	[##......................]  nmdc-next.read_qc_analysis_activity_set   101/1058  (9.5%)
# 2023-03-01T16:54:15.192-0500	[........................]                nmdc-next.data_object_set  101/40858  (0.2%)
# 2023-03-01T16:54:15.192-0500	[........................]        nmdc-next.metagenome_assembly_set     0/1056  (0.0%)
# 2023-03-01T16:54:15.192-0500
# 2023-03-01T16:54:16.145-0500	[########################]  nmdc-next.omics_processing_set  1927/1927  (100.0%)
# 2023-03-01T16:54:16.146-0500	done dumping nmdc-next.omics_processing_set (1927 documents)
# 2023-03-01T16:54:17.159-0500	[########################]  nmdc-next.read_qc_analysis_activity_set  1058/1058  (100.0%)
# 2023-03-01T16:54:17.160-0500	done dumping nmdc-next.read_qc_analysis_activity_set (1058 documents)
# 2023-03-01T16:54:18.192-0500	[........................]          nmdc-next.data_object_set  101/40858  (0.2%)
# 2023-03-01T16:54:18.192-0500	[##......................]  nmdc-next.metagenome_assembly_set   101/1056  (9.6%)
# 2023-03-01T16:54:18.192-0500
# 2023-03-01T16:54:19.015-0500	writing nmdc-next.nom_analysis_activity_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc-next/nom_analysis_activity_set.bson
# 2023-03-01T16:54:19.649-0500	writing nmdc-next.metagenome_annotation_activity_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc-next/metagenome_annotation_activity_set.bson
# 2023-03-01T16:54:19.654-0500	[########################]  nmdc-next.metagenome_assembly_set  1056/1056  (100.0%)
# 2023-03-01T16:54:19.654-0500	done dumping nmdc-next.metagenome_assembly_set (1056 documents)
# 2023-03-01T16:54:21.192-0500	[........................]            nmdc-next.data_object_set  101/40858  (0.2%)
# 2023-03-01T16:54:21.192-0500	[........................]  nmdc-next.nom_analysis_activity_set      0/838  (0.0%)
# 2023-03-01T16:54:21.192-0500
# 2023-03-01T16:54:23.394-0500	writing nmdc-next.mags_activity_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc-next/mags_activity_set.bson
# 2023-03-01T16:54:23.569-0500	[########################]  nmdc-next.data_object_set  40858/40858  (100.0%)
# 2023-03-01T16:54:23.569-0500	done dumping nmdc-next.data_object_set (40858 documents)
# 2023-03-01T16:54:23.732-0500	writing nmdc-next.biosample_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc-next/biosample_set.bson
# 2023-03-01T16:54:23.742-0500	[########################]  nmdc-next.nom_analysis_activity_set  838/838  (100.0%)
# 2023-03-01T16:54:23.742-0500	done dumping nmdc-next.nom_analysis_activity_set (838 documents)
# 2023-03-01T16:54:24.192-0500	[##......................]  nmdc-next.metagenome_annotation_activity_set  101/818  (12.3%)
# 2023-03-01T16:54:24.192-0500	[###.....................]                   nmdc-next.mags_activity_set  101/761  (13.3%)
# 2023-03-01T16:54:24.192-0500
# 2023-03-01T16:54:24.262-0500	writing nmdc-next.metabolomics_analysis_activity_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc-next/metabolomics_analysis_activity_set.bson
# 2023-03-01T16:54:24.265-0500	[########################]  nmdc-next.metagenome_annotation_activity_set  818/818  (100.0%)
# 2023-03-01T16:54:24.265-0500	done dumping nmdc-next.metagenome_annotation_activity_set (818 documents)
# 2023-03-01T16:54:24.535-0500	writing nmdc-next.metatranscriptome_activity_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc-next/metatranscriptome_activity_set.bson
# 2023-03-01T16:54:24.790-0500	[########################]  nmdc-next.mags_activity_set  761/761  (100.0%)
# 2023-03-01T16:54:24.790-0500	done dumping nmdc-next.mags_activity_set (761 documents)
# 2023-03-01T16:54:25.057-0500	done dumping nmdc-next.biosample_set (753 documents)
# 2023-03-01T16:54:25.089-0500	done dumping nmdc-next.metatranscriptome_activity_set (55 documents)
# 2023-03-01T16:54:25.306-0500	writing nmdc-next.metaproteomics_analysis_activity_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc-next/metaproteomics_analysis_activity_set.bson
# 2023-03-01T16:54:25.487-0500	writing nmdc-next.study_set to /Users/dwinston/nmdcdb-mongodump/2023-03-01/nmdc-next/study_set.bson
# 2023-03-01T16:54:26.062-0500	done dumping nmdc-next.study_set (9 documents)
# 2023-03-01T16:54:27.192-0500	[###########.............]    nmdc-next.metabolomics_analysis_activity_set  101/209  (48.3%)
# 2023-03-01T16:54:27.192-0500	[........................]  nmdc-next.metaproteomics_analysis_activity_set     0/52   (0.0%)
# 2023-03-01T16:54:27.192-0500
# 2023-03-01T16:54:27.697-0500	[########################]  nmdc-next.metabolomics_analysis_activity_set  209/209  (100.0%)
# 2023-03-01T16:54:27.697-0500	done dumping nmdc-next.metabolomics_analysis_activity_set (209 documents)
# 2023-03-01T16:54:30.192-0500	[######..................]  nmdc-next.metaproteomics_analysis_activity_set  15/52  (28.8%)
# 2023-03-01T16:54:33.192-0500	[######..................]  nmdc-next.metaproteomics_analysis_activity_set  15/52  (28.8%)
# 2023-03-01T16:54:36.192-0500	[############............]  nmdc-next.metaproteomics_analysis_activity_set  26/52  (50.0%)
# 2023-03-01T16:54:39.204-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set  30/52  (57.7%)
# 2023-03-01T16:54:42.191-0500	[################........]  nmdc-next.metaproteomics_analysis_activity_set  35/52  (67.3%)
# 2023-03-01T16:54:45.192-0500	[##################......]  nmdc-next.metaproteomics_analysis_activity_set  40/52  (76.9%)
# 2023-03-01T16:54:48.191-0500	[####################....]  nmdc-next.metaproteomics_analysis_activity_set  45/52  (86.5%)
# 2023-03-01T16:54:51.191-0500	[#####################...]  nmdc-next.metaproteomics_analysis_activity_set  47/52  (90.4%)
# 2023-03-01T16:54:54.191-0500	[######################..]  nmdc-next.metaproteomics_analysis_activity_set  48/52  (92.3%)
# 2023-03-01T16:54:57.191-0500	[######################..]  nmdc-next.metaproteomics_analysis_activity_set  49/52  (94.2%)
# 2023-03-01T16:55:00.191-0500	[#######################.]  nmdc-next.metaproteomics_analysis_activity_set  50/52  (96.2%)
# 2023-03-01T16:55:03.191-0500	[#######################.]  nmdc-next.metaproteomics_analysis_activity_set  51/52  (98.1%)
# 2023-03-01T16:55:03.753-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  52/52  (100.0%)
# 2023-03-01T16:55:03.754-0500	done dumping nmdc-next.metaproteomics_analysis_activity_set (52 documents)
# Took approx. 57.77128005027771 seconds

# %%
tic = time.time()

# !mongorestore --host {os.getenv("MONGO_HOST")} \
     -u {os.getenv("MONGO_USERNAME")} \
     -p {os.getenv("MONGO_PASSWORD")} \
     --authenticationDatabase admin \
     -d {os.getenv("MONGO_DBNAME") + "-next"} \
     --drop \
     --quiet \   
     {today_dir / os.getenv("MONGO_DBNAME")}

print(f"Took approx. {time.time() - tic} seconds")
