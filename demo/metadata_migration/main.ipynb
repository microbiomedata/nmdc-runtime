# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

from dotenv import load_dotenv
from pymongo import MongoClient
from pymongo.errors import OperationFailure

load_dotenv("../../.env.localhost")

admin_client = MongoClient(
    host=os.getenv("MONGO_HOST"),
    username=os.getenv("MONGO_USERNAME"),
    password=os.getenv("MONGO_PASSWORD"),
    directConnection=True, # connect to host as a standalone, rather than to entire replicaset
)
reader_client = MongoClient(
    host=os.getenv("MONGO_HOST"),
    username=os.getenv("MONGO_READONLY_USERNAME"),
    password=os.getenv("MONGO_READONLY_PASSWORD"),
    directConnection=True, # connect to host as a standalone, rather than to entire replicaset
)

mdb_src = reader_client[os.getenv("MONGO_DBNAME")]
mdb_tgt = admin_client[os.getenv("MONGO_DBNAME") + "-next"]


try:
    mdb_src.study_set.insert_one({"_id": "foobar"})
    print("NOT OK")
    mdb_src.study_set.delete_one({"_id": "foobar"})
    print("state restored")
    raise Exception("can write to `mdb_src`!")
except OperationFailure:
    pass

# %% [markdown]
# No output from above? Good!

# %%
"""Utils"""

from copy import deepcopy
import pkg_resources
from pprint import pprint

import fastjsonschema
from toolz import dissoc

def strip_oid(doc):
    return dissoc(doc, "_id")

def nmdc_schema_collection_names() -> set:
    return {
        k for k, v in get_nmdc_jsonschema_dict()["$defs"]["Database"]["properties"].items()
        if v.get("items",{}).get("$ref")
    }

def present_src_collections(mdb) -> list:
    return sorted(
        n for n in (nmdc_schema_collection_names() & set(mdb_src.list_collection_names()))
        if mdb_src[n].estimated_document_count()
    )

# %%
"""Monkey-patch schema in light of expected metadata/schema modifications."""

from nmdc_runtime.util import get_nmdc_jsonschema_dict

def without_id_patterns(nmdc_jsonschema):
    rv = deepcopy(nmdc_jsonschema)
    for cls_, spec in rv["$defs"].items():
        if "properties" in spec:
            if "id" in spec["properties"]:
                spec["properties"]["id"].pop("pattern", None)
    return rv


SCHEMA_DEFS_PATCHES = {
    "MetabolomicsAnalysisActivity": {
        "has_calibration": {
               "description": "TODO: Yuri to fill in",
               "type": "string"
        },
        "has_metabolite_quantifications": {
               "items": {
                  "$ref": "#/$defs/MetaboliteQuantification"
               },
               "type": "array"
        }
    },
    "MetaboliteQuantification": {
        "alternative_identifiers": {
           "description": "A list of alternative identifiers for the entity.",
           "items": {
              "type": "string"
           },
           "type": "array"
        },
        "highest_similarity_score": {
           "description": "TODO: Yuri to fill in",
           "type": "number"
        },
        "metabolite_quantified": {
           "description": "the specific metabolite identifier",
           "type": "string"
        }
    },
    "MetaproteomicsAnalysisActivity": {
        "has_peptide_quantifications": {
           "items": {
              "$ref": "#/$defs/PeptideQuantification"
           },
           "type": "array"
        }
    },
    "PeptideQuantification": {
        "all_proteins": {
           "description": "the list of protein identifiers that are associated with the peptide sequence",
           "items": {
              "type": "string"
           },
           "type": "array"
        },
        "best_protein": {
           "description": "the specific protein identifier most correctly associated with the peptide sequence",
           "type": "string"
        },
        "min_q_value": {
           "description": "smallest Q-Value associated with the peptide sequence as provided by MSGFPlus tool",
           "type": "number"
        },
        "peptide_sequence": {
           "type": "string"
        },
        "peptide_spectral_count": {
           "description": "sum of filter passing MS2 spectra associated with the peptide sequence within a given LC-MS/MS data file",
           "type": "integer"
        },
        "peptide_sum_masic_abundance": {
           "description": "combined MS1 extracted ion chromatograms derived from MS2 spectra associated with the peptide sequence from a given LC-MS/MS data file using the MASIC tool",
           "type": "integer"
        }
    },
    "NomAnalysisActivity": {
        "has_calibration": {
           "description": "A reference to a file that holds calibration information.",
           "type": "string"
        }
    },
}


def patch_schema_defs(nmdc_jsonschema, patches=SCHEMA_DEFS_PATCHES):
    rv = deepcopy(nmdc_jsonschema)
    defs = rv["$defs"]
    for cls_, spec in patches.items():
        if cls_ not in defs:
            raise Exception(f"Class not present, so cannot patch: {cls_}")
        elif "properties" not in defs[cls_]:
            defs[cls_]["properties"] = spec
        else:
            for k, v in spec.items():
                defs[cls_]["properties"][k] = v
    return rv

print(pkg_resources.get_distribution("nmdc_schema").version)

nmdc_jsonschema_validate = fastjsonschema.compile(
    patch_schema_defs(without_id_patterns(get_nmdc_jsonschema_dict()))
)
# Out:
# 7.4.10

# %% [markdown]
# Reference for anticipated migration logic/config: https://github.com/microbiomedata/nmdc-schema/blob/v7.4.10/nmdc_schema/migrate_3_2_to_7.py

# %%
from inspect import signature
import re

from toolz import assoc, assoc_in, dissoc


id_pattern = re.compile(r"(PO|ENVO):\d+")
curie_pattern = re.compile(r"[A-Za-z]\w+:\w+")


def ensure_term_id(v):
    if not ("term" in v or "has_raw_value" in v):
        raise Exception(f"needs `term` or `has_raw_value`")
    if not (m := re.search(id_pattern, v["has_raw_value"])):
        raise Exception(f'{v["has_raw_value"]} does not match a known ID pattern')
    
    return assoc(v, "term", {"id": v["has_raw_value"]})


def uppercase_curie_prefixes(v):
    if not isinstance(v, list):
        raise Exception("list expected")
    if not all(":" in elt for elt in v):
        raise Exception("CURIEs expected")
    
    rv = []
    for elt in v:
        prefix, localpart = elt.split(":", maxsplit=1)
        rv.append(prefix.upper() + ":" + localpart)
    return rv

def lowercase_curie_prefixes(v):
    if not isinstance(v, list):
        raise Exception("list expected")
    if not all(":" in elt for elt in v):
        raise Exception("CURIEs expected")
    
    rv = []
    for elt in v:
        prefix, localpart = elt.split(":", maxsplit=1)
        rv.append(prefix.lower() + ":" + localpart)
    return rv

def ensure_curies(v):
    """
    >>> ensure_curies(['HTTPS://identifiers.org/gold:Gs0144557'])
    ['gold:Gs0144557']
    """
    if not isinstance(v, list):
        raise Exception("list expected")
    if not all(":" in elt for elt in v):
        raise Exception("CURIE-ables expected")

    return [re.search(curie_pattern, elt).group(0) for elt in v]

def ensure_depth_via_depth2(v, d):
    if "depth" not in d:
        raise Exception("no `depth` field")
    
    depth = d["depth"]
    return {"depth": depth, "depth2": None}
#     depth = d["depth"]
#     if v['has_unit'] != depth['has_unit']:
#         raise Exception("disagreement wrt units")
#     if 'has_numeric_value' not in v:
#         return {"depth
    
    
#     if 'has_maximum_numeric_value' in v:
#         if v['has_maximum_numeric_value'] != depth2['has_numeric_value']:
#             raise Exception("disagreement wrt maximum value")
#     else:
#         v = assoc(v, "has_maximum_numeric_value", depth2["has_numeric_value"])
#         if 'has_minimum_numeric_value' not in v:
#             # sets missing min value as given numeric value
#             v = assoc(v, "has_minimum_numeric_value", v["has_numeric_value"])
#         else:
#             if v["has_numeric_value"] != v["has_minimum_numeric_value"]:
#                 # XXX Is this really a problem?
#                 raise Exception("min value not the same as numeric value")


def remove_type_field(v):
    return dissoc(v, "type")


def ensure_number_in_meters(v):
    if isinstance(v, dict):
        assert "has_unit" in v, "no units"
        assert v["has_unit"] in ("meter", "metre"), "not meters"
        return v["has_numeric_value"]
    assert isinstance(v, int | float), "not a number"
    return v

def ensure_gold_sequencing_project_identifiers(v, d):
    if not isinstance(v, list):
        raise Exception("list expected")
    if "gold_sequencing_project_identifiers" not in d:
        return v

    rv = []
    for elt in v:
        if elt.lower().startswith("gold:gb"):
            if d["id"].lower().startswith("gold:gp"):
                rv.append(d["id"])
            else:
                raise Exception("no avaialable substitute")
        else:
            rv.append(elt)
    return {"gold_sequencing_project_identifiers": rv}


def rename_num_tRNA(v):
    return [
        change_fieldname(elt, "num_tRNA", "num_t_rna")
        for elt in v if "num_tRNA" in elt
    ]


fieldname_replacements = {
    "biosample_set": {
        "INSDC_biosample_identifiers": "insdc_biosample_identifiers",
        # # "part_of": "sample_link",
        "identifier": "samp_name",
        "GOLD_sample_identifiers": "gold_biosample_identifiers",
        "env_broad_scale": [ensure_term_id, remove_type_field],
        "env_local_scale": [ensure_term_id, remove_type_field],
        "env_medium": [ensure_term_id, remove_type_field],
        # depends on `dict`s being ordered in python 3.8+
        "gold_biosample_identifiers": [uppercase_curie_prefixes],
        "depth2": [ensure_depth_via_depth2],
        "lat_lon": [remove_type_field],
        "elev": [ensure_number_in_meters],
        "insdc_biosample_identifiers": [lowercase_curie_prefixes],
    },
    "study_set": {
        "GOLD_study_identifiers": "gold_study_identifiers",
        "gold_study_identifiers": [ensure_curies, uppercase_curie_prefixes],
    },
    "omics_processing_set": {
        "GOLD_sequencing_project_identifiers": "gold_sequencing_project_identifiers",
        "gold_sequencing_project_identifiers": [
            ensure_gold_sequencing_project_identifiers,
            uppercase_curie_prefixes,
        ],
    },
    "mags_activity_set": {
        "mags_list": [rename_num_tRNA],
        "lowDepth_contig_num": "low_depth_contig_num",
    },
    "metagenome_assembly_set": {
        "ctg_L50": "ctg_l50",
        "ctg_L90": "ctg_l90",
        "ctg_N50": "ctg_n50",
        "ctg_N90": "ctg_n90",
        "scaf_L50": "scaf_l50",
        "scaf_L90": "scaf_l90",
        "scaf_N50": "scaf_n50",
        "scaf_N90": "scaf_n90",
        "scaf_l_gt50K": "scaf_l_gt50k",
        "scaf_n_gt50K": "scaf_n_gt50k",
        "scaf_pct_gt50K": "scaf_pct_gt50k",
    },
    "read_qc_analysis_activity_set": {
        "output_read_bases": "output_base_count",
        "input_read_bases": "input_base_count",
    },
}

biosample_id_routing = {
    "emsl": "emsl_biosample_identifiers",
    "gold": "gold_biosample_identifiers",
    "igsn": "igsn_biosample_identifiers",
    "img.taxon": "img_identifiers"
}


def change_fieldname(d, fieldname, replacement):
    return dissoc(assoc(d, replacement, d[fieldname]), fieldname)


def replace_fields(d, context):
    assert "collection_name" in context
    for fieldname, replacement in fieldname_replacements[context["collection_name"]].items():
        if fieldname in d:
            if isinstance(replacement, list):
                assert all(callable(r) for r in replacement), "replacement-list must be all functions"
                for rfun in replacement:
                    n_params = len(signature(rfun).parameters)
                    if n_params == 1:
                        d = assoc(d, fieldname, rfun(d[fieldname]))
                    elif n_params == 2:
                        mapping_updates = rfun(d[fieldname], d)
                        for k, v in mapping_updates.items():
                            d = dissoc(d, k) if v is None else assoc(d, k, v)
                    else:
                        raise Exception("replaced fn takes too many parameters")
            else:
                d = change_fieldname(d, fieldname, replacement)
    return d


def iter_validate(mdb=None, collection_name=None, limit=0, xform=None):
    print(f"validating {collection_name}...")
    for d in mdb_src[collection_name].find(limit=limit):
        d = strip_oid(d)
        if xform:
            d = xform(d, {"collection_name": collection_name})
        try:
            _ = nmdc_jsonschema_validate({collection_name: [d]})
        except fastjsonschema.JsonSchemaException as e:
            print(d["id"])
            print(e)
            #pprint(d)
            #raise e
            return

# %% [markdown]
# # replacements

# %%
collections = present_src_collections(mdb_src)
print(collections)

for coll_name in collections:
    if coll_name in fieldname_replacements:
        iter_validate(mdb_src, coll_name, xform=replace_fields)
    else:
        iter_validate(mdb_src, coll_name, xform=None)
# Out:
# ['biosample_set', 'data_object_set', 'mags_activity_set', 'metabolomics_analysis_activity_set', 'metagenome_annotation_activity_set', 'metagenome_assembly_set', 'metaproteomics_analysis_activity_set', 'metatranscriptome_activity_set', 'nom_analysis_activity_set', 'omics_processing_set', 'read_qc_analysis_activity_set', 'study_set']
# validating biosample_set...
# validating data_object_set...
# validating mags_activity_set...
# validating metabolomics_analysis_activity_set...
# validating metagenome_annotation_activity_set...
# validating metagenome_assembly_set...
# validating metaproteomics_analysis_activity_set...
# validating metatranscriptome_activity_set...
# validating nom_analysis_activity_set...
# validating omics_processing_set...
# validating read_qc_analysis_activity_set...
# validating study_set...

# %% [markdown]
# ## mongodump and mongorestore

# %%
from datetime import datetime, timezone
from pathlib import Path
import time

today = datetime.now(timezone.utc).strftime("%Y-%m-%d")
print(f"ensuring ~/nmdcdb-mongodump/{today} directory for exports")
today_dir = Path("~/nmdcdb-mongodump").expanduser().joinpath(today)
os.makedirs(str(today_dir), exist_ok=True)

collections_excluded = set(mdb_src.list_collection_names()) - set(collections)
collections_excluded_str = " ".join(
    ["--excludeCollection=" + c for c in collections_excluded]
)
# Out:
# ensuring ~/nmdcdb-mongodump/2023-02-27 directory for exports

# %%
tic = time.time()

# !mongodump --host {os.getenv("MONGO_HOST")} \
     -u {os.getenv("MONGO_READONLY_USERNAME")} \
     -p {os.getenv("MONGO_READONLY_PASSWORD")} \
     --authenticationDatabase admin \
     -d {os.getenv("MONGO_DBNAME")} \
     {collections_excluded_str} \
     -o {today_dir}

print(f"Took approx. {time.time() - tic} seconds")
# Out:
# 2023-02-27T09:33:25.702-0500	writing nmdc.omics_processing_set to /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/omics_processing_set.bson
# 2023-02-27T09:33:25.777-0500	writing nmdc.read_qc_analysis_activity_set to /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/read_qc_analysis_activity_set.bson
# 2023-02-27T09:33:25.856-0500	writing nmdc.metagenome_assembly_set to /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/metagenome_assembly_set.bson
# 2023-02-27T09:33:26.952-0500	writing nmdc.data_object_set to /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/data_object_set.bson
# 2023-02-27T09:33:27.406-0500	[........................]           nmdc.omics_processing_set  0/1927  (0.0%)
# 2023-02-27T09:33:27.406-0500	[........................]  nmdc.read_qc_analysis_activity_set  0/1058  (0.0%)
# 2023-02-27T09:33:27.406-0500
# 2023-02-27T09:33:30.407-0500	[#.......................]           nmdc.omics_processing_set   101/1927  (5.2%)
# 2023-02-27T09:33:30.407-0500	[##......................]  nmdc.read_qc_analysis_activity_set   101/1058  (9.5%)
# 2023-02-27T09:33:30.407-0500	[##......................]        nmdc.metagenome_assembly_set   101/1056  (9.6%)
# 2023-02-27T09:33:30.407-0500	[........................]                nmdc.data_object_set  101/40858  (0.2%)
# 2023-02-27T09:33:30.407-0500
# 2023-02-27T09:33:31.921-0500	[########################]  nmdc.read_qc_analysis_activity_set  1058/1058  (100.0%)
# 2023-02-27T09:33:31.922-0500	done dumping nmdc.read_qc_analysis_activity_set (1058 documents)
# 2023-02-27T09:33:32.575-0500	[########################]  nmdc.omics_processing_set  1927/1927  (100.0%)
# 2023-02-27T09:33:32.576-0500	done dumping nmdc.omics_processing_set (1927 documents)
# 2023-02-27T09:33:33.406-0500	[##......................]  nmdc.metagenome_assembly_set   101/1056  (9.6%)
# 2023-02-27T09:33:33.406-0500	[........................]          nmdc.data_object_set  101/40858  (0.2%)
# 2023-02-27T09:33:33.406-0500
# 2023-02-27T09:33:33.585-0500	[########################]  nmdc.metagenome_assembly_set  1056/1056  (100.0%)
# 2023-02-27T09:33:33.585-0500	done dumping nmdc.metagenome_assembly_set (1056 documents)
# 2023-02-27T09:33:34.815-0500	writing nmdc.metagenome_annotation_activity_set to /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/metagenome_annotation_activity_set.bson
# 2023-02-27T09:33:34.816-0500	writing nmdc.mags_activity_set to /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/mags_activity_set.bson
# 2023-02-27T09:33:34.816-0500	writing nmdc.nom_analysis_activity_set to /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/nom_analysis_activity_set.bson
# 2023-02-27T09:33:36.407-0500	[........................]  nmdc.data_object_set  101/40858  (0.2%)
# 2023-02-27T09:33:39.406-0500	[........................]                     nmdc.data_object_set  101/40858  (0.2%)
# 2023-02-27T09:33:39.406-0500	[........................]           nmdc.nom_analysis_activity_set      0/838  (0.0%)
# 2023-02-27T09:33:39.406-0500	[........................]  nmdc.metagenome_annotation_activity_set      0/818  (0.0%)
# 2023-02-27T09:33:39.406-0500
# 2023-02-27T09:33:39.999-0500	[########################]  nmdc.data_object_set  40858/40858  (100.0%)
# 2023-02-27T09:33:39.999-0500	done dumping nmdc.data_object_set (40858 documents)
# 2023-02-27T09:33:40.915-0500	writing nmdc.biosample_set to /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/biosample_set.bson
# 2023-02-27T09:33:41.026-0500	[########################]  nmdc.nom_analysis_activity_set  838/838  (100.0%)
# 2023-02-27T09:33:41.026-0500	done dumping nmdc.nom_analysis_activity_set (838 documents)
# 2023-02-27T09:33:41.469-0500	[########################]  nmdc.metagenome_annotation_activity_set  818/818  (100.0%)
# 2023-02-27T09:33:41.469-0500	done dumping nmdc.metagenome_annotation_activity_set (818 documents)
# 2023-02-27T09:33:42.113-0500	writing nmdc.metabolomics_analysis_activity_set to /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/metabolomics_analysis_activity_set.bson
# 2023-02-27T09:33:42.299-0500	writing nmdc.metatranscriptome_activity_set to /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/metatranscriptome_activity_set.bson
# 2023-02-27T09:33:42.406-0500	[###.....................]  nmdc.mags_activity_set  101/761  (13.3%)
# 2023-02-27T09:33:42.406-0500	[###.....................]      nmdc.biosample_set  101/753  (13.4%)
# 2023-02-27T09:33:42.406-0500
# 2023-02-27T09:33:42.521-0500	[########################]  nmdc.mags_activity_set  761/761  (100.0%)
# 2023-02-27T09:33:42.521-0500	done dumping nmdc.mags_activity_set (761 documents)
# 2023-02-27T09:33:42.674-0500	[########################]  nmdc.biosample_set  753/753  (100.0%)
# 2023-02-27T09:33:42.674-0500	done dumping nmdc.biosample_set (753 documents)
# 2023-02-27T09:33:43.102-0500	writing nmdc.metaproteomics_analysis_activity_set to /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/metaproteomics_analysis_activity_set.bson
# 2023-02-27T09:33:43.455-0500	writing nmdc.study_set to /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/study_set.bson
# 2023-02-27T09:33:43.455-0500	done dumping nmdc.metatranscriptome_activity_set (55 documents)
# 2023-02-27T09:33:44.763-0500	done dumping nmdc.study_set (9 documents)
# 2023-02-27T09:33:45.406-0500	[........................]    nmdc.metabolomics_analysis_activity_set  0/209  (0.0%)
# 2023-02-27T09:33:45.406-0500	[........................]  nmdc.metaproteomics_analysis_activity_set   0/52  (0.0%)
# 2023-02-27T09:33:45.406-0500
# 2023-02-27T09:33:48.406-0500	[###########.............]    nmdc.metabolomics_analysis_activity_set  101/209  (48.3%)
# 2023-02-27T09:33:48.406-0500	[........................]  nmdc.metaproteomics_analysis_activity_set     0/52   (0.0%)
# 2023-02-27T09:33:48.406-0500
# 2023-02-27T09:33:48.707-0500	[########################]  nmdc.metabolomics_analysis_activity_set  209/209  (100.0%)
# 2023-02-27T09:33:48.707-0500	done dumping nmdc.metabolomics_analysis_activity_set (209 documents)
# 2023-02-27T09:33:51.406-0500	[#########...............]  nmdc.metaproteomics_analysis_activity_set  21/52  (40.4%)
# 2023-02-27T09:33:54.406-0500	[#############...........]  nmdc.metaproteomics_analysis_activity_set  30/52  (57.7%)
# 2023-02-27T09:33:57.407-0500	[##################......]  nmdc.metaproteomics_analysis_activity_set  40/52  (76.9%)
# 2023-02-27T09:34:00.406-0500	[####################....]  nmdc.metaproteomics_analysis_activity_set  45/52  (86.5%)
# 2023-02-27T09:34:03.407-0500	[#####################...]  nmdc.metaproteomics_analysis_activity_set  47/52  (90.4%)
# 2023-02-27T09:34:06.407-0500	[######################..]  nmdc.metaproteomics_analysis_activity_set  49/52  (94.2%)
# 2023-02-27T09:34:09.407-0500	[#######################.]  nmdc.metaproteomics_analysis_activity_set  50/52  (96.2%)
# 2023-02-27T09:34:10.932-0500	[########################]  nmdc.metaproteomics_analysis_activity_set  52/52  (100.0%)
# 2023-02-27T09:34:10.932-0500	done dumping nmdc.metaproteomics_analysis_activity_set (52 documents)
# Took approx. 49.72788977622986 seconds

# %%
tic = time.time()

# !mongorestore --host {os.getenv("MONGO_HOST")} \
     -u {os.getenv("MONGO_USERNAME")} \
     -p {os.getenv("MONGO_PASSWORD")} \
     --authenticationDatabase admin \
     -d {os.getenv("MONGO_DBNAME") + "-next"} \
     --drop \
     {today_dir / os.getenv("MONGO_DBNAME")}

print(f"Took approx. {time.time() - tic} seconds")
# Out:
# 2023-02-27T09:39:47.508-0500	The --db and --collection flags are deprecated for this use-case; please use --nsInclude instead, i.e. with --nsInclude=${DATABASE}.${COLLECTION}
# 2023-02-27T09:39:47.509-0500	building a list of collections to restore from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc dir
# 2023-02-27T09:39:47.510-0500	reading metadata for nmdc-next.metaproteomics_analysis_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/metaproteomics_analysis_activity_set.metadata.json
# 2023-02-27T09:39:47.510-0500	reading metadata for nmdc-next.metatranscriptome_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/metatranscriptome_activity_set.metadata.json
# 2023-02-27T09:39:47.510-0500	reading metadata for nmdc-next.omics_processing_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/omics_processing_set.metadata.json
# 2023-02-27T09:39:47.511-0500	reading metadata for nmdc-next.read_qc_analysis_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/read_qc_analysis_activity_set.metadata.json
# 2023-02-27T09:39:47.511-0500	reading metadata for nmdc-next.study_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/study_set.metadata.json
# 2023-02-27T09:39:47.511-0500	reading metadata for nmdc-next.mags_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/mags_activity_set.metadata.json
# 2023-02-27T09:39:47.511-0500	reading metadata for nmdc-next.metabolomics_analysis_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/metabolomics_analysis_activity_set.metadata.json
# 2023-02-27T09:39:47.511-0500	reading metadata for nmdc-next.metagenome_assembly_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/metagenome_assembly_set.metadata.json
# 2023-02-27T09:39:47.511-0500	reading metadata for nmdc-next.nom_analysis_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/nom_analysis_activity_set.metadata.json
# 2023-02-27T09:39:47.511-0500	reading metadata for nmdc-next.biosample_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/biosample_set.metadata.json
# 2023-02-27T09:39:47.511-0500	reading metadata for nmdc-next.data_object_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/data_object_set.metadata.json
# 2023-02-27T09:39:47.511-0500	reading metadata for nmdc-next.metagenome_annotation_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/metagenome_annotation_activity_set.metadata.json
# 2023-02-27T09:39:47.801-0500	dropping collection nmdc-next.metabolomics_analysis_activity_set before restoring
# 2023-02-27T09:39:47.801-0500	dropping collection nmdc-next.data_object_set before restoring
# 2023-02-27T09:39:47.801-0500	dropping collection nmdc-next.mags_activity_set before restoring
# 2023-02-27T09:39:47.999-0500	restoring nmdc-next.metaproteomics_analysis_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/metaproteomics_analysis_activity_set.bson
# 2023-02-27T09:39:48.193-0500	restoring nmdc-next.metabolomics_analysis_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/metabolomics_analysis_activity_set.bson
# 2023-02-27T09:39:48.194-0500	restoring nmdc-next.data_object_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/data_object_set.bson
# 2023-02-27T09:39:48.328-0500	restoring nmdc-next.mags_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/mags_activity_set.bson
# 2023-02-27T09:39:50.350-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-02-27T09:39:50.350-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-02-27T09:39:50.350-0500	[........................]                       nmdc-next.data_object_set   417KB/14.4MB    (2.8%)
# 2023-02-27T09:39:50.350-0500	[########################]                     nmdc-next.mags_activity_set  5.04MB/5.04MB  (100.0%)
# 2023-02-27T09:39:50.350-0500
# 2023-02-27T09:39:53.350-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-02-27T09:39:53.350-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-02-27T09:39:53.350-0500	[#.......................]                       nmdc-next.data_object_set   662KB/14.4MB    (4.5%)
# 2023-02-27T09:39:53.350-0500	[########################]                     nmdc-next.mags_activity_set  5.04MB/5.04MB  (100.0%)
# 2023-02-27T09:39:53.350-0500
# 2023-02-27T09:39:56.350-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-02-27T09:39:56.350-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-02-27T09:39:56.350-0500	[##......................]                       nmdc-next.data_object_set  1.26MB/14.4MB    (8.8%)
# 2023-02-27T09:39:56.350-0500	[########################]                     nmdc-next.mags_activity_set  5.04MB/5.04MB  (100.0%)
# 2023-02-27T09:39:56.350-0500
# 2023-02-27T09:39:59.349-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-02-27T09:39:59.349-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-02-27T09:39:59.349-0500	[###.....................]                       nmdc-next.data_object_set  1.97MB/14.4MB   (13.7%)
# 2023-02-27T09:39:59.349-0500	[########################]                     nmdc-next.mags_activity_set  5.04MB/5.04MB  (100.0%)
# 2023-02-27T09:39:59.349-0500
# 2023-02-27T09:40:02.350-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-02-27T09:40:02.350-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-02-27T09:40:02.350-0500	[####....................]                       nmdc-next.data_object_set  2.65MB/14.4MB   (18.4%)
# 2023-02-27T09:40:02.350-0500	[########################]                     nmdc-next.mags_activity_set  5.04MB/5.04MB  (100.0%)
# 2023-02-27T09:40:02.350-0500
# 2023-02-27T09:40:05.350-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-02-27T09:40:05.350-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-02-27T09:40:05.350-0500	[#####...................]                       nmdc-next.data_object_set  3.31MB/14.4MB   (23.0%)
# 2023-02-27T09:40:05.350-0500	[########################]                     nmdc-next.mags_activity_set  5.04MB/5.04MB  (100.0%)
# 2023-02-27T09:40:05.350-0500
# 2023-02-27T09:40:07.917-0500	[########################]  nmdc-next.mags_activity_set  5.04MB/5.04MB  (100.0%)
# 2023-02-27T09:40:07.917-0500	finished restoring nmdc-next.mags_activity_set (761 documents, 0 failures)
# 2023-02-27T09:40:08.250-0500	restoring nmdc-next.metagenome_assembly_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/metagenome_assembly_set.bson
# 2023-02-27T09:40:08.349-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-02-27T09:40:08.349-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-02-27T09:40:08.349-0500	[#######.................]                       nmdc-next.data_object_set  4.20MB/14.4MB   (29.2%)
# 2023-02-27T09:40:08.349-0500	[######################..]               nmdc-next.metagenome_assembly_set  1.06MB/1.11MB   (95.3%)
# 2023-02-27T09:40:08.349-0500
# 2023-02-27T09:40:11.350-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-02-27T09:40:11.350-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-02-27T09:40:11.350-0500	[########................]                       nmdc-next.data_object_set  4.93MB/14.4MB   (34.3%)
# 2023-02-27T09:40:11.350-0500	[######################..]               nmdc-next.metagenome_assembly_set  1.06MB/1.11MB   (95.3%)
# 2023-02-27T09:40:11.350-0500
# 2023-02-27T09:40:12.215-0500	[########################]  nmdc-next.metagenome_assembly_set  1.11MB/1.11MB  (100.0%)
# 2023-02-27T09:40:12.215-0500	finished restoring nmdc-next.metagenome_assembly_set (1056 documents, 0 failures)
# 2023-02-27T09:40:13.167-0500	restoring nmdc-next.omics_processing_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/omics_processing_set.bson
# 2023-02-27T09:40:14.350-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-02-27T09:40:14.350-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-02-27T09:40:14.350-0500	[#########...............]                       nmdc-next.data_object_set  5.68MB/14.4MB   (39.5%)
# 2023-02-27T09:40:14.350-0500	[##########..............]                  nmdc-next.omics_processing_set   489KB/1.05MB   (45.7%)
# 2023-02-27T09:40:14.351-0500
# 2023-02-27T09:40:16.506-0500	[########################]  nmdc-next.omics_processing_set  1.05MB/1.05MB  (100.0%)
# 2023-02-27T09:40:16.506-0500	finished restoring nmdc-next.omics_processing_set (1927 documents, 0 failures)
# 2023-02-27T09:40:16.905-0500	restoring nmdc-next.metagenome_annotation_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/metagenome_annotation_activity_set.bson
# 2023-02-27T09:40:17.350-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-02-27T09:40:17.351-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-02-27T09:40:17.351-0500	[##########..............]                       nmdc-next.data_object_set  6.42MB/14.4MB   (44.7%)
# 2023-02-27T09:40:17.351-0500	[########################]    nmdc-next.metagenome_annotation_activity_set  1.03MB/1.03MB  (100.0%)
# 2023-02-27T09:40:17.351-0500
# 2023-02-27T09:40:19.894-0500	[########################]  nmdc-next.metagenome_annotation_activity_set  1.03MB/1.03MB  (100.0%)
# 2023-02-27T09:40:19.894-0500	finished restoring nmdc-next.metagenome_annotation_activity_set (818 documents, 0 failures)
# 2023-02-27T09:40:19.894-0500	dropping collection nmdc-next.biosample_set before restoring
# 2023-02-27T09:40:20.350-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-02-27T09:40:20.350-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-02-27T09:40:20.350-0500	[############............]                       nmdc-next.data_object_set  7.56MB/14.4MB   (52.6%)
# 2023-02-27T09:40:20.350-0500
# 2023-02-27T09:40:20.599-0500	restoring nmdc-next.biosample_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/biosample_set.bson
# 2023-02-27T09:40:23.350-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-02-27T09:40:23.350-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-02-27T09:40:23.350-0500	[#############...........]                       nmdc-next.data_object_set  7.94MB/14.4MB   (55.3%)
# 2023-02-27T09:40:23.350-0500	[########################]                         nmdc-next.biosample_set  1008KB/1008KB  (100.0%)
# 2023-02-27T09:40:23.350-0500
# 2023-02-27T09:40:24.079-0500	[########################]  nmdc-next.biosample_set  1008KB/1008KB  (100.0%)
# 2023-02-27T09:40:24.079-0500	finished restoring nmdc-next.biosample_set (753 documents, 0 failures)
# 2023-02-27T09:40:24.521-0500	restoring nmdc-next.read_qc_analysis_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/read_qc_analysis_activity_set.bson
# 2023-02-27T09:40:26.350-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-02-27T09:40:26.350-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-02-27T09:40:26.350-0500	[###############.........]                       nmdc-next.data_object_set  9.09MB/14.4MB   (63.3%)
# 2023-02-27T09:40:26.350-0500	[########################]         nmdc-next.read_qc_analysis_activity_set    696KB/696KB  (100.0%)
# 2023-02-27T09:40:26.350-0500
# 2023-02-27T09:40:26.839-0500	[########################]  nmdc-next.read_qc_analysis_activity_set  696KB/696KB  (100.0%)
# 2023-02-27T09:40:26.839-0500	finished restoring nmdc-next.read_qc_analysis_activity_set (1058 documents, 0 failures)
# 2023-02-27T09:40:27.255-0500	restoring nmdc-next.nom_analysis_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/nom_analysis_activity_set.bson
# 2023-02-27T09:40:28.797-0500	finished restoring nmdc-next.nom_analysis_activity_set (838 documents, 0 failures)
# 2023-02-27T09:40:28.994-0500	restoring nmdc-next.study_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/study_set.bson
# 2023-02-27T09:40:29.350-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-02-27T09:40:29.350-0500	[########################]    nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-02-27T09:40:29.350-0500	[################........]                       nmdc-next.data_object_set  9.86MB/14.4MB   (68.6%)
# 2023-02-27T09:40:29.350-0500	[########################]                             nmdc-next.study_set  56.3KB/56.3KB  (100.0%)
# 2023-02-27T09:40:29.350-0500
# 2023-02-27T09:40:29.396-0500	[########################]  nmdc-next.study_set  56.3KB/56.3KB  (100.0%)
# 2023-02-27T09:40:29.396-0500	finished restoring nmdc-next.study_set (9 documents, 0 failures)
# 2023-02-27T09:40:29.887-0500	restoring nmdc-next.metatranscriptome_activity_set from /Users/dwinston/nmdcdb-mongodump/2023-02-27/nmdc/metatranscriptome_activity_set.bson
# 2023-02-27T09:40:30.558-0500	finished restoring nmdc-next.metatranscriptome_activity_set (55 documents, 0 failures)
# 2023-02-27T09:40:32.233-0500	[########################]  nmdc-next.metabolomics_analysis_activity_set  15.0MB/15.0MB  (100.0%)
# 2023-02-27T09:40:32.233-0500	finished restoring nmdc-next.metabolomics_analysis_activity_set (209 documents, 0 failures)
# 2023-02-27T09:40:32.350-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB  (22.2%)
# 2023-02-27T09:40:32.350-0500	[#################.......]                       nmdc-next.data_object_set  10.5MB/14.4MB  (73.1%)
# 2023-02-27T09:40:32.350-0500
# 2023-02-27T09:40:35.351-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB  (22.2%)
# 2023-02-27T09:40:35.351-0500	[###################.....]                       nmdc-next.data_object_set  11.9MB/14.4MB  (83.1%)
# 2023-02-27T09:40:35.351-0500
# 2023-02-27T09:40:38.351-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB  (22.2%)
# 2023-02-27T09:40:38.351-0500	[######################..]                       nmdc-next.data_object_set  13.4MB/14.4MB  (93.0%)
# 2023-02-27T09:40:38.351-0500
# 2023-02-27T09:40:41.350-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set   43.9MB/198MB   (22.2%)
# 2023-02-27T09:40:41.350-0500	[########################]                       nmdc-next.data_object_set  14.4MB/14.4MB  (100.0%)
# 2023-02-27T09:40:41.350-0500
# 2023-02-27T09:40:41.520-0500	[########################]  nmdc-next.data_object_set  14.4MB/14.4MB  (100.0%)
# 2023-02-27T09:40:41.521-0500	finished restoring nmdc-next.data_object_set (40858 documents, 0 failures)
# 2023-02-27T09:40:44.351-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set  43.9MB/198MB  (22.2%)
# 2023-02-27T09:40:47.351-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set  43.9MB/198MB  (22.2%)
# 2023-02-27T09:40:50.351-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set  43.9MB/198MB  (22.2%)
# 2023-02-27T09:40:53.351-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set  43.9MB/198MB  (22.2%)
# 2023-02-27T09:40:56.351-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set  43.9MB/198MB  (22.2%)
# 2023-02-27T09:40:59.351-0500	[#####...................]  nmdc-next.metaproteomics_analysis_activity_set  43.9MB/198MB  (22.2%)
# 2023-02-27T09:41:02.351-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set  109MB/198MB  (55.1%)
# 2023-02-27T09:41:05.351-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set  109MB/198MB  (55.1%)
# 2023-02-27T09:41:08.352-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set  109MB/198MB  (55.1%)
# 2023-02-27T09:41:11.351-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set  109MB/198MB  (55.1%)
# 2023-02-27T09:41:14.351-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set  109MB/198MB  (55.1%)
# 2023-02-27T09:41:17.351-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set  109MB/198MB  (55.1%)
# 2023-02-27T09:41:20.352-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set  109MB/198MB  (55.1%)
# 2023-02-27T09:41:23.351-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set  109MB/198MB  (55.1%)
# 2023-02-27T09:41:26.352-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set  109MB/198MB  (55.1%)
# 2023-02-27T09:41:29.352-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set  109MB/198MB  (55.1%)
# 2023-02-27T09:41:32.352-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set  109MB/198MB  (55.1%)
# 2023-02-27T09:41:35.352-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set  109MB/198MB  (55.1%)
# 2023-02-27T09:41:38.352-0500	[#############...........]  nmdc-next.metaproteomics_analysis_activity_set  109MB/198MB  (55.1%)
# 2023-02-27T09:41:41.353-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:41:44.352-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:41:47.352-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:41:50.353-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:41:53.352-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:41:56.352-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:41:59.352-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:42:02.352-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:42:05.353-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:42:08.353-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:42:11.353-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:42:14.353-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:42:17.353-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:42:20.353-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:42:23.353-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:42:26.353-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:42:29.353-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:42:32.353-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:42:35.354-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:42:38.353-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:42:41.353-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:42:44.354-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:42:47.354-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:42:50.354-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:42:53.354-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:42:56.354-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:42:58.647-0500	[########################]  nmdc-next.metaproteomics_analysis_activity_set  198MB/198MB  (100.0%)
# 2023-02-27T09:42:58.647-0500	finished restoring nmdc-next.metaproteomics_analysis_activity_set (52 documents, 0 failures)
# 2023-02-27T09:42:58.647-0500	restoring indexes for collection nmdc-next.metaproteomics_analysis_activity_set from metadata
# 2023-02-27T09:42:58.647-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:58.647-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ended_at_time_1", "v":2}, Key:primitive.D{primitive.E{Key:"ended_at_time", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:58.647-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"was_informed_by_1", "v":2}, Key:primitive.D{primitive.E{Key:"was_informed_by", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:58.647-0500	restoring indexes for collection nmdc-next.nom_analysis_activity_set from metadata
# 2023-02-27T09:42:58.647-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:58.647-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"was_informed_by_1", "v":2}, Key:primitive.D{primitive.E{Key:"was_informed_by", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:58.647-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ended_at_time_1", "v":2}, Key:primitive.D{primitive.E{Key:"ended_at_time", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:58.647-0500	restoring indexes for collection nmdc-next.study_set from metadata
# 2023-02-27T09:42:58.647-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"has_credit_associations.applies_to_person.orcid", "v":2}, Key:primitive.D{primitive.E{Key:"has_credit_associations.applies_to_person.orcid", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:58.647-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:58.648-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"has_credit_associations.applies_to_person.name", "v":2}, Key:primitive.D{primitive.E{Key:"has_credit_associations.applies_to_person.name", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:58.648-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"has_credit_associations.applied_roles", "v":2}, Key:primitive.D{primitive.E{Key:"has_credit_associations.applied_roles", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:58.648-0500	restoring indexes for collection nmdc-next.data_object_set from metadata
# 2023-02-27T09:42:58.648-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"file_size_bytes", "v":2}, Key:primitive.D{primitive.E{Key:"file_size_bytes", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:58.648-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"url", "v":2}, Key:primitive.D{primitive.E{Key:"url", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:58.648-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:58.648-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"md5_checksum", "v":2}, Key:primitive.D{primitive.E{Key:"md5_checksum", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:58.648-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"data_object_type", "v":2}, Key:primitive.D{primitive.E{Key:"data_object_type", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:59.325-0500	restoring indexes for collection nmdc-next.biosample_set from metadata
# 2023-02-27T09:42:59.325-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ecosystem_category", "v":2}, Key:primitive.D{primitive.E{Key:"ecosystem_category", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:59.325-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:59.325-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"collection_date.has_raw_value", "v":2}, Key:primitive.D{primitive.E{Key:"collection_date.has_raw_value", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:59.325-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"specific_ecosystem", "v":2}, Key:primitive.D{primitive.E{Key:"specific_ecosystem", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:59.325-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"alternative_identifiers", "v":2}, Key:primitive.D{primitive.E{Key:"alternative_identifiers", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:59.325-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ecosystem_subtype", "v":2}, Key:primitive.D{primitive.E{Key:"ecosystem_subtype", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:59.325-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"part_of_1", "v":2}, Key:primitive.D{primitive.E{Key:"part_of", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:59.326-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ecosystem_type", "v":2}, Key:primitive.D{primitive.E{Key:"ecosystem_type", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:59.326-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"env_medium.has_raw_value", "v":2}, Key:primitive.D{primitive.E{Key:"env_medium.has_raw_value", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:59.326-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"lat_lon.latitude", "v":2}, Key:primitive.D{primitive.E{Key:"lat_lon.latitude", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:59.326-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"lat_lon.longitude", "v":2}, Key:primitive.D{primitive.E{Key:"lat_lon.longitude", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:59.326-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ecosystem", "v":2}, Key:primitive.D{primitive.E{Key:"ecosystem", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:59.326-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"env_local_scale.has_raw_value", "v":2}, Key:primitive.D{primitive.E{Key:"env_local_scale.has_raw_value", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:59.326-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"env_broad_scale.has_raw_value", "v":2}, Key:primitive.D{primitive.E{Key:"env_broad_scale.has_raw_value", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:59.698-0500	restoring indexes for collection nmdc-next.metatranscriptome_activity_set from metadata
# 2023-02-27T09:42:59.698-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:59.698-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"was_informed_by_1", "v":2}, Key:primitive.D{primitive.E{Key:"was_informed_by", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:42:59.698-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ended_at_time_1", "v":2}, Key:primitive.D{primitive.E{Key:"ended_at_time", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:43:00.217-0500	restoring indexes for collection nmdc-next.omics_processing_set from metadata
# 2023-02-27T09:43:00.217-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:43:00.217-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"alternative_identifiers", "v":2}, Key:primitive.D{primitive.E{Key:"alternative_identifiers", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:43:00.217-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"has_output", "v":2}, Key:primitive.D{primitive.E{Key:"has_output", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:43:00.217-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"has_input", "v":2}, Key:primitive.D{primitive.E{Key:"has_input", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:43:00.217-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"instrument_name", "v":2}, Key:primitive.D{primitive.E{Key:"instrument_name", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:43:00.217-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ended_at_time_1", "v":2}, Key:primitive.D{primitive.E{Key:"ended_at_time", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:43:00.217-0500	restoring indexes for collection nmdc-next.read_qc_analysis_activity_set from metadata
# 2023-02-27T09:43:00.217-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:43:00.217-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"was_informed_by_1", "v":2}, Key:primitive.D{primitive.E{Key:"was_informed_by", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:43:00.217-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ended_at_time_1", "v":2}, Key:primitive.D{primitive.E{Key:"ended_at_time", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:43:00.217-0500	restoring indexes for collection nmdc-next.mags_activity_set from metadata
# 2023-02-27T09:43:00.217-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:43:00.217-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ended_at_time_1", "v":2}, Key:primitive.D{primitive.E{Key:"ended_at_time", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:43:00.217-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"was_informed_by_1", "v":2}, Key:primitive.D{primitive.E{Key:"was_informed_by", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:43:00.757-0500	restoring indexes for collection nmdc-next.metabolomics_analysis_activity_set from metadata
# 2023-02-27T09:43:00.757-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"was_informed_by_1", "v":2}, Key:primitive.D{primitive.E{Key:"was_informed_by", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:43:00.757-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ended_at_time_1", "v":2}, Key:primitive.D{primitive.E{Key:"ended_at_time", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:43:00.757-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:43:00.827-0500	restoring indexes for collection nmdc-next.metagenome_assembly_set from metadata
# 2023-02-27T09:43:00.827-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:43:00.827-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"was_informed_by_1", "v":2}, Key:primitive.D{primitive.E{Key:"was_informed_by", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:43:00.827-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ended_at_time_1", "v":2}, Key:primitive.D{primitive.E{Key:"ended_at_time", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:43:01.050-0500	restoring indexes for collection nmdc-next.metagenome_annotation_activity_set from metadata
# 2023-02-27T09:43:01.050-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"id_1", "unique":true, "v":2}, Key:primitive.D{primitive.E{Key:"id", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:43:01.050-0500	index: &idx.IndexDocument{Options:primitive.M{"name":"was_informed_by_1", "v":2}, Key:primitive.D{primitive.E{Key:"was_informed_by", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:43:01.050-0500	index: &idx.IndexDocument{Options:primitive.M{"background":true, "name":"ended_at_time_1", "v":2}, Key:primitive.D{primitive.E{Key:"ended_at_time", Value:1}}, PartialFilterExpression:primitive.D(nil)}
# 2023-02-27T09:43:01.414-0500	48394 document(s) restored successfully. 0 document(s) failed to restore.
# Took approx. 195.1042697429657 seconds
