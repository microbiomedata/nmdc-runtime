# %%
# autoreload modules; useful for testing
# %load_ext autoreload
# %autoreload 2

# %%
import json
import copy
import pandas as pd
from toolz.dicttoolz import assoc_in, merge, merge_with, get_in, dissoc
from dotenv import dotenv_values
from pymongo import MongoClient
from pymongo.database import Database as MongoDatabase
from nmdc_runtime.api.core.metadata import load_changesheet, update_mongo_db, mongo_update_command_for, copy_docs_in_update_cmd

# %% [markdown]
# ### load mongodb via env info

# %%
config = dotenv_values("../../.env.localhost")
config["MONGO_HOST"]
# Out:
# 'mongodb://localhost:27018'

# %%
client = MongoClient(host=config["MONGO_HOST"], username=config["MONGO_USERNAME"], password=config["MONGO_PASSWORD"])
mongodb = client["nmdc"]

# %% [markdown]
# ### create temp database and temp_set collection for testing

# %%
if "temp_db" in client.list_database_names():
    client.drop_database("temp_db")
temp_db = client["temp_db"]

# %% [markdown]
# ### helper functons

# %%
# wraps the mongo_update_command_for and update_mongo_db into
# a single function to process the change sheet
def process_changesheet(changeDf, mdb: MongoDatabase, temp_db: MongoDatabase):
    update_cmd = mongo_update_command_for(changeDf)
    copy_docs_in_update_cmd(update_cmd, mdb, temp_db)
    return update_mongo_db(temp_db, update_cmd)
    
#     for id_, cmd in update_cmd.items():
#         print('id:', id_)
#         print(cmd)
#         print('\n')

# %%
# puts the change sheet results in dataframe
def print_results(results, print_before=True, print_after=True, print_errors=True):
    for i, result in enumerate(results):
        print(f"\n============== {result['id']} ==============")
        if print_before:
            print("------------------ BEFORE ------------------")
            print(json.dumps(result["doc_before"], indent=2))
        if print_after:
            print("------------------ AFTER ------------------")
            print(json.dumps(result["doc_after"], indent=2))
        if print_errors:
            print("------------------ ERRORS ------------------")
            print("\n".join(result["validation_errors"]))

# %% [markdown]
# ### set dataframe display options

# %%
pd.set_option("display.max_columns", None)
pd.set_option('display.width', 1000)

# %% [markdown]
# ### process change sheet 1
# Simple test with two studies. The doi is changed using "." path separator.

# %%
pd.read_csv("data/changesheet-with-separator1.tsv", sep="\t", dtype="string").fillna('')
# Out:
#                id  action          attribute           value
# 0  gold:Gs0114663  update               name  UPDATED NAME 1
# 1                  update          ecosystem            SOIL
# 2  gold:Gs0103573  update  doi.has_raw_value    10.9999/8888
# 3                  update               name  UPDATED NAME 2

# %%
sheetDf = load_changesheet("data/changesheet-with-separator1.tsv", mongodb)
sheetDf
# Out:
#                id  action          attribute           value        group_id group_var               path collection_name linkml_class       linkml_slots                  ranges  multivalues
# 0  gold:Gs0114663  update               name  UPDATED NAME 1  gold:Gs0114663                         name       study_set        study               name                  string        False
# 1                  update          ecosystem            SOIL  gold:Gs0114663                    ecosystem       study_set        study          ecosystem                  string        False
# 2  gold:Gs0103573  update  doi.has_raw_value    10.9999/8888  gold:Gs0103573            doi.has_raw_value       study_set        study  doi|has raw value  attribute value|string  False|False
# 3                  update               name  UPDATED NAME 2  gold:Gs0103573                         name       study_set        study               name                  string        False

# %%
print_results(process_changesheet(sheetDf, mongodb, temp_db))
# Out:
# ============== gold:Gs0103573 ==============
# ------------------ BEFORE ------------------
# {
#   "id": "gold:Gs0103573",
#   "name": "Populus root and rhizosphere microbial communities from Tennessee, USA",
#   "description": "This study is part of the Plant-Microbe Interfaces Science Focus Area, which aims to gain a deeper understanding of the diversity and functioning of mutually beneficial interactions between plants and microbes in the rhizosphere. Ongoing efforts focus on characterizing and interpreting such interfaces using systems comprising plants and microbes, in particular the poplar tree (Populus) and its microbial community in the context of favorable plant microbe interactions.",
#   "ecosystem": "Host-associated",
#   "ecosystem_category": "Plants",
#   "ecosystem_type": "Unclassified",
#   "ecosystem_subtype": "Unclassified",
#   "specific_ecosystem": "Unclassified",
#   "principal_investigator": {
#     "has_raw_value": "Mitchel J. Doktycz",
#     "name": "Mitchel J. Doktycz",
#     "profile_image_url": "https://portal.nersc.gov/project/m3408/profile_images/doktycz_mitchel.jpg",
#     "orcid": "orcid:0000-0003-4856-8343"
#   },
#   "type": "nmdc:Study",
#   "websites": [
#     "https://pmiweb.ornl.gov/pmi-project-aims/"
#   ],
#   "title": "Defining the functional diversity of the Populus root microbiome",
#   "doi": {
#     "has_raw_value": "https://doi.org/10.25585/1488096"
#   },
#   "publications": [
#     "https://doi.org/10.1128/mSystems.00045-18"
#   ],
#   "has_credit_associations": [
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Mitchel J. Doktycz",
#         "email": "doktyczmj@ornl.gov",
#         "orcid": "orcid:0000-0003-4856-8343"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Josh Michener",
#         "email": "michenerjk@ornl.gov",
#         "orcid": "orcid:0000-0003-2302-8180"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Jennifer Morrell-Falvey",
#         "email": "morrelljl1@ornl.gov",
#         "orcid": "orcid:0000-0002-9362-7528"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Wellington Muchero",
#         "email": "mucherow@ornl.gov",
#         "orcid": "orcid:0000-0002-0200-9856"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Dale Pelletier",
#         "email": "pelletierda@ornl.gov",
#         "orcid": "orcid:0000-0002-4321-7918"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Mircea Podar",
#         "email": "podarm@ornl.gov",
#         "orcid": "orcid:0000-0003-2776-0205"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Scott Retterer",
#         "email": "rettererst@ornl.gov",
#         "orcid": "orcid:0000-0001-8534-1979"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Robert Hettich",
#         "email": "hettichrl@ornl.gov",
#         "orcid": "orcid:0000-0001-7708-786X"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Christopher Schadt",
#         "email": "schadtcw@ornl.gov",
#         "orcid": "orcid:0000-0001-8759-2448"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Timothy Tschaplinski",
#         "email": "tschaplinstj@ornl.gov",
#         "orcid": "orcid:0000-0002-9540-6622"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "David Weston",
#         "email": "westondj@ornl.gov",
#         "orcid": "orcid:0000-0002-4794-9913"
#       }
#     },
#     {
#       "applied_role": "Data curation",
#       "applies_to_person": {
#         "name": "Paul Abraham",
#         "email": "abrahampe@ornl.gov",
#         "orcid": "orcid:0000-0003-2685-9123"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Xiaohan Yang",
#         "email": "yangx@ornl.gov",
#         "orcid": "orcid:0000-0001-5207-4210"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Jin-Gui Chen",
#         "email": "chenj@ornl.gov",
#         "orcid": "orcid:0000-0002-1752-4201"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Melissa Cregger",
#         "email": "creggerma@ornl.gov",
#         "orcid": "orcid:0000-0001-8329-366X"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Omar Demerdash",
#         "email": "demerdashon@ornl.gov",
#         "orcid": "orcid:0000-0001-6846-1506"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Joseph C. Ellis",
#         "email": "ellisjc@ornl.gov",
#         "orcid": "orcid:0000-0002-2510-977X"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Daniel Jacobson",
#         "email": "jacobsonda@ornl.gov",
#         "orcid": "orcid:0000-0002-9822-8251"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Udaya Kalluri",
#         "email": "Kalluriudayc@ornl.gov",
#         "orcid": "orcid:0000-0002-5963-8370"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Stanton Martin",
#         "email": "martins@ornl.gov",
#         "orcid": "orcid:0000-0001-9246-8193"
#       }
#     }
#   ],
#   "funding_sources": [
#     "U.S. Department of Energy, Office of Science, Office of Biological and Environmental Research (BER) under contract DE-AC05-00OR22725; Project Number (FWP): 3ERKP730"
#   ]
# }
# ------------------ AFTER ------------------
# {
#   "id": "gold:Gs0103573",
#   "name": "UPDATED NAME 2",
#   "description": "This study is part of the Plant-Microbe Interfaces Science Focus Area, which aims to gain a deeper understanding of the diversity and functioning of mutually beneficial interactions between plants and microbes in the rhizosphere. Ongoing efforts focus on characterizing and interpreting such interfaces using systems comprising plants and microbes, in particular the poplar tree (Populus) and its microbial community in the context of favorable plant microbe interactions.",
#   "ecosystem": "Host-associated",
#   "ecosystem_category": "Plants",
#   "ecosystem_type": "Unclassified",
#   "ecosystem_subtype": "Unclassified",
#   "specific_ecosystem": "Unclassified",
#   "principal_investigator": {
#     "has_raw_value": "Mitchel J. Doktycz",
#     "name": "Mitchel J. Doktycz",
#     "profile_image_url": "https://portal.nersc.gov/project/m3408/profile_images/doktycz_mitchel.jpg",
#     "orcid": "orcid:0000-0003-4856-8343"
#   },
#   "type": "nmdc:Study",
#   "websites": [
#     "https://pmiweb.ornl.gov/pmi-project-aims/"
#   ],
#   "title": "Defining the functional diversity of the Populus root microbiome",
#   "doi": {
#     "has_raw_value": "10.9999/8888"
#   },
#   "publications": [
#     "https://doi.org/10.1128/mSystems.00045-18"
#   ],
#   "has_credit_associations": [
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Mitchel J. Doktycz",
#         "email": "doktyczmj@ornl.gov",
#         "orcid": "orcid:0000-0003-4856-8343"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Josh Michener",
#         "email": "michenerjk@ornl.gov",
#         "orcid": "orcid:0000-0003-2302-8180"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Jennifer Morrell-Falvey",
#         "email": "morrelljl1@ornl.gov",
#         "orcid": "orcid:0000-0002-9362-7528"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Wellington Muchero",
#         "email": "mucherow@ornl.gov",
#         "orcid": "orcid:0000-0002-0200-9856"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Dale Pelletier",
#         "email": "pelletierda@ornl.gov",
#         "orcid": "orcid:0000-0002-4321-7918"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Mircea Podar",
#         "email": "podarm@ornl.gov",
#         "orcid": "orcid:0000-0003-2776-0205"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Scott Retterer",
#         "email": "rettererst@ornl.gov",
#         "orcid": "orcid:0000-0001-8534-1979"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Robert Hettich",
#         "email": "hettichrl@ornl.gov",
#         "orcid": "orcid:0000-0001-7708-786X"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Christopher Schadt",
#         "email": "schadtcw@ornl.gov",
#         "orcid": "orcid:0000-0001-8759-2448"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Timothy Tschaplinski",
#         "email": "tschaplinstj@ornl.gov",
#         "orcid": "orcid:0000-0002-9540-6622"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "David Weston",
#         "email": "westondj@ornl.gov",
#         "orcid": "orcid:0000-0002-4794-9913"
#       }
#     },
#     {
#       "applied_role": "Data curation",
#       "applies_to_person": {
#         "name": "Paul Abraham",
#         "email": "abrahampe@ornl.gov",
#         "orcid": "orcid:0000-0003-2685-9123"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Xiaohan Yang",
#         "email": "yangx@ornl.gov",
#         "orcid": "orcid:0000-0001-5207-4210"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Jin-Gui Chen",
#         "email": "chenj@ornl.gov",
#         "orcid": "orcid:0000-0002-1752-4201"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Melissa Cregger",
#         "email": "creggerma@ornl.gov",
#         "orcid": "orcid:0000-0001-8329-366X"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Omar Demerdash",
#         "email": "demerdashon@ornl.gov",
#         "orcid": "orcid:0000-0001-6846-1506"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Joseph C. Ellis",
#         "email": "ellisjc@ornl.gov",
#         "orcid": "orcid:0000-0002-2510-977X"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Daniel Jacobson",
#         "email": "jacobsonda@ornl.gov",
#         "orcid": "orcid:0000-0002-9822-8251"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Udaya Kalluri",
#         "email": "Kalluriudayc@ornl.gov",
#         "orcid": "orcid:0000-0002-5963-8370"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Stanton Martin",
#         "email": "martins@ornl.gov",
#         "orcid": "orcid:0000-0001-9246-8193"
#       }
#     }
#   ],
#   "funding_sources": [
#     "U.S. Department of Energy, Office of Science, Office of Biological and Environmental Research (BER) under contract DE-AC05-00OR22725; Project Number (FWP): 3ERKP730"
#   ]
# }
# ------------------ ERRORS ------------------
#
#
# ============== gold:Gs0114663 ==============
# ------------------ BEFORE ------------------
# {
#   "id": "gold:Gs0114663",
#   "name": "Riverbed sediment microbial communities from the Columbia River, Washington, USA",
#   "description": "This research project, led by James Stegen at PNNL, aimed to understand how molecular-scale processes govern the biogeochemical function of subsurface groundwater-surface water mixing zones (i.e., the hyporheic zone). This project was conducted along the Columbia River in Eastern Washington State, which exhibits variation in microbiome composition, biogeochemical activity, and substrate biogeochemistry, making it an ideal environment for studying biogeochemical hotspots. To capture a range of biogeochemical activities, samples were collected from areas with dense vegetation and virtually no vegetation.\n\nThis project\u2019s long-term goal is to develop models that can simulate impacts of disturbance on river corridor hydro-biogeochemistry by understanding fundamental molecular processes that lead to emergent function. This project is part of PNNL\u2019s River Corridor Hydrobiogeochemistry Science Focus Area (https://www.pnnl.gov/projects/river-corridor-hydrobiogeochemistry-science-focus-area).\n",
#   "ecosystem": "Environmental",
#   "ecosystem_category": "Aquatic",
#   "ecosystem_type": "Freshwater",
#   "ecosystem_subtype": "River",
#   "specific_ecosystem": "Sediment",
#   "principal_investigator": {
#     "has_raw_value": "James Stegen",
#     "profile_image_url": "https://portal.nersc.gov/project/m3408/profile_images/stegen_james.jpg"
#   },
#   "doi": {
#     "has_raw_value": "https://doi.org/10.25585/1487765"
#   },
#   "type": "nmdc:Study",
#   "publications": [
#     "https://doi.org/10.1371/journal.pone.0228165"
#   ],
#   "has_credit_associations": [
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "James Stegen",
#         "email": "James.Stegen@pnnl.gov",
#         "orcid": "orcid:0000-0001-9135-7424"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Malak Tfaily",
#         "email": "tfaily@email.arizona.edu",
#         "orcid": "orcid:0000-0002-3036-2833"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Amy Goldman",
#         "email": "amy.goldman@pnnl.gov",
#         "orcid": "orcid:0000-0003-0490-6451"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Lisa Bramer",
#         "email": "Lisa.Bramer@pnnl.gov",
#         "orcid": "orcid:0000-0002-8384-1926"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "C. Tom Resch",
#         "email": "tom.resch@pnnl.gov",
#         "orcid": "orcid:0000-0002-9143-6277"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Emily Graham",
#         "email": "emily.graham@pnnl.gov",
#         "orcid": "orcid:0000-0002-4623-7076"
#       }
#     },
#     {
#       "applied_role": "Data curation",
#       "applies_to_person": {
#         "name": "Alex Crump",
#         "email": "acrump@uidaho.edu",
#         "orcid": "orcid:0000-0002-2443-6146"
#       }
#     },
#     {
#       "applied_role": "Data curation",
#       "applies_to_person": {
#         "name": "David Kennedy",
#         "email": "",
#         "orcid": ""
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Evan Amtzen",
#         "email": "Evan.Arntzen@pnnl.gov",
#         "orcid": "orcid:0000-0002-9209-5670"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Sarah Fansler",
#         "email": "Sarah.Fansler@pnnl.gov",
#         "orcid": "orcid:0000-0003-4190-907X"
#       }
#     },
#     {
#       "applied_role": "Data curation",
#       "applies_to_person": {
#         "name": "Samuel Purvine",
#         "email": "Samuel.Purvine@pnnl.gov",
#         "orcid": "orcid:0000-0002-2257-2400"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Carrie Nicora",
#         "email": "Carrie.Nicora@pnnl.gov",
#         "orcid": "orcid:0000-0003-2461-9548"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "William Nelson",
#         "email": "William.Nelson@pnnl.gov",
#         "orcid": "orcid:0000-0002-1873-3929"
#       }
#     }
#   ],
#   "funding_sources": [
#     "U.S. Department of Energy, Office of Science, Office of Biological and Environmental Research (BER) under contract DE-AC05-76RL01830 (PNNL))"
#   ]
# }
# ------------------ AFTER ------------------
# {
#   "id": "gold:Gs0114663",
#   "name": "UPDATED NAME 1",
#   "description": "This research project, led by James Stegen at PNNL, aimed to understand how molecular-scale processes govern the biogeochemical function of subsurface groundwater-surface water mixing zones (i.e., the hyporheic zone). This project was conducted along the Columbia River in Eastern Washington State, which exhibits variation in microbiome composition, biogeochemical activity, and substrate biogeochemistry, making it an ideal environment for studying biogeochemical hotspots. To capture a range of biogeochemical activities, samples were collected from areas with dense vegetation and virtually no vegetation.\n\nThis project\u2019s long-term goal is to develop models that can simulate impacts of disturbance on river corridor hydro-biogeochemistry by understanding fundamental molecular processes that lead to emergent function. This project is part of PNNL\u2019s River Corridor Hydrobiogeochemistry Science Focus Area (https://www.pnnl.gov/projects/river-corridor-hydrobiogeochemistry-science-focus-area).\n",
#   "ecosystem": "SOIL",
#   "ecosystem_category": "Aquatic",
#   "ecosystem_type": "Freshwater",
#   "ecosystem_subtype": "River",
#   "specific_ecosystem": "Sediment",
#   "principal_investigator": {
#     "has_raw_value": "James Stegen",
#     "profile_image_url": "https://portal.nersc.gov/project/m3408/profile_images/stegen_james.jpg"
#   },
#   "doi": {
#     "has_raw_value": "https://doi.org/10.25585/1487765"
#   },
#   "type": "nmdc:Study",
#   "publications": [
#     "https://doi.org/10.1371/journal.pone.0228165"
#   ],
#   "has_credit_associations": [
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "James Stegen",
#         "email": "James.Stegen@pnnl.gov",
#         "orcid": "orcid:0000-0001-9135-7424"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Malak Tfaily",
#         "email": "tfaily@email.arizona.edu",
#         "orcid": "orcid:0000-0002-3036-2833"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Amy Goldman",
#         "email": "amy.goldman@pnnl.gov",
#         "orcid": "orcid:0000-0003-0490-6451"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Lisa Bramer",
#         "email": "Lisa.Bramer@pnnl.gov",
#         "orcid": "orcid:0000-0002-8384-1926"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "C. Tom Resch",
#         "email": "tom.resch@pnnl.gov",
#         "orcid": "orcid:0000-0002-9143-6277"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Emily Graham",
#         "email": "emily.graham@pnnl.gov",
#         "orcid": "orcid:0000-0002-4623-7076"
#       }
#     },
#     {
#       "applied_role": "Data curation",
#       "applies_to_person": {
#         "name": "Alex Crump",
#         "email": "acrump@uidaho.edu",
#         "orcid": "orcid:0000-0002-2443-6146"
#       }
#     },
#     {
#       "applied_role": "Data curation",
#       "applies_to_person": {
#         "name": "David Kennedy",
#         "email": "",
#         "orcid": ""
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Evan Amtzen",
#         "email": "Evan.Arntzen@pnnl.gov",
#         "orcid": "orcid:0000-0002-9209-5670"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Sarah Fansler",
#         "email": "Sarah.Fansler@pnnl.gov",
#         "orcid": "orcid:0000-0003-4190-907X"
#       }
#     },
#     {
#       "applied_role": "Data curation",
#       "applies_to_person": {
#         "name": "Samuel Purvine",
#         "email": "Samuel.Purvine@pnnl.gov",
#         "orcid": "orcid:0000-0002-2257-2400"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Carrie Nicora",
#         "email": "Carrie.Nicora@pnnl.gov",
#         "orcid": "orcid:0000-0003-2461-9548"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "William Nelson",
#         "email": "William.Nelson@pnnl.gov",
#         "orcid": "orcid:0000-0002-1873-3929"
#       }
#     }
#   ],
#   "funding_sources": [
#     "U.S. Department of Energy, Office of Science, Office of Biological and Environmental Research (BER) under contract DE-AC05-76RL01830 (PNNL))"
#   ]
# }
# ------------------ ERRORS ------------------

# %% [markdown]
# ### process change sheet 2
# Test with two studies, but the second study uses grouping variables/symbols to update object values.

# %%
pd.read_csv("data/changesheet-without-separator1.tsv", sep="\t", dtype="string").fillna('')
# Out:
#                id  action               attribute            value
# 0  gold:Gs0103573  update                    name       NEW NAME 1
# 1                                       ecosystem             SOIL
# 2  gold:Gs0114663  update                     doi               v1
# 3              v1                   has_raw_value     10.9999/8888
# 4                  update                    name       NEW NAME 2
# 5                  update  principal_investigator               v2
# 6              v2                   has_raw_value  NEW RAW VALUE 2

# %%
sheetDf = load_changesheet("data/changesheet-without-separator1.tsv", mongodb)
sheetDf
# Out:
#                id  action               attribute            value        group_id group_var                                  path collection_name linkml_class                          linkml_slots                  ranges  multivalues
# 0  gold:Gs0103573  update                    name       NEW NAME 1  gold:Gs0103573                                            name       study_set        study                                  name                  string        False
# 1                  update               ecosystem             SOIL  gold:Gs0103573                                       ecosystem       study_set        study                             ecosystem                  string        False
# 2  gold:Gs0114663  update                     doi               v1  gold:Gs0114663        v1                                             study_set        study                                   doi         attribute value        False
# 3              v1  update           has_raw_value     10.9999/8888  gold:Gs0114663        v1                     doi.has_raw_value       study_set        study                     doi|has raw value  attribute value|string  False|False
# 4                  update                    name       NEW NAME 2  gold:Gs0114663                                            name       study_set        study                                  name                  string        False
# 5                  update  principal_investigator               v2  gold:Gs0114663        v2                                             study_set        study                principal investigator            person value        False
# 6              v2  update           has_raw_value  NEW RAW VALUE 2  gold:Gs0114663        v2  principal_investigator.has_raw_value       study_set        study  principal investigator|has raw value     person value|string  False|False

# %%
print_results(process_changesheet(sheetDf, mongodb, temp_db))
# Out:
# ============== gold:Gs0103573 ==============
# ------------------ BEFORE ------------------
# {
#   "id": "gold:Gs0103573",
#   "name": "Populus root and rhizosphere microbial communities from Tennessee, USA",
#   "description": "This study is part of the Plant-Microbe Interfaces Science Focus Area, which aims to gain a deeper understanding of the diversity and functioning of mutually beneficial interactions between plants and microbes in the rhizosphere. Ongoing efforts focus on characterizing and interpreting such interfaces using systems comprising plants and microbes, in particular the poplar tree (Populus) and its microbial community in the context of favorable plant microbe interactions.",
#   "ecosystem": "Host-associated",
#   "ecosystem_category": "Plants",
#   "ecosystem_type": "Unclassified",
#   "ecosystem_subtype": "Unclassified",
#   "specific_ecosystem": "Unclassified",
#   "principal_investigator": {
#     "has_raw_value": "Mitchel J. Doktycz",
#     "name": "Mitchel J. Doktycz",
#     "profile_image_url": "https://portal.nersc.gov/project/m3408/profile_images/doktycz_mitchel.jpg",
#     "orcid": "orcid:0000-0003-4856-8343"
#   },
#   "type": "nmdc:Study",
#   "websites": [
#     "https://pmiweb.ornl.gov/pmi-project-aims/"
#   ],
#   "title": "Defining the functional diversity of the Populus root microbiome",
#   "doi": {
#     "has_raw_value": "https://doi.org/10.25585/1488096"
#   },
#   "publications": [
#     "https://doi.org/10.1128/mSystems.00045-18"
#   ],
#   "has_credit_associations": [
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Mitchel J. Doktycz",
#         "email": "doktyczmj@ornl.gov",
#         "orcid": "orcid:0000-0003-4856-8343"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Josh Michener",
#         "email": "michenerjk@ornl.gov",
#         "orcid": "orcid:0000-0003-2302-8180"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Jennifer Morrell-Falvey",
#         "email": "morrelljl1@ornl.gov",
#         "orcid": "orcid:0000-0002-9362-7528"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Wellington Muchero",
#         "email": "mucherow@ornl.gov",
#         "orcid": "orcid:0000-0002-0200-9856"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Dale Pelletier",
#         "email": "pelletierda@ornl.gov",
#         "orcid": "orcid:0000-0002-4321-7918"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Mircea Podar",
#         "email": "podarm@ornl.gov",
#         "orcid": "orcid:0000-0003-2776-0205"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Scott Retterer",
#         "email": "rettererst@ornl.gov",
#         "orcid": "orcid:0000-0001-8534-1979"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Robert Hettich",
#         "email": "hettichrl@ornl.gov",
#         "orcid": "orcid:0000-0001-7708-786X"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Christopher Schadt",
#         "email": "schadtcw@ornl.gov",
#         "orcid": "orcid:0000-0001-8759-2448"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Timothy Tschaplinski",
#         "email": "tschaplinstj@ornl.gov",
#         "orcid": "orcid:0000-0002-9540-6622"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "David Weston",
#         "email": "westondj@ornl.gov",
#         "orcid": "orcid:0000-0002-4794-9913"
#       }
#     },
#     {
#       "applied_role": "Data curation",
#       "applies_to_person": {
#         "name": "Paul Abraham",
#         "email": "abrahampe@ornl.gov",
#         "orcid": "orcid:0000-0003-2685-9123"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Xiaohan Yang",
#         "email": "yangx@ornl.gov",
#         "orcid": "orcid:0000-0001-5207-4210"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Jin-Gui Chen",
#         "email": "chenj@ornl.gov",
#         "orcid": "orcid:0000-0002-1752-4201"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Melissa Cregger",
#         "email": "creggerma@ornl.gov",
#         "orcid": "orcid:0000-0001-8329-366X"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Omar Demerdash",
#         "email": "demerdashon@ornl.gov",
#         "orcid": "orcid:0000-0001-6846-1506"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Joseph C. Ellis",
#         "email": "ellisjc@ornl.gov",
#         "orcid": "orcid:0000-0002-2510-977X"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Daniel Jacobson",
#         "email": "jacobsonda@ornl.gov",
#         "orcid": "orcid:0000-0002-9822-8251"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Udaya Kalluri",
#         "email": "Kalluriudayc@ornl.gov",
#         "orcid": "orcid:0000-0002-5963-8370"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Stanton Martin",
#         "email": "martins@ornl.gov",
#         "orcid": "orcid:0000-0001-9246-8193"
#       }
#     }
#   ],
#   "funding_sources": [
#     "U.S. Department of Energy, Office of Science, Office of Biological and Environmental Research (BER) under contract DE-AC05-00OR22725; Project Number (FWP): 3ERKP730"
#   ]
# }
# ------------------ AFTER ------------------
# {
#   "id": "gold:Gs0103573",
#   "name": "NEW NAME 1",
#   "description": "This study is part of the Plant-Microbe Interfaces Science Focus Area, which aims to gain a deeper understanding of the diversity and functioning of mutually beneficial interactions between plants and microbes in the rhizosphere. Ongoing efforts focus on characterizing and interpreting such interfaces using systems comprising plants and microbes, in particular the poplar tree (Populus) and its microbial community in the context of favorable plant microbe interactions.",
#   "ecosystem": "SOIL",
#   "ecosystem_category": "Plants",
#   "ecosystem_type": "Unclassified",
#   "ecosystem_subtype": "Unclassified",
#   "specific_ecosystem": "Unclassified",
#   "principal_investigator": {
#     "has_raw_value": "Mitchel J. Doktycz",
#     "name": "Mitchel J. Doktycz",
#     "profile_image_url": "https://portal.nersc.gov/project/m3408/profile_images/doktycz_mitchel.jpg",
#     "orcid": "orcid:0000-0003-4856-8343"
#   },
#   "type": "nmdc:Study",
#   "websites": [
#     "https://pmiweb.ornl.gov/pmi-project-aims/"
#   ],
#   "title": "Defining the functional diversity of the Populus root microbiome",
#   "doi": {
#     "has_raw_value": "https://doi.org/10.25585/1488096"
#   },
#   "publications": [
#     "https://doi.org/10.1128/mSystems.00045-18"
#   ],
#   "has_credit_associations": [
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Mitchel J. Doktycz",
#         "email": "doktyczmj@ornl.gov",
#         "orcid": "orcid:0000-0003-4856-8343"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Josh Michener",
#         "email": "michenerjk@ornl.gov",
#         "orcid": "orcid:0000-0003-2302-8180"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Jennifer Morrell-Falvey",
#         "email": "morrelljl1@ornl.gov",
#         "orcid": "orcid:0000-0002-9362-7528"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Wellington Muchero",
#         "email": "mucherow@ornl.gov",
#         "orcid": "orcid:0000-0002-0200-9856"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Dale Pelletier",
#         "email": "pelletierda@ornl.gov",
#         "orcid": "orcid:0000-0002-4321-7918"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Mircea Podar",
#         "email": "podarm@ornl.gov",
#         "orcid": "orcid:0000-0003-2776-0205"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Scott Retterer",
#         "email": "rettererst@ornl.gov",
#         "orcid": "orcid:0000-0001-8534-1979"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Robert Hettich",
#         "email": "hettichrl@ornl.gov",
#         "orcid": "orcid:0000-0001-7708-786X"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Christopher Schadt",
#         "email": "schadtcw@ornl.gov",
#         "orcid": "orcid:0000-0001-8759-2448"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Timothy Tschaplinski",
#         "email": "tschaplinstj@ornl.gov",
#         "orcid": "orcid:0000-0002-9540-6622"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "David Weston",
#         "email": "westondj@ornl.gov",
#         "orcid": "orcid:0000-0002-4794-9913"
#       }
#     },
#     {
#       "applied_role": "Data curation",
#       "applies_to_person": {
#         "name": "Paul Abraham",
#         "email": "abrahampe@ornl.gov",
#         "orcid": "orcid:0000-0003-2685-9123"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Xiaohan Yang",
#         "email": "yangx@ornl.gov",
#         "orcid": "orcid:0000-0001-5207-4210"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Jin-Gui Chen",
#         "email": "chenj@ornl.gov",
#         "orcid": "orcid:0000-0002-1752-4201"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Melissa Cregger",
#         "email": "creggerma@ornl.gov",
#         "orcid": "orcid:0000-0001-8329-366X"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Omar Demerdash",
#         "email": "demerdashon@ornl.gov",
#         "orcid": "orcid:0000-0001-6846-1506"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Joseph C. Ellis",
#         "email": "ellisjc@ornl.gov",
#         "orcid": "orcid:0000-0002-2510-977X"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Daniel Jacobson",
#         "email": "jacobsonda@ornl.gov",
#         "orcid": "orcid:0000-0002-9822-8251"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Udaya Kalluri",
#         "email": "Kalluriudayc@ornl.gov",
#         "orcid": "orcid:0000-0002-5963-8370"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Stanton Martin",
#         "email": "martins@ornl.gov",
#         "orcid": "orcid:0000-0001-9246-8193"
#       }
#     }
#   ],
#   "funding_sources": [
#     "U.S. Department of Energy, Office of Science, Office of Biological and Environmental Research (BER) under contract DE-AC05-00OR22725; Project Number (FWP): 3ERKP730"
#   ]
# }
# ------------------ ERRORS ------------------
#
#
# ============== gold:Gs0114663 ==============
# ------------------ BEFORE ------------------
# {
#   "id": "gold:Gs0114663",
#   "name": "Riverbed sediment microbial communities from the Columbia River, Washington, USA",
#   "description": "This research project, led by James Stegen at PNNL, aimed to understand how molecular-scale processes govern the biogeochemical function of subsurface groundwater-surface water mixing zones (i.e., the hyporheic zone). This project was conducted along the Columbia River in Eastern Washington State, which exhibits variation in microbiome composition, biogeochemical activity, and substrate biogeochemistry, making it an ideal environment for studying biogeochemical hotspots. To capture a range of biogeochemical activities, samples were collected from areas with dense vegetation and virtually no vegetation.\n\nThis project\u2019s long-term goal is to develop models that can simulate impacts of disturbance on river corridor hydro-biogeochemistry by understanding fundamental molecular processes that lead to emergent function. This project is part of PNNL\u2019s River Corridor Hydrobiogeochemistry Science Focus Area (https://www.pnnl.gov/projects/river-corridor-hydrobiogeochemistry-science-focus-area).\n",
#   "ecosystem": "Environmental",
#   "ecosystem_category": "Aquatic",
#   "ecosystem_type": "Freshwater",
#   "ecosystem_subtype": "River",
#   "specific_ecosystem": "Sediment",
#   "principal_investigator": {
#     "has_raw_value": "James Stegen",
#     "profile_image_url": "https://portal.nersc.gov/project/m3408/profile_images/stegen_james.jpg"
#   },
#   "doi": {
#     "has_raw_value": "https://doi.org/10.25585/1487765"
#   },
#   "type": "nmdc:Study",
#   "publications": [
#     "https://doi.org/10.1371/journal.pone.0228165"
#   ],
#   "has_credit_associations": [
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "James Stegen",
#         "email": "James.Stegen@pnnl.gov",
#         "orcid": "orcid:0000-0001-9135-7424"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Malak Tfaily",
#         "email": "tfaily@email.arizona.edu",
#         "orcid": "orcid:0000-0002-3036-2833"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Amy Goldman",
#         "email": "amy.goldman@pnnl.gov",
#         "orcid": "orcid:0000-0003-0490-6451"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Lisa Bramer",
#         "email": "Lisa.Bramer@pnnl.gov",
#         "orcid": "orcid:0000-0002-8384-1926"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "C. Tom Resch",
#         "email": "tom.resch@pnnl.gov",
#         "orcid": "orcid:0000-0002-9143-6277"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Emily Graham",
#         "email": "emily.graham@pnnl.gov",
#         "orcid": "orcid:0000-0002-4623-7076"
#       }
#     },
#     {
#       "applied_role": "Data curation",
#       "applies_to_person": {
#         "name": "Alex Crump",
#         "email": "acrump@uidaho.edu",
#         "orcid": "orcid:0000-0002-2443-6146"
#       }
#     },
#     {
#       "applied_role": "Data curation",
#       "applies_to_person": {
#         "name": "David Kennedy",
#         "email": "",
#         "orcid": ""
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Evan Amtzen",
#         "email": "Evan.Arntzen@pnnl.gov",
#         "orcid": "orcid:0000-0002-9209-5670"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Sarah Fansler",
#         "email": "Sarah.Fansler@pnnl.gov",
#         "orcid": "orcid:0000-0003-4190-907X"
#       }
#     },
#     {
#       "applied_role": "Data curation",
#       "applies_to_person": {
#         "name": "Samuel Purvine",
#         "email": "Samuel.Purvine@pnnl.gov",
#         "orcid": "orcid:0000-0002-2257-2400"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Carrie Nicora",
#         "email": "Carrie.Nicora@pnnl.gov",
#         "orcid": "orcid:0000-0003-2461-9548"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "William Nelson",
#         "email": "William.Nelson@pnnl.gov",
#         "orcid": "orcid:0000-0002-1873-3929"
#       }
#     }
#   ],
#   "funding_sources": [
#     "U.S. Department of Energy, Office of Science, Office of Biological and Environmental Research (BER) under contract DE-AC05-76RL01830 (PNNL))"
#   ]
# }
# ------------------ AFTER ------------------
# {
#   "id": "gold:Gs0114663",
#   "name": "NEW NAME 2",
#   "description": "This research project, led by James Stegen at PNNL, aimed to understand how molecular-scale processes govern the biogeochemical function of subsurface groundwater-surface water mixing zones (i.e., the hyporheic zone). This project was conducted along the Columbia River in Eastern Washington State, which exhibits variation in microbiome composition, biogeochemical activity, and substrate biogeochemistry, making it an ideal environment for studying biogeochemical hotspots. To capture a range of biogeochemical activities, samples were collected from areas with dense vegetation and virtually no vegetation.\n\nThis project\u2019s long-term goal is to develop models that can simulate impacts of disturbance on river corridor hydro-biogeochemistry by understanding fundamental molecular processes that lead to emergent function. This project is part of PNNL\u2019s River Corridor Hydrobiogeochemistry Science Focus Area (https://www.pnnl.gov/projects/river-corridor-hydrobiogeochemistry-science-focus-area).\n",
#   "ecosystem": "Environmental",
#   "ecosystem_category": "Aquatic",
#   "ecosystem_type": "Freshwater",
#   "ecosystem_subtype": "River",
#   "specific_ecosystem": "Sediment",
#   "principal_investigator": {
#     "has_raw_value": "NEW RAW VALUE 2"
#   },
#   "doi": {
#     "has_raw_value": "10.9999/8888"
#   },
#   "type": "nmdc:Study",
#   "publications": [
#     "https://doi.org/10.1371/journal.pone.0228165"
#   ],
#   "has_credit_associations": [
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "James Stegen",
#         "email": "James.Stegen@pnnl.gov",
#         "orcid": "orcid:0000-0001-9135-7424"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Malak Tfaily",
#         "email": "tfaily@email.arizona.edu",
#         "orcid": "orcid:0000-0002-3036-2833"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Amy Goldman",
#         "email": "amy.goldman@pnnl.gov",
#         "orcid": "orcid:0000-0003-0490-6451"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Lisa Bramer",
#         "email": "Lisa.Bramer@pnnl.gov",
#         "orcid": "orcid:0000-0002-8384-1926"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "C. Tom Resch",
#         "email": "tom.resch@pnnl.gov",
#         "orcid": "orcid:0000-0002-9143-6277"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Emily Graham",
#         "email": "emily.graham@pnnl.gov",
#         "orcid": "orcid:0000-0002-4623-7076"
#       }
#     },
#     {
#       "applied_role": "Data curation",
#       "applies_to_person": {
#         "name": "Alex Crump",
#         "email": "acrump@uidaho.edu",
#         "orcid": "orcid:0000-0002-2443-6146"
#       }
#     },
#     {
#       "applied_role": "Data curation",
#       "applies_to_person": {
#         "name": "David Kennedy",
#         "email": "",
#         "orcid": ""
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Evan Amtzen",
#         "email": "Evan.Arntzen@pnnl.gov",
#         "orcid": "orcid:0000-0002-9209-5670"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Sarah Fansler",
#         "email": "Sarah.Fansler@pnnl.gov",
#         "orcid": "orcid:0000-0003-4190-907X"
#       }
#     },
#     {
#       "applied_role": "Data curation",
#       "applies_to_person": {
#         "name": "Samuel Purvine",
#         "email": "Samuel.Purvine@pnnl.gov",
#         "orcid": "orcid:0000-0002-2257-2400"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Carrie Nicora",
#         "email": "Carrie.Nicora@pnnl.gov",
#         "orcid": "orcid:0000-0003-2461-9548"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "William Nelson",
#         "email": "William.Nelson@pnnl.gov",
#         "orcid": "orcid:0000-0002-1873-3929"
#       }
#     }
#   ],
#   "funding_sources": [
#     "U.S. Department of Energy, Office of Science, Office of Biological and Environmental Research (BER) under contract DE-AC05-76RL01830 (PNNL))"
#   ]
# }
# ------------------ ERRORS ------------------

# %% [markdown]
# ### process change sheet 3
# Test with two studies. Both studies are updated using grouping variables/symbols.
# Note the reuse of variables/symbols in each id group. A variable/symbol is local the id group it appears in.

# %%
pd.read_csv("data/changesheet-without-separator3.tsv", sep="\t", dtype="string").fillna('')
# Out:
#                 id  action                attribute                       value
# 0   gold:Gs0114663  update                     name            NEW STUDY NAME 1
# 1                   update                ecosystem             NEW ECOSYSTEM 1
# 2                   update           ecosystem_type        NEW ECOSYSTEM_TYPE 1
# 3                   update        ecosystem_subtype     NEW ECOSYSTEM_SUBTYPE 1
# 4                   update                      doi                          v1
# 5               v1  update            has_raw_value                   NEW DOI 1
# 6                   update   principal_investigator                          v2
# 7               v2                             name               NEW PI NAME 1
# 8               v2                    has_raw_value              NEW RAW NAME 1
# 9                   update              description           NEW DESCRIPTION 1
# 10                  update                 websites    HTTP://TEST1.EXAMPLE.COM
# 11                  update                 websites    HTTP://TEST2.EXAMPLE.COM
# 12                  update  has_credit_associations                          v3
# 13              v3                     applied_role               Investigation
# 14              v3           applies_to_person.name  NEW CO-INVESTIGATOR NAME 1
# 15                  update  has_credit_associations                          v4
# 16              v4                     applied_role               Investigation
# 17              v4           applies_to_person.name          NEW CURATOR NAME 1
# 18  gold:Gs0103573  update                     name            NEW STUDY NAME 2
# 19                  update                ecosystem             NEW ECOSYSTEM 2
# 20                  update           ecosystem_type        NEW ECOSYSTEM_TYPE 2
# 21                  update        ecosystem_subtype     NEW ECOSYSTEM_SUBTYPE 2
# 22                  update                      doi                          v1
# 23              v1  update            has_raw_value                   NEW DOI 2
# 24                  update   principal_investigator                          v2
# 25              v2                             name               NEW PI NAME 2
# 26              v2                    has_raw_value              NEW RAW NAME 2
# 27                  update              description           NEW DESCRIPTION 2
# 28                  update                 websites    HTTP://TEST3.EXAMPLE.COM
# 29                  update                 websites    HTTP://TEST4.EXAMPLE.COM
# 30                  update  has_credit_associations                          v3
# 31              v3                     applied_role               Investigation
# 32              v3           applies_to_person.name  NEW CO-INVESTIGATOR NAME 2
# 33                  update  has_credit_associations                          v4
# 34              v4                     applied_role               Investigation
# 35              v4           applies_to_person.name          NEW CURATOR NAME 2

# %%
sheetDf = load_changesheet("data/changesheet-without-separator3.tsv", mongodb)
sheetDf
# Out:
#                 id  action                attribute                       value        group_id group_var                                            path collection_name linkml_class                                    linkml_slots                                  ranges       multivalues
# 0   gold:Gs0114663  update                     name            NEW STUDY NAME 1  gold:Gs0114663                                                      name       study_set        study                                            name                                  string             False
# 1                   update                ecosystem             NEW ECOSYSTEM 1  gold:Gs0114663                                                 ecosystem       study_set        study                                       ecosystem                                  string             False
# 2                   update           ecosystem_type        NEW ECOSYSTEM_TYPE 1  gold:Gs0114663                                            ecosystem_type       study_set        study                                  ecosystem_type                                  string             False
# 3                   update        ecosystem_subtype     NEW ECOSYSTEM_SUBTYPE 1  gold:Gs0114663                                         ecosystem_subtype       study_set        study                               ecosystem_subtype                                  string             False
# 4                   update                      doi                          v1  gold:Gs0114663        v1                                                       study_set        study                                             doi                         attribute value             False
# 5               v1  update            has_raw_value                   NEW DOI 1  gold:Gs0114663        v1                               doi.has_raw_value       study_set        study                               doi|has raw value                  attribute value|string       False|False
# 6                   update   principal_investigator                          v2  gold:Gs0114663        v2                                                       study_set        study                          principal investigator                            person value             False
# 7               v2  update                     name               NEW PI NAME 1  gold:Gs0114663        v2                     principal_investigator.name       study_set        study                     principal investigator|name                     person value|string       False|False
# 8               v2  update            has_raw_value              NEW RAW NAME 1  gold:Gs0114663        v2            principal_investigator.has_raw_value       study_set        study            principal investigator|has raw value                     person value|string       False|False
# 9                   update              description           NEW DESCRIPTION 1  gold:Gs0114663                                               description       study_set        study                                     description                                  string             False
# 10                  update                 websites    HTTP://TEST1.EXAMPLE.COM  gold:Gs0114663                                                  websites       study_set        study                                        websites                                  string              True
# 11                  update                 websites    HTTP://TEST2.EXAMPLE.COM  gold:Gs0114663                                                  websites       study_set        study                                        websites                                  string              True
# 12                  update  has_credit_associations                          v3  gold:Gs0114663        v3                                                       study_set        study                         has credit associations                      credit association              True
# 13              v3  update             applied_role               Investigation  gold:Gs0114663        v3            has_credit_associations.applied_role       study_set        study            has credit associations|applied role          credit association|credit enum        True|False
# 14              v3  update   applies_to_person.name  NEW CO-INVESTIGATOR NAME 1  gold:Gs0114663        v3  has_credit_associations.applies_to_person.name       study_set        study  has credit associations|applies to person|name  credit association|person value|string  True|False|False
# 15                  update  has_credit_associations                          v4  gold:Gs0114663        v4                                                       study_set        study                         has credit associations                      credit association              True
# 16              v4  update             applied_role               Investigation  gold:Gs0114663        v4            has_credit_associations.applied_role       study_set        study            has credit associations|applied role          credit association|credit enum        True|False
# 17              v4  update   applies_to_person.name          NEW CURATOR NAME 1  gold:Gs0114663        v4  has_credit_associations.applies_to_person.name       study_set        study  has credit associations|applies to person|name  credit association|person value|string  True|False|False
# 18  gold:Gs0103573  update                     name            NEW STUDY NAME 2  gold:Gs0103573                                                      name       study_set        study                                            name                                  string             False
# 19                  update                ecosystem             NEW ECOSYSTEM 2  gold:Gs0103573                                                 ecosystem       study_set        study                                       ecosystem                                  string             False
# 20                  update           ecosystem_type        NEW ECOSYSTEM_TYPE 2  gold:Gs0103573                                            ecosystem_type       study_set        study                                  ecosystem_type                                  string             False
# 21                  update        ecosystem_subtype     NEW ECOSYSTEM_SUBTYPE 2  gold:Gs0103573                                         ecosystem_subtype       study_set        study                               ecosystem_subtype                                  string             False
# 22                  update                      doi                          v1  gold:Gs0103573        v1                                                       study_set        study                                             doi                         attribute value             False
# 23              v1  update            has_raw_value                   NEW DOI 2  gold:Gs0103573        v1                               doi.has_raw_value       study_set        study                               doi|has raw value                  attribute value|string       False|False
# 24                  update   principal_investigator                          v2  gold:Gs0103573        v2                                                       study_set        study                          principal investigator                            person value             False
# 25              v2  update                     name               NEW PI NAME 2  gold:Gs0103573        v2                     principal_investigator.name       study_set        study                     principal investigator|name                     person value|string       False|False
# 26              v2  update            has_raw_value              NEW RAW NAME 2  gold:Gs0103573        v2            principal_investigator.has_raw_value       study_set        study            principal investigator|has raw value                     person value|string       False|False
# 27                  update              description           NEW DESCRIPTION 2  gold:Gs0103573                                               description       study_set        study                                     description                                  string             False
# 28                  update                 websites    HTTP://TEST3.EXAMPLE.COM  gold:Gs0103573                                                  websites       study_set        study                                        websites                                  string              True
# 29                  update                 websites    HTTP://TEST4.EXAMPLE.COM  gold:Gs0103573                                                  websites       study_set        study                                        websites                                  string              True
# 30                  update  has_credit_associations                          v3  gold:Gs0103573        v3                                                       study_set        study                         has credit associations                      credit association              True
# 31              v3  update             applied_role               Investigation  gold:Gs0103573        v3            has_credit_associations.applied_role       study_set        study            has credit associations|applied role          credit association|credit enum        True|False
# 32              v3  update   applies_to_person.name  NEW CO-INVESTIGATOR NAME 2  gold:Gs0103573        v3  has_credit_associations.applies_to_person.name       study_set        study  has credit associations|applies to person|name  credit association|person value|string  True|False|False
# 33                  update  has_credit_associations                          v4  gold:Gs0103573        v4                                                       study_set        study                         has credit associations                      credit association              True
# 34              v4  update             applied_role               Investigation  gold:Gs0103573        v4            has_credit_associations.applied_role       study_set        study            has credit associations|applied role          credit association|credit enum        True|False
# 35              v4  update   applies_to_person.name          NEW CURATOR NAME 2  gold:Gs0103573        v4  has_credit_associations.applies_to_person.name       study_set        study  has credit associations|applies to person|name  credit association|person value|string  True|False|False

# %%
print_results(process_changesheet(sheetDf, mongodb, temp_db), print_before=True)
# Out:
# ============== gold:Gs0103573 ==============
# ------------------ BEFORE ------------------
# {
#   "id": "gold:Gs0103573",
#   "name": "Populus root and rhizosphere microbial communities from Tennessee, USA",
#   "description": "This study is part of the Plant-Microbe Interfaces Science Focus Area, which aims to gain a deeper understanding of the diversity and functioning of mutually beneficial interactions between plants and microbes in the rhizosphere. Ongoing efforts focus on characterizing and interpreting such interfaces using systems comprising plants and microbes, in particular the poplar tree (Populus) and its microbial community in the context of favorable plant microbe interactions.",
#   "ecosystem": "Host-associated",
#   "ecosystem_category": "Plants",
#   "ecosystem_type": "Unclassified",
#   "ecosystem_subtype": "Unclassified",
#   "specific_ecosystem": "Unclassified",
#   "principal_investigator": {
#     "has_raw_value": "Mitchel J. Doktycz",
#     "name": "Mitchel J. Doktycz",
#     "profile_image_url": "https://portal.nersc.gov/project/m3408/profile_images/doktycz_mitchel.jpg",
#     "orcid": "orcid:0000-0003-4856-8343"
#   },
#   "type": "nmdc:Study",
#   "websites": [
#     "https://pmiweb.ornl.gov/pmi-project-aims/"
#   ],
#   "title": "Defining the functional diversity of the Populus root microbiome",
#   "doi": {
#     "has_raw_value": "https://doi.org/10.25585/1488096"
#   },
#   "publications": [
#     "https://doi.org/10.1128/mSystems.00045-18"
#   ],
#   "has_credit_associations": [
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Mitchel J. Doktycz",
#         "email": "doktyczmj@ornl.gov",
#         "orcid": "orcid:0000-0003-4856-8343"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Josh Michener",
#         "email": "michenerjk@ornl.gov",
#         "orcid": "orcid:0000-0003-2302-8180"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Jennifer Morrell-Falvey",
#         "email": "morrelljl1@ornl.gov",
#         "orcid": "orcid:0000-0002-9362-7528"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Wellington Muchero",
#         "email": "mucherow@ornl.gov",
#         "orcid": "orcid:0000-0002-0200-9856"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Dale Pelletier",
#         "email": "pelletierda@ornl.gov",
#         "orcid": "orcid:0000-0002-4321-7918"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Mircea Podar",
#         "email": "podarm@ornl.gov",
#         "orcid": "orcid:0000-0003-2776-0205"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Scott Retterer",
#         "email": "rettererst@ornl.gov",
#         "orcid": "orcid:0000-0001-8534-1979"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Robert Hettich",
#         "email": "hettichrl@ornl.gov",
#         "orcid": "orcid:0000-0001-7708-786X"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Christopher Schadt",
#         "email": "schadtcw@ornl.gov",
#         "orcid": "orcid:0000-0001-8759-2448"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Timothy Tschaplinski",
#         "email": "tschaplinstj@ornl.gov",
#         "orcid": "orcid:0000-0002-9540-6622"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "David Weston",
#         "email": "westondj@ornl.gov",
#         "orcid": "orcid:0000-0002-4794-9913"
#       }
#     },
#     {
#       "applied_role": "Data curation",
#       "applies_to_person": {
#         "name": "Paul Abraham",
#         "email": "abrahampe@ornl.gov",
#         "orcid": "orcid:0000-0003-2685-9123"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Xiaohan Yang",
#         "email": "yangx@ornl.gov",
#         "orcid": "orcid:0000-0001-5207-4210"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Jin-Gui Chen",
#         "email": "chenj@ornl.gov",
#         "orcid": "orcid:0000-0002-1752-4201"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Melissa Cregger",
#         "email": "creggerma@ornl.gov",
#         "orcid": "orcid:0000-0001-8329-366X"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Omar Demerdash",
#         "email": "demerdashon@ornl.gov",
#         "orcid": "orcid:0000-0001-6846-1506"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Joseph C. Ellis",
#         "email": "ellisjc@ornl.gov",
#         "orcid": "orcid:0000-0002-2510-977X"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Daniel Jacobson",
#         "email": "jacobsonda@ornl.gov",
#         "orcid": "orcid:0000-0002-9822-8251"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Udaya Kalluri",
#         "email": "Kalluriudayc@ornl.gov",
#         "orcid": "orcid:0000-0002-5963-8370"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Stanton Martin",
#         "email": "martins@ornl.gov",
#         "orcid": "orcid:0000-0001-9246-8193"
#       }
#     }
#   ],
#   "funding_sources": [
#     "U.S. Department of Energy, Office of Science, Office of Biological and Environmental Research (BER) under contract DE-AC05-00OR22725; Project Number (FWP): 3ERKP730"
#   ]
# }
# ------------------ AFTER ------------------
# {
#   "id": "gold:Gs0103573",
#   "name": "NEW STUDY NAME 2",
#   "description": "NEW DESCRIPTION 2",
#   "ecosystem": "NEW ECOSYSTEM 2",
#   "ecosystem_category": "Plants",
#   "ecosystem_type": "NEW ECOSYSTEM_TYPE 2",
#   "ecosystem_subtype": "NEW ECOSYSTEM_SUBTYPE 2",
#   "specific_ecosystem": "Unclassified",
#   "principal_investigator": {
#     "name": "NEW PI NAME 2",
#     "has_raw_value": "NEW RAW NAME 2"
#   },
#   "type": "nmdc:Study",
#   "websites": [
#     "HTTP://TEST4.EXAMPLE.COM"
#   ],
#   "title": "Defining the functional diversity of the Populus root microbiome",
#   "doi": {
#     "has_raw_value": "NEW DOI 2"
#   },
#   "publications": [
#     "https://doi.org/10.1128/mSystems.00045-18"
#   ],
#   "has_credit_associations": [
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "NEW CURATOR NAME 2"
#       }
#     }
#   ],
#   "funding_sources": [
#     "U.S. Department of Energy, Office of Science, Office of Biological and Environmental Research (BER) under contract DE-AC05-00OR22725; Project Number (FWP): 3ERKP730"
#   ]
# }
# ------------------ ERRORS ------------------
#
#
# ============== gold:Gs0114663 ==============
# ------------------ BEFORE ------------------
# {
#   "id": "gold:Gs0114663",
#   "name": "Riverbed sediment microbial communities from the Columbia River, Washington, USA",
#   "description": "This research project, led by James Stegen at PNNL, aimed to understand how molecular-scale processes govern the biogeochemical function of subsurface groundwater-surface water mixing zones (i.e., the hyporheic zone). This project was conducted along the Columbia River in Eastern Washington State, which exhibits variation in microbiome composition, biogeochemical activity, and substrate biogeochemistry, making it an ideal environment for studying biogeochemical hotspots. To capture a range of biogeochemical activities, samples were collected from areas with dense vegetation and virtually no vegetation.\n\nThis project\u2019s long-term goal is to develop models that can simulate impacts of disturbance on river corridor hydro-biogeochemistry by understanding fundamental molecular processes that lead to emergent function. This project is part of PNNL\u2019s River Corridor Hydrobiogeochemistry Science Focus Area (https://www.pnnl.gov/projects/river-corridor-hydrobiogeochemistry-science-focus-area).\n",
#   "ecosystem": "Environmental",
#   "ecosystem_category": "Aquatic",
#   "ecosystem_type": "Freshwater",
#   "ecosystem_subtype": "River",
#   "specific_ecosystem": "Sediment",
#   "principal_investigator": {
#     "has_raw_value": "James Stegen",
#     "profile_image_url": "https://portal.nersc.gov/project/m3408/profile_images/stegen_james.jpg"
#   },
#   "doi": {
#     "has_raw_value": "https://doi.org/10.25585/1487765"
#   },
#   "type": "nmdc:Study",
#   "publications": [
#     "https://doi.org/10.1371/journal.pone.0228165"
#   ],
#   "has_credit_associations": [
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "James Stegen",
#         "email": "James.Stegen@pnnl.gov",
#         "orcid": "orcid:0000-0001-9135-7424"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Malak Tfaily",
#         "email": "tfaily@email.arizona.edu",
#         "orcid": "orcid:0000-0002-3036-2833"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Amy Goldman",
#         "email": "amy.goldman@pnnl.gov",
#         "orcid": "orcid:0000-0003-0490-6451"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Lisa Bramer",
#         "email": "Lisa.Bramer@pnnl.gov",
#         "orcid": "orcid:0000-0002-8384-1926"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "C. Tom Resch",
#         "email": "tom.resch@pnnl.gov",
#         "orcid": "orcid:0000-0002-9143-6277"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Emily Graham",
#         "email": "emily.graham@pnnl.gov",
#         "orcid": "orcid:0000-0002-4623-7076"
#       }
#     },
#     {
#       "applied_role": "Data curation",
#       "applies_to_person": {
#         "name": "Alex Crump",
#         "email": "acrump@uidaho.edu",
#         "orcid": "orcid:0000-0002-2443-6146"
#       }
#     },
#     {
#       "applied_role": "Data curation",
#       "applies_to_person": {
#         "name": "David Kennedy",
#         "email": "",
#         "orcid": ""
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Evan Amtzen",
#         "email": "Evan.Arntzen@pnnl.gov",
#         "orcid": "orcid:0000-0002-9209-5670"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Sarah Fansler",
#         "email": "Sarah.Fansler@pnnl.gov",
#         "orcid": "orcid:0000-0003-4190-907X"
#       }
#     },
#     {
#       "applied_role": "Data curation",
#       "applies_to_person": {
#         "name": "Samuel Purvine",
#         "email": "Samuel.Purvine@pnnl.gov",
#         "orcid": "orcid:0000-0002-2257-2400"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Carrie Nicora",
#         "email": "Carrie.Nicora@pnnl.gov",
#         "orcid": "orcid:0000-0003-2461-9548"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "William Nelson",
#         "email": "William.Nelson@pnnl.gov",
#         "orcid": "orcid:0000-0002-1873-3929"
#       }
#     }
#   ],
#   "funding_sources": [
#     "U.S. Department of Energy, Office of Science, Office of Biological and Environmental Research (BER) under contract DE-AC05-76RL01830 (PNNL))"
#   ]
# }
# ------------------ AFTER ------------------
# {
#   "id": "gold:Gs0114663",
#   "name": "NEW STUDY NAME 1",
#   "description": "NEW DESCRIPTION 1",
#   "ecosystem": "NEW ECOSYSTEM 1",
#   "ecosystem_category": "Aquatic",
#   "ecosystem_type": "NEW ECOSYSTEM_TYPE 1",
#   "ecosystem_subtype": "NEW ECOSYSTEM_SUBTYPE 1",
#   "specific_ecosystem": "Sediment",
#   "principal_investigator": {
#     "name": "NEW PI NAME 1",
#     "has_raw_value": "NEW RAW NAME 1"
#   },
#   "doi": {
#     "has_raw_value": "NEW DOI 1"
#   },
#   "type": "nmdc:Study",
#   "publications": [
#     "https://doi.org/10.1371/journal.pone.0228165"
#   ],
#   "has_credit_associations": [
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "NEW CURATOR NAME 1"
#       }
#     }
#   ],
#   "funding_sources": [
#     "U.S. Department of Energy, Office of Science, Office of Biological and Environmental Research (BER) under contract DE-AC05-76RL01830 (PNNL))"
#   ],
#   "websites": [
#     "HTTP://TEST2.EXAMPLE.COM"
#   ]
# }
# ------------------ ERRORS ------------------

# %% [markdown]
# ### set multiple values for credit associations

# %%
pd.read_csv("data/changesheet-array-item-nested-attributes.tsv", sep="\t", dtype="string").fillna('')
# Out:
#                id  action                attribute                      value
# 0  gold:Gs0114675  update  has_credit_associations                        ca1
# 1             ca1  update             applied_role          Conceptualization
# 2             ca1  update   applies_to_person.name              CREDIT NAME 1
# 3             ca1  update  applies_to_person.email      CREDIT_NAME_1@foo.edu
# 4             ca1  update  applies_to_person.orcid  orcid:0000-0000-0000-0001

# %%
sheetDf = load_changesheet("data/changesheet-array-item-nested-attributes.tsv", mongodb)
sheetDf
# Out:
#                id  action                attribute                      value        group_id group_var                                             path collection_name linkml_class                                     linkml_slots                                  ranges       multivalues
# 0  gold:Gs0114675  update  has_credit_associations                        ca1  gold:Gs0114675       ca1                                                        study_set        study                          has credit associations                      credit association              True
# 1             ca1  update             applied_role          Conceptualization  gold:Gs0114675       ca1             has_credit_associations.applied_role       study_set        study             has credit associations|applied role          credit association|credit enum        True|False
# 2             ca1  update   applies_to_person.name              CREDIT NAME 1  gold:Gs0114675       ca1   has_credit_associations.applies_to_person.name       study_set        study   has credit associations|applies to person|name  credit association|person value|string  True|False|False
# 3             ca1  update  applies_to_person.email      CREDIT_NAME_1@foo.edu  gold:Gs0114675       ca1  has_credit_associations.applies_to_person.email       study_set        study  has credit associations|applies to person|email  credit association|person value|string  True|False|False
# 4             ca1  update  applies_to_person.orcid  orcid:0000-0000-0000-0001  gold:Gs0114675       ca1  has_credit_associations.applies_to_person.orcid       study_set        study  has credit associations|applies to person|orcid  credit association|person value|string  True|False|False

# %%
print_results(process_changesheet(sheetDf, mongodb, temp_db), print_before=False)
# Out:
# ============== gold:Gs0114675 ==============
# ------------------ AFTER ------------------
# {
#   "id": "gold:Gs0114675",
#   "name": "Deep subsurface shale carbon reservoir microbial communities from Ohio and West Virginia, USA",
#   "description": "This project aims to improve the understanding of microbial diversity and metabolism in deep shale, with implications for novel enzyme discovery and energy development. This project was conducted along two Appalachian basin shales, the Marcellus and Utica/Point Pleasant formations in Pennsylvania and Ohio, respectively. Samples were collected from input and produced fluids up to a year after hydraulic fracturing at varying depths and locations (4 wells, 2 basin shales).\n",
#   "ecosystem": "Environmental",
#   "ecosystem_category": "Terrestrial",
#   "ecosystem_type": "Deep subsurface",
#   "ecosystem_subtype": "Unclassified",
#   "specific_ecosystem": "Unclassified",
#   "principal_investigator": {
#     "has_raw_value": "Kelly Wrighton",
#     "profile_image_url": "https://portal.nersc.gov/project/m3408/profile_images/wrighton_kelly.jpg"
#   },
#   "doi": {
#     "has_raw_value": "https://doi.org/10.25585/1487763"
#   },
#   "type": "nmdc:Study",
#   "has_credit_associations": [
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "CREDIT NAME 1",
#         "email": "CREDIT_NAME_1@foo.edu",
#         "orcid": "orcid:0000-0000-0000-0001"
#       }
#     }
#   ],
#   "funding_sources": [
#     "National Sciences Foundation Dimensions of Biodiversity (award no. 1342701)"
#   ],
#   "relevant_protocols": [
#     "https://github.com/TheWrightonLab/"
#   ]
# }
# ------------------ ERRORS ------------------

# %% [markdown]
# ### set website for principal investigator

# %%
pd.read_csv("data/changesheet-update-pi-websites.tsv", sep="\t", dtype="string").fillna('')
# Out:
#                id  action                                 attribute                                           value
# 0  gold:Gs0103573  update      principal_investigator.has_raw_value                                     NEW PI NAME
# 1                  update               principal_investigator.name                                     NEW PI NAME
# 2                  update  principal_investigator.profile_image_url        https://portal.nersc.gov/NEW-PI-NAME.jpg
# 3                  update              principal_investigator.orcid                       orcid:0000-0000-0000-0000
# 4                  update           principal_investigator.websites  https://www.ornl.gov/staff-profile/NEW-PI-NAME

# %%
sheetDf = load_changesheet("data/changesheet-update-pi-websites.tsv", mongodb)
sheetDf
# Out:
#                id  action                                 attribute                                           value        group_id group_var                                      path collection_name linkml_class                              linkml_slots               ranges  multivalues
# 0  gold:Gs0103573  update      principal_investigator.has_raw_value                                     NEW PI NAME  gold:Gs0103573                principal_investigator.has_raw_value       study_set        study      principal investigator|has raw value  person value|string  False|False
# 1                  update               principal_investigator.name                                     NEW PI NAME  gold:Gs0103573                         principal_investigator.name       study_set        study               principal investigator|name  person value|string  False|False
# 2                  update  principal_investigator.profile_image_url        https://portal.nersc.gov/NEW-PI-NAME.jpg  gold:Gs0103573            principal_investigator.profile_image_url       study_set        study  principal investigator|profile image url  person value|string  False|False
# 3                  update              principal_investigator.orcid                       orcid:0000-0000-0000-0000  gold:Gs0103573                        principal_investigator.orcid       study_set        study              principal investigator|orcid  person value|string  False|False
# 4                  update           principal_investigator.websites  https://www.ornl.gov/staff-profile/NEW-PI-NAME  gold:Gs0103573                     principal_investigator.websites       study_set        study           principal investigator|websites  person value|string   False|True

# %%
print_results(process_changesheet(sheetDf, mongodb, temp_db), print_before=False)
# Out:
# ============== gold:Gs0103573 ==============
# ------------------ AFTER ------------------
# {
#   "id": "gold:Gs0103573",
#   "name": "Populus root and rhizosphere microbial communities from Tennessee, USA",
#   "description": "This study is part of the Plant-Microbe Interfaces Science Focus Area, which aims to gain a deeper understanding of the diversity and functioning of mutually beneficial interactions between plants and microbes in the rhizosphere. Ongoing efforts focus on characterizing and interpreting such interfaces using systems comprising plants and microbes, in particular the poplar tree (Populus) and its microbial community in the context of favorable plant microbe interactions.",
#   "ecosystem": "Host-associated",
#   "ecosystem_category": "Plants",
#   "ecosystem_type": "Unclassified",
#   "ecosystem_subtype": "Unclassified",
#   "specific_ecosystem": "Unclassified",
#   "principal_investigator": {
#     "has_raw_value": "NEW PI NAME",
#     "name": "NEW PI NAME",
#     "profile_image_url": "https://portal.nersc.gov/NEW-PI-NAME.jpg",
#     "orcid": "orcid:0000-0000-0000-0000",
#     "websites": [
#       "https://www.ornl.gov/staff-profile/NEW-PI-NAME"
#     ]
#   },
#   "type": "nmdc:Study",
#   "websites": [
#     "https://pmiweb.ornl.gov/pmi-project-aims/"
#   ],
#   "title": "Defining the functional diversity of the Populus root microbiome",
#   "doi": {
#     "has_raw_value": "https://doi.org/10.25585/1488096"
#   },
#   "publications": [
#     "https://doi.org/10.1128/mSystems.00045-18"
#   ],
#   "has_credit_associations": [
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Mitchel J. Doktycz",
#         "email": "doktyczmj@ornl.gov",
#         "orcid": "orcid:0000-0003-4856-8343"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Josh Michener",
#         "email": "michenerjk@ornl.gov",
#         "orcid": "orcid:0000-0003-2302-8180"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Jennifer Morrell-Falvey",
#         "email": "morrelljl1@ornl.gov",
#         "orcid": "orcid:0000-0002-9362-7528"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Wellington Muchero",
#         "email": "mucherow@ornl.gov",
#         "orcid": "orcid:0000-0002-0200-9856"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Dale Pelletier",
#         "email": "pelletierda@ornl.gov",
#         "orcid": "orcid:0000-0002-4321-7918"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Mircea Podar",
#         "email": "podarm@ornl.gov",
#         "orcid": "orcid:0000-0003-2776-0205"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Scott Retterer",
#         "email": "rettererst@ornl.gov",
#         "orcid": "orcid:0000-0001-8534-1979"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Robert Hettich",
#         "email": "hettichrl@ornl.gov",
#         "orcid": "orcid:0000-0001-7708-786X"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Christopher Schadt",
#         "email": "schadtcw@ornl.gov",
#         "orcid": "orcid:0000-0001-8759-2448"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Timothy Tschaplinski",
#         "email": "tschaplinstj@ornl.gov",
#         "orcid": "orcid:0000-0002-9540-6622"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "David Weston",
#         "email": "westondj@ornl.gov",
#         "orcid": "orcid:0000-0002-4794-9913"
#       }
#     },
#     {
#       "applied_role": "Data curation",
#       "applies_to_person": {
#         "name": "Paul Abraham",
#         "email": "abrahampe@ornl.gov",
#         "orcid": "orcid:0000-0003-2685-9123"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Xiaohan Yang",
#         "email": "yangx@ornl.gov",
#         "orcid": "orcid:0000-0001-5207-4210"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Jin-Gui Chen",
#         "email": "chenj@ornl.gov",
#         "orcid": "orcid:0000-0002-1752-4201"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Melissa Cregger",
#         "email": "creggerma@ornl.gov",
#         "orcid": "orcid:0000-0001-8329-366X"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Omar Demerdash",
#         "email": "demerdashon@ornl.gov",
#         "orcid": "orcid:0000-0001-6846-1506"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Joseph C. Ellis",
#         "email": "ellisjc@ornl.gov",
#         "orcid": "orcid:0000-0002-2510-977X"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Daniel Jacobson",
#         "email": "jacobsonda@ornl.gov",
#         "orcid": "orcid:0000-0002-9822-8251"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Udaya Kalluri",
#         "email": "Kalluriudayc@ornl.gov",
#         "orcid": "orcid:0000-0002-5963-8370"
#       }
#     },
#     {
#       "applied_role": "Conceptualization",
#       "applies_to_person": {
#         "name": "Stanton Martin",
#         "email": "martins@ornl.gov",
#         "orcid": "orcid:0000-0001-9246-8193"
#       }
#     }
#   ],
#   "funding_sources": [
#     "U.S. Department of Energy, Office of Science, Office of Biological and Environmental Research (BER) under contract DE-AC05-00OR22725; Project Number (FWP): 3ERKP730"
#   ]
# }
# ------------------ ERRORS ------------------

# %% [markdown]
# ### remove items from list/array (e.g. a funding source) from document

# %%
pd.read_csv("data/changesheet-remove-item.tsv", sep="\t", dtype="string").fillna('')
# Out:
#                id        action        attribute                                              value
# 0  gold:Gs0135149  remove items  funding_sources  A portion of this research was performed under...

# %%
sheetDf = load_changesheet("data/changesheet-remove-item.tsv", mongodb)
sheetDf
# Out:
#                id        action        attribute                                              value        group_id group_var             path collection_name linkml_class     linkml_slots  ranges multivalues
# 0  gold:Gs0135149  remove items  funding_sources  A portion of this research was performed under...  gold:Gs0135149            funding_sources       study_set        study  funding sources  string        True

# %%
print_results(process_changesheet(sheetDf, mongodb, temp_db), print_before=True)
# Out:
# ============== gold:Gs0135149 ==============
# ------------------ BEFORE ------------------
# {
#   "id": "gold:Gs0135149",
#   "name": "Bulk soil microbial communities from the East River watershed near Crested Butte, Colorado, United States",
#   "description": "This research project aimed to understand how snow accumulation and snowmelt influences the mobilization of nitrogen through the soil microbiome in a mountainous catchment at the East River Watershed in Colorado. This project sought to identify bacteria, archaea, and fungi that were associated with the microbial biomass bloom that occurs during winter and the biomass crash following snowmelt. This project also sought to understand whether the traits that govern microbial community assembly during and after snowmelt were phylogenetically conserved. Samples were collected during winter, the snowmelt period, and after snowmelt in spring, from an area that transitioned from an upland hillslope to a riparian floodplain.\n\nThis project is part of the Watershed Function Science Focus Area: https://watershed.lbl.gov/.\n",
#   "ecosystem": "Environmental",
#   "ecosystem_category": "Terrestrial",
#   "ecosystem_type": "Soil",
#   "ecosystem_subtype": "Meadow",
#   "specific_ecosystem": "Bulk soil",
#   "principal_investigator": {
#     "has_raw_value": "Eoin Brodie",
#     "profile_image_url": "https://portal.nersc.gov/project/m3408/profile_images/brodie_eoin.jpg"
#   },
#   "doi": {
#     "has_raw_value": "https://doi.org/10.25585/1488224"
#   },
#   "type": "nmdc:Study",
#   "publications": [
#     "https://doi.org/10.21952/WTR/1573029"
#   ],
#   "has_credit_associations": [
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Harry Beller",
#         "email": "hrbeller@lbl.gov",
#         "orcid": "orcid:0000-0001-9637-3650"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Shi Wang ",
#         "email": "ShiWang@lbl.gov",
#         "orcid": "orcid:0000-0002-2408-2544"
#       }
#     },
#     {
#       "applied_role": "Supervision",
#       "applies_to_person": {
#         "name": "Eoin Brodie",
#         "email": "elbrodie@lbl.gov",
#         "orcid": "orcid:0000-0002-8453-8435"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Rosalie Chu",
#         "email": "Rosalie.Chu@pnnl.gov",
#         "orcid": "orcid:0000-0001-7428-7647"
#       }
#     },
#     {
#       "applied_role": "Project administration",
#       "applies_to_person": {
#         "name": "Emiley Eloe-Fadrosh",
#         "email": "eaeloefadrosh@lbl.gov ",
#         "orcid": "orcid:0000-0002-8162-1276"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "David Hoyt ",
#         "email": "david.hoyt@pnnl.gov",
#         "orcid": "orcid:0000-0002-2857-719X"
#       }
#     },
#     {
#       "applied_role": "Formal Analysis",
#       "applies_to_person": {
#         "name": "Ulas Karaoz",
#         "email": "ukaraoz@lbl.gov",
#         "orcid": "orcid:0000-0002-8238-6757"
#       }
#     },
#     {
#       "applied_role": "Writing original draft",
#       "applies_to_person": {
#         "name": "Patrick Sorensen",
#         "email": "posorensen@lbl.gov",
#         "orcid": "orcid:0000-0002-0558-2789"
#       }
#     },
#     {
#       "applied_role": "Project administration",
#       "applies_to_person": {
#         "name": "Tijana Glavina del Rio",
#         "email": "tglavina@lbl.gov",
#         "orcid": "orcid:0000-0003-1411-9814"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Malak Tfaily ",
#         "email": "tfaily@arizona.edu ",
#         "orcid": "orcid:0000-0002-3036-2833"
#       }
#     }
#   ],
#   "funding_sources": [
#     "This material is based upon work supported as part of the Watershed Function Scientific Focus Area funded by the U.S. Department of Energy, Office of Science, Office of Biological and Environmental Research under Award Number DE-AC02-05CH11231",
#     "A portion of this research was performed under the Facilities Integrating Collaborations for User Science (FICUS) program and used resources at the DOE Joint Genome Institute and the Environmental Molecular Sciences Laboratory (grid.436923.9), which are DOE Office of Science User Facilities. Both facilities are sponsored by the Biological and Environmental Research program and operated under Contract Nos. DE-AC02-05CH11231 (JGI) and DE-AC05-76RL01830 (EMSL)."
#   ],
#   "ess_dive_datasets": [
#     "doi:10.21952/WTR/1573029"
#   ]
# }
# ------------------ AFTER ------------------
# {
#   "id": "gold:Gs0135149",
#   "name": "Bulk soil microbial communities from the East River watershed near Crested Butte, Colorado, United States",
#   "description": "This research project aimed to understand how snow accumulation and snowmelt influences the mobilization of nitrogen through the soil microbiome in a mountainous catchment at the East River Watershed in Colorado. This project sought to identify bacteria, archaea, and fungi that were associated with the microbial biomass bloom that occurs during winter and the biomass crash following snowmelt. This project also sought to understand whether the traits that govern microbial community assembly during and after snowmelt were phylogenetically conserved. Samples were collected during winter, the snowmelt period, and after snowmelt in spring, from an area that transitioned from an upland hillslope to a riparian floodplain.\n\nThis project is part of the Watershed Function Science Focus Area: https://watershed.lbl.gov/.\n",
#   "ecosystem": "Environmental",
#   "ecosystem_category": "Terrestrial",
#   "ecosystem_type": "Soil",
#   "ecosystem_subtype": "Meadow",
#   "specific_ecosystem": "Bulk soil",
#   "principal_investigator": {
#     "has_raw_value": "Eoin Brodie",
#     "profile_image_url": "https://portal.nersc.gov/project/m3408/profile_images/brodie_eoin.jpg"
#   },
#   "doi": {
#     "has_raw_value": "https://doi.org/10.25585/1488224"
#   },
#   "type": "nmdc:Study",
#   "publications": [
#     "https://doi.org/10.21952/WTR/1573029"
#   ],
#   "has_credit_associations": [
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Harry Beller",
#         "email": "hrbeller@lbl.gov",
#         "orcid": "orcid:0000-0001-9637-3650"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Shi Wang ",
#         "email": "ShiWang@lbl.gov",
#         "orcid": "orcid:0000-0002-2408-2544"
#       }
#     },
#     {
#       "applied_role": "Supervision",
#       "applies_to_person": {
#         "name": "Eoin Brodie",
#         "email": "elbrodie@lbl.gov",
#         "orcid": "orcid:0000-0002-8453-8435"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Rosalie Chu",
#         "email": "Rosalie.Chu@pnnl.gov",
#         "orcid": "orcid:0000-0001-7428-7647"
#       }
#     },
#     {
#       "applied_role": "Project administration",
#       "applies_to_person": {
#         "name": "Emiley Eloe-Fadrosh",
#         "email": "eaeloefadrosh@lbl.gov ",
#         "orcid": "orcid:0000-0002-8162-1276"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "David Hoyt ",
#         "email": "david.hoyt@pnnl.gov",
#         "orcid": "orcid:0000-0002-2857-719X"
#       }
#     },
#     {
#       "applied_role": "Formal Analysis",
#       "applies_to_person": {
#         "name": "Ulas Karaoz",
#         "email": "ukaraoz@lbl.gov",
#         "orcid": "orcid:0000-0002-8238-6757"
#       }
#     },
#     {
#       "applied_role": "Writing original draft",
#       "applies_to_person": {
#         "name": "Patrick Sorensen",
#         "email": "posorensen@lbl.gov",
#         "orcid": "orcid:0000-0002-0558-2789"
#       }
#     },
#     {
#       "applied_role": "Project administration",
#       "applies_to_person": {
#         "name": "Tijana Glavina del Rio",
#         "email": "tglavina@lbl.gov",
#         "orcid": "orcid:0000-0003-1411-9814"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Malak Tfaily ",
#         "email": "tfaily@arizona.edu ",
#         "orcid": "orcid:0000-0002-3036-2833"
#       }
#     }
#   ],
#   "funding_sources": [
#     "This material is based upon work supported as part of the Watershed Function Scientific Focus Area funded by the U.S. Department of Energy, Office of Science, Office of Biological and Environmental Research under Award Number DE-AC02-05CH11231"
#   ],
#   "ess_dive_datasets": [
#     "doi:10.21952/WTR/1573029"
#   ]
# }
# ------------------ ERRORS ------------------

# %% [markdown]
# ### remove (i.e., unset, remove property) from document

# %%
pd.read_csv("data/changesheet-remove-property.tsv", sep="\t", dtype="string").fillna('')
# Out:
#                id  action          attribute                     value
# 0  gold:Gs0135149  remove  ess_dive_datasets  doi:10.21952/WTR/1573029

# %%
sheetDf = load_changesheet("data/changesheet-remove-property.tsv", mongodb)
sheetDf
# Out:
#                id  action          attribute                     value        group_id group_var               path collection_name linkml_class       linkml_slots  ranges multivalues
# 0  gold:Gs0135149  remove  ess_dive_datasets  doi:10.21952/WTR/1573029  gold:Gs0135149            ess_dive_datasets       study_set        study  ess dive datasets  string        True

# %%
print_results(process_changesheet(sheetDf, mongodb, temp_db), print_before=True)
# Out:
# ============== gold:Gs0135149 ==============
# ------------------ BEFORE ------------------
# {
#   "id": "gold:Gs0135149",
#   "name": "Bulk soil microbial communities from the East River watershed near Crested Butte, Colorado, United States",
#   "description": "This research project aimed to understand how snow accumulation and snowmelt influences the mobilization of nitrogen through the soil microbiome in a mountainous catchment at the East River Watershed in Colorado. This project sought to identify bacteria, archaea, and fungi that were associated with the microbial biomass bloom that occurs during winter and the biomass crash following snowmelt. This project also sought to understand whether the traits that govern microbial community assembly during and after snowmelt were phylogenetically conserved. Samples were collected during winter, the snowmelt period, and after snowmelt in spring, from an area that transitioned from an upland hillslope to a riparian floodplain.\n\nThis project is part of the Watershed Function Science Focus Area: https://watershed.lbl.gov/.\n",
#   "ecosystem": "Environmental",
#   "ecosystem_category": "Terrestrial",
#   "ecosystem_type": "Soil",
#   "ecosystem_subtype": "Meadow",
#   "specific_ecosystem": "Bulk soil",
#   "principal_investigator": {
#     "has_raw_value": "Eoin Brodie",
#     "profile_image_url": "https://portal.nersc.gov/project/m3408/profile_images/brodie_eoin.jpg"
#   },
#   "doi": {
#     "has_raw_value": "https://doi.org/10.25585/1488224"
#   },
#   "type": "nmdc:Study",
#   "publications": [
#     "https://doi.org/10.21952/WTR/1573029"
#   ],
#   "has_credit_associations": [
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Harry Beller",
#         "email": "hrbeller@lbl.gov",
#         "orcid": "orcid:0000-0001-9637-3650"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Shi Wang ",
#         "email": "ShiWang@lbl.gov",
#         "orcid": "orcid:0000-0002-2408-2544"
#       }
#     },
#     {
#       "applied_role": "Supervision",
#       "applies_to_person": {
#         "name": "Eoin Brodie",
#         "email": "elbrodie@lbl.gov",
#         "orcid": "orcid:0000-0002-8453-8435"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Rosalie Chu",
#         "email": "Rosalie.Chu@pnnl.gov",
#         "orcid": "orcid:0000-0001-7428-7647"
#       }
#     },
#     {
#       "applied_role": "Project administration",
#       "applies_to_person": {
#         "name": "Emiley Eloe-Fadrosh",
#         "email": "eaeloefadrosh@lbl.gov ",
#         "orcid": "orcid:0000-0002-8162-1276"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "David Hoyt ",
#         "email": "david.hoyt@pnnl.gov",
#         "orcid": "orcid:0000-0002-2857-719X"
#       }
#     },
#     {
#       "applied_role": "Formal Analysis",
#       "applies_to_person": {
#         "name": "Ulas Karaoz",
#         "email": "ukaraoz@lbl.gov",
#         "orcid": "orcid:0000-0002-8238-6757"
#       }
#     },
#     {
#       "applied_role": "Writing original draft",
#       "applies_to_person": {
#         "name": "Patrick Sorensen",
#         "email": "posorensen@lbl.gov",
#         "orcid": "orcid:0000-0002-0558-2789"
#       }
#     },
#     {
#       "applied_role": "Project administration",
#       "applies_to_person": {
#         "name": "Tijana Glavina del Rio",
#         "email": "tglavina@lbl.gov",
#         "orcid": "orcid:0000-0003-1411-9814"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Malak Tfaily ",
#         "email": "tfaily@arizona.edu ",
#         "orcid": "orcid:0000-0002-3036-2833"
#       }
#     }
#   ],
#   "funding_sources": [
#     "This material is based upon work supported as part of the Watershed Function Scientific Focus Area funded by the U.S. Department of Energy, Office of Science, Office of Biological and Environmental Research under Award Number DE-AC02-05CH11231",
#     "A portion of this research was performed under the Facilities Integrating Collaborations for User Science (FICUS) program and used resources at the DOE Joint Genome Institute and the Environmental Molecular Sciences Laboratory (grid.436923.9), which are DOE Office of Science User Facilities. Both facilities are sponsored by the Biological and Environmental Research program and operated under Contract Nos. DE-AC02-05CH11231 (JGI) and DE-AC05-76RL01830 (EMSL)."
#   ],
#   "ess_dive_datasets": [
#     "doi:10.21952/WTR/1573029"
#   ]
# }
# ------------------ AFTER ------------------
# {
#   "id": "gold:Gs0135149",
#   "name": "Bulk soil microbial communities from the East River watershed near Crested Butte, Colorado, United States",
#   "description": "This research project aimed to understand how snow accumulation and snowmelt influences the mobilization of nitrogen through the soil microbiome in a mountainous catchment at the East River Watershed in Colorado. This project sought to identify bacteria, archaea, and fungi that were associated with the microbial biomass bloom that occurs during winter and the biomass crash following snowmelt. This project also sought to understand whether the traits that govern microbial community assembly during and after snowmelt were phylogenetically conserved. Samples were collected during winter, the snowmelt period, and after snowmelt in spring, from an area that transitioned from an upland hillslope to a riparian floodplain.\n\nThis project is part of the Watershed Function Science Focus Area: https://watershed.lbl.gov/.\n",
#   "ecosystem": "Environmental",
#   "ecosystem_category": "Terrestrial",
#   "ecosystem_type": "Soil",
#   "ecosystem_subtype": "Meadow",
#   "specific_ecosystem": "Bulk soil",
#   "principal_investigator": {
#     "has_raw_value": "Eoin Brodie",
#     "profile_image_url": "https://portal.nersc.gov/project/m3408/profile_images/brodie_eoin.jpg"
#   },
#   "doi": {
#     "has_raw_value": "https://doi.org/10.25585/1488224"
#   },
#   "type": "nmdc:Study",
#   "publications": [
#     "https://doi.org/10.21952/WTR/1573029"
#   ],
#   "has_credit_associations": [
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Harry Beller",
#         "email": "hrbeller@lbl.gov",
#         "orcid": "orcid:0000-0001-9637-3650"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Shi Wang ",
#         "email": "ShiWang@lbl.gov",
#         "orcid": "orcid:0000-0002-2408-2544"
#       }
#     },
#     {
#       "applied_role": "Supervision",
#       "applies_to_person": {
#         "name": "Eoin Brodie",
#         "email": "elbrodie@lbl.gov",
#         "orcid": "orcid:0000-0002-8453-8435"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Rosalie Chu",
#         "email": "Rosalie.Chu@pnnl.gov",
#         "orcid": "orcid:0000-0001-7428-7647"
#       }
#     },
#     {
#       "applied_role": "Project administration",
#       "applies_to_person": {
#         "name": "Emiley Eloe-Fadrosh",
#         "email": "eaeloefadrosh@lbl.gov ",
#         "orcid": "orcid:0000-0002-8162-1276"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "David Hoyt ",
#         "email": "david.hoyt@pnnl.gov",
#         "orcid": "orcid:0000-0002-2857-719X"
#       }
#     },
#     {
#       "applied_role": "Formal Analysis",
#       "applies_to_person": {
#         "name": "Ulas Karaoz",
#         "email": "ukaraoz@lbl.gov",
#         "orcid": "orcid:0000-0002-8238-6757"
#       }
#     },
#     {
#       "applied_role": "Writing original draft",
#       "applies_to_person": {
#         "name": "Patrick Sorensen",
#         "email": "posorensen@lbl.gov",
#         "orcid": "orcid:0000-0002-0558-2789"
#       }
#     },
#     {
#       "applied_role": "Project administration",
#       "applies_to_person": {
#         "name": "Tijana Glavina del Rio",
#         "email": "tglavina@lbl.gov",
#         "orcid": "orcid:0000-0003-1411-9814"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Malak Tfaily ",
#         "email": "tfaily@arizona.edu ",
#         "orcid": "orcid:0000-0002-3036-2833"
#       }
#     }
#   ],
#   "funding_sources": [
#     "This material is based upon work supported as part of the Watershed Function Scientific Focus Area funded by the U.S. Department of Energy, Office of Science, Office of Biological and Environmental Research under Award Number DE-AC02-05CH11231",
#     "A portion of this research was performed under the Facilities Integrating Collaborations for User Science (FICUS) program and used resources at the DOE Joint Genome Institute and the Environmental Molecular Sciences Laboratory (grid.436923.9), which are DOE Office of Science User Facilities. Both facilities are sponsored by the Biological and Environmental Research program and operated under Contract Nos. DE-AC02-05CH11231 (JGI) and DE-AC05-76RL01830 (EMSL)."
#   ]
# }
# ------------------ ERRORS ------------------

# %% [markdown]
# ### replace value with new value in document
# Note the use of the "|" for multiple values.
# **Update** will also perform this.

# %%
pd.read_csv("data/changesheet-replace.tsv", sep="\t", dtype="string").fillna('')
# Out:
#                id   action          attribute                        value
# 0  gold:Gs0135149  replace  ess_dive_datasets  doi:ess_dive1|doi:ess_dive2

# %%
sheetDf = load_changesheet("data/changesheet-replace.tsv", mongodb)
sheetDf
# Out:
#                id   action          attribute                        value        group_id group_var               path collection_name linkml_class       linkml_slots  ranges multivalues
# 0  gold:Gs0135149  replace  ess_dive_datasets  doi:ess_dive1|doi:ess_dive2  gold:Gs0135149            ess_dive_datasets       study_set        study  ess dive datasets  string        True

# %%
print_results(process_changesheet(sheetDf, mongodb, temp_db), print_before=True)
# Out:
# ============== gold:Gs0135149 ==============
# ------------------ BEFORE ------------------
# {
#   "id": "gold:Gs0135149",
#   "name": "Bulk soil microbial communities from the East River watershed near Crested Butte, Colorado, United States",
#   "description": "This research project aimed to understand how snow accumulation and snowmelt influences the mobilization of nitrogen through the soil microbiome in a mountainous catchment at the East River Watershed in Colorado. This project sought to identify bacteria, archaea, and fungi that were associated with the microbial biomass bloom that occurs during winter and the biomass crash following snowmelt. This project also sought to understand whether the traits that govern microbial community assembly during and after snowmelt were phylogenetically conserved. Samples were collected during winter, the snowmelt period, and after snowmelt in spring, from an area that transitioned from an upland hillslope to a riparian floodplain.\n\nThis project is part of the Watershed Function Science Focus Area: https://watershed.lbl.gov/.\n",
#   "ecosystem": "Environmental",
#   "ecosystem_category": "Terrestrial",
#   "ecosystem_type": "Soil",
#   "ecosystem_subtype": "Meadow",
#   "specific_ecosystem": "Bulk soil",
#   "principal_investigator": {
#     "has_raw_value": "Eoin Brodie",
#     "profile_image_url": "https://portal.nersc.gov/project/m3408/profile_images/brodie_eoin.jpg"
#   },
#   "doi": {
#     "has_raw_value": "https://doi.org/10.25585/1488224"
#   },
#   "type": "nmdc:Study",
#   "publications": [
#     "https://doi.org/10.21952/WTR/1573029"
#   ],
#   "has_credit_associations": [
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Harry Beller",
#         "email": "hrbeller@lbl.gov",
#         "orcid": "orcid:0000-0001-9637-3650"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Shi Wang ",
#         "email": "ShiWang@lbl.gov",
#         "orcid": "orcid:0000-0002-2408-2544"
#       }
#     },
#     {
#       "applied_role": "Supervision",
#       "applies_to_person": {
#         "name": "Eoin Brodie",
#         "email": "elbrodie@lbl.gov",
#         "orcid": "orcid:0000-0002-8453-8435"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Rosalie Chu",
#         "email": "Rosalie.Chu@pnnl.gov",
#         "orcid": "orcid:0000-0001-7428-7647"
#       }
#     },
#     {
#       "applied_role": "Project administration",
#       "applies_to_person": {
#         "name": "Emiley Eloe-Fadrosh",
#         "email": "eaeloefadrosh@lbl.gov ",
#         "orcid": "orcid:0000-0002-8162-1276"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "David Hoyt ",
#         "email": "david.hoyt@pnnl.gov",
#         "orcid": "orcid:0000-0002-2857-719X"
#       }
#     },
#     {
#       "applied_role": "Formal Analysis",
#       "applies_to_person": {
#         "name": "Ulas Karaoz",
#         "email": "ukaraoz@lbl.gov",
#         "orcid": "orcid:0000-0002-8238-6757"
#       }
#     },
#     {
#       "applied_role": "Writing original draft",
#       "applies_to_person": {
#         "name": "Patrick Sorensen",
#         "email": "posorensen@lbl.gov",
#         "orcid": "orcid:0000-0002-0558-2789"
#       }
#     },
#     {
#       "applied_role": "Project administration",
#       "applies_to_person": {
#         "name": "Tijana Glavina del Rio",
#         "email": "tglavina@lbl.gov",
#         "orcid": "orcid:0000-0003-1411-9814"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Malak Tfaily ",
#         "email": "tfaily@arizona.edu ",
#         "orcid": "orcid:0000-0002-3036-2833"
#       }
#     }
#   ],
#   "funding_sources": [
#     "This material is based upon work supported as part of the Watershed Function Scientific Focus Area funded by the U.S. Department of Energy, Office of Science, Office of Biological and Environmental Research under Award Number DE-AC02-05CH11231",
#     "A portion of this research was performed under the Facilities Integrating Collaborations for User Science (FICUS) program and used resources at the DOE Joint Genome Institute and the Environmental Molecular Sciences Laboratory (grid.436923.9), which are DOE Office of Science User Facilities. Both facilities are sponsored by the Biological and Environmental Research program and operated under Contract Nos. DE-AC02-05CH11231 (JGI) and DE-AC05-76RL01830 (EMSL)."
#   ],
#   "ess_dive_datasets": [
#     "doi:10.21952/WTR/1573029"
#   ]
# }
# ------------------ AFTER ------------------
# {
#   "id": "gold:Gs0135149",
#   "name": "Bulk soil microbial communities from the East River watershed near Crested Butte, Colorado, United States",
#   "description": "This research project aimed to understand how snow accumulation and snowmelt influences the mobilization of nitrogen through the soil microbiome in a mountainous catchment at the East River Watershed in Colorado. This project sought to identify bacteria, archaea, and fungi that were associated with the microbial biomass bloom that occurs during winter and the biomass crash following snowmelt. This project also sought to understand whether the traits that govern microbial community assembly during and after snowmelt were phylogenetically conserved. Samples were collected during winter, the snowmelt period, and after snowmelt in spring, from an area that transitioned from an upland hillslope to a riparian floodplain.\n\nThis project is part of the Watershed Function Science Focus Area: https://watershed.lbl.gov/.\n",
#   "ecosystem": "Environmental",
#   "ecosystem_category": "Terrestrial",
#   "ecosystem_type": "Soil",
#   "ecosystem_subtype": "Meadow",
#   "specific_ecosystem": "Bulk soil",
#   "principal_investigator": {
#     "has_raw_value": "Eoin Brodie",
#     "profile_image_url": "https://portal.nersc.gov/project/m3408/profile_images/brodie_eoin.jpg"
#   },
#   "doi": {
#     "has_raw_value": "https://doi.org/10.25585/1488224"
#   },
#   "type": "nmdc:Study",
#   "publications": [
#     "https://doi.org/10.21952/WTR/1573029"
#   ],
#   "has_credit_associations": [
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Harry Beller",
#         "email": "hrbeller@lbl.gov",
#         "orcid": "orcid:0000-0001-9637-3650"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Shi Wang ",
#         "email": "ShiWang@lbl.gov",
#         "orcid": "orcid:0000-0002-2408-2544"
#       }
#     },
#     {
#       "applied_role": "Supervision",
#       "applies_to_person": {
#         "name": "Eoin Brodie",
#         "email": "elbrodie@lbl.gov",
#         "orcid": "orcid:0000-0002-8453-8435"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Rosalie Chu",
#         "email": "Rosalie.Chu@pnnl.gov",
#         "orcid": "orcid:0000-0001-7428-7647"
#       }
#     },
#     {
#       "applied_role": "Project administration",
#       "applies_to_person": {
#         "name": "Emiley Eloe-Fadrosh",
#         "email": "eaeloefadrosh@lbl.gov ",
#         "orcid": "orcid:0000-0002-8162-1276"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "David Hoyt ",
#         "email": "david.hoyt@pnnl.gov",
#         "orcid": "orcid:0000-0002-2857-719X"
#       }
#     },
#     {
#       "applied_role": "Formal Analysis",
#       "applies_to_person": {
#         "name": "Ulas Karaoz",
#         "email": "ukaraoz@lbl.gov",
#         "orcid": "orcid:0000-0002-8238-6757"
#       }
#     },
#     {
#       "applied_role": "Writing original draft",
#       "applies_to_person": {
#         "name": "Patrick Sorensen",
#         "email": "posorensen@lbl.gov",
#         "orcid": "orcid:0000-0002-0558-2789"
#       }
#     },
#     {
#       "applied_role": "Project administration",
#       "applies_to_person": {
#         "name": "Tijana Glavina del Rio",
#         "email": "tglavina@lbl.gov",
#         "orcid": "orcid:0000-0003-1411-9814"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Malak Tfaily ",
#         "email": "tfaily@arizona.edu ",
#         "orcid": "orcid:0000-0002-3036-2833"
#       }
#     }
#   ],
#   "funding_sources": [
#     "This material is based upon work supported as part of the Watershed Function Scientific Focus Area funded by the U.S. Department of Energy, Office of Science, Office of Biological and Environmental Research under Award Number DE-AC02-05CH11231",
#     "A portion of this research was performed under the Facilities Integrating Collaborations for User Science (FICUS) program and used resources at the DOE Joint Genome Institute and the Environmental Molecular Sciences Laboratory (grid.436923.9), which are DOE Office of Science User Facilities. Both facilities are sponsored by the Biological and Environmental Research program and operated under Contract Nos. DE-AC02-05CH11231 (JGI) and DE-AC05-76RL01830 (EMSL)."
#   ],
#   "ess_dive_datasets": [
#     "doi:ess_dive1",
#     "doi:ess_dive2"
#   ]
# }
# ------------------ ERRORS ------------------

# %% [markdown]
# ### insert items into a list/array in the document
# Note use of "|" for multiple values. If the property does not exist, it will be created.

# %%
pd.read_csv("data/changesheet-insert.tsv", sep="\t", dtype="string").fillna('')
# Out:
#                id        action          attribute                              value
# 0  gold:Gs0135149  insert items  ess_dive_datasets      doi:ESS_DIVE_1|doi:ESS_DIVE_2
# 1  gold:Gs0135149  insert items           websites  http://WEBSITE_1|http://WEBSITE_2
# 2  gold:Gs0135149  insert items       publications                      PUBLICATION 1

# %%
sheetDf = load_changesheet("data/changesheet-insert.tsv", mongodb)
sheetDf
# Out:
#                id        action          attribute                              value        group_id group_var               path collection_name linkml_class       linkml_slots  ranges multivalues
# 0  gold:Gs0135149  insert items  ess_dive_datasets      doi:ESS_DIVE_1|doi:ESS_DIVE_2  gold:Gs0135149            ess_dive_datasets       study_set        study  ess dive datasets  string        True
# 1  gold:Gs0135149  insert items           websites  http://WEBSITE_1|http://WEBSITE_2  gold:Gs0135149                     websites       study_set        study           websites  string        True
# 2  gold:Gs0135149  insert items       publications                      PUBLICATION 1  gold:Gs0135149                 publications       study_set        study       publications  string        True

# %%
print_results(process_changesheet(sheetDf, mongodb, temp_db), print_before=True)
# Out:
# ============== gold:Gs0135149 ==============
# ------------------ BEFORE ------------------
# {
#   "id": "gold:Gs0135149",
#   "name": "Bulk soil microbial communities from the East River watershed near Crested Butte, Colorado, United States",
#   "description": "This research project aimed to understand how snow accumulation and snowmelt influences the mobilization of nitrogen through the soil microbiome in a mountainous catchment at the East River Watershed in Colorado. This project sought to identify bacteria, archaea, and fungi that were associated with the microbial biomass bloom that occurs during winter and the biomass crash following snowmelt. This project also sought to understand whether the traits that govern microbial community assembly during and after snowmelt were phylogenetically conserved. Samples were collected during winter, the snowmelt period, and after snowmelt in spring, from an area that transitioned from an upland hillslope to a riparian floodplain.\n\nThis project is part of the Watershed Function Science Focus Area: https://watershed.lbl.gov/.\n",
#   "ecosystem": "Environmental",
#   "ecosystem_category": "Terrestrial",
#   "ecosystem_type": "Soil",
#   "ecosystem_subtype": "Meadow",
#   "specific_ecosystem": "Bulk soil",
#   "principal_investigator": {
#     "has_raw_value": "Eoin Brodie",
#     "profile_image_url": "https://portal.nersc.gov/project/m3408/profile_images/brodie_eoin.jpg"
#   },
#   "doi": {
#     "has_raw_value": "https://doi.org/10.25585/1488224"
#   },
#   "type": "nmdc:Study",
#   "publications": [
#     "https://doi.org/10.21952/WTR/1573029"
#   ],
#   "has_credit_associations": [
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Harry Beller",
#         "email": "hrbeller@lbl.gov",
#         "orcid": "orcid:0000-0001-9637-3650"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Shi Wang ",
#         "email": "ShiWang@lbl.gov",
#         "orcid": "orcid:0000-0002-2408-2544"
#       }
#     },
#     {
#       "applied_role": "Supervision",
#       "applies_to_person": {
#         "name": "Eoin Brodie",
#         "email": "elbrodie@lbl.gov",
#         "orcid": "orcid:0000-0002-8453-8435"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Rosalie Chu",
#         "email": "Rosalie.Chu@pnnl.gov",
#         "orcid": "orcid:0000-0001-7428-7647"
#       }
#     },
#     {
#       "applied_role": "Project administration",
#       "applies_to_person": {
#         "name": "Emiley Eloe-Fadrosh",
#         "email": "eaeloefadrosh@lbl.gov ",
#         "orcid": "orcid:0000-0002-8162-1276"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "David Hoyt ",
#         "email": "david.hoyt@pnnl.gov",
#         "orcid": "orcid:0000-0002-2857-719X"
#       }
#     },
#     {
#       "applied_role": "Formal Analysis",
#       "applies_to_person": {
#         "name": "Ulas Karaoz",
#         "email": "ukaraoz@lbl.gov",
#         "orcid": "orcid:0000-0002-8238-6757"
#       }
#     },
#     {
#       "applied_role": "Writing original draft",
#       "applies_to_person": {
#         "name": "Patrick Sorensen",
#         "email": "posorensen@lbl.gov",
#         "orcid": "orcid:0000-0002-0558-2789"
#       }
#     },
#     {
#       "applied_role": "Project administration",
#       "applies_to_person": {
#         "name": "Tijana Glavina del Rio",
#         "email": "tglavina@lbl.gov",
#         "orcid": "orcid:0000-0003-1411-9814"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Malak Tfaily ",
#         "email": "tfaily@arizona.edu ",
#         "orcid": "orcid:0000-0002-3036-2833"
#       }
#     }
#   ],
#   "funding_sources": [
#     "This material is based upon work supported as part of the Watershed Function Scientific Focus Area funded by the U.S. Department of Energy, Office of Science, Office of Biological and Environmental Research under Award Number DE-AC02-05CH11231",
#     "A portion of this research was performed under the Facilities Integrating Collaborations for User Science (FICUS) program and used resources at the DOE Joint Genome Institute and the Environmental Molecular Sciences Laboratory (grid.436923.9), which are DOE Office of Science User Facilities. Both facilities are sponsored by the Biological and Environmental Research program and operated under Contract Nos. DE-AC02-05CH11231 (JGI) and DE-AC05-76RL01830 (EMSL)."
#   ],
#   "ess_dive_datasets": [
#     "doi:10.21952/WTR/1573029"
#   ]
# }
# ------------------ AFTER ------------------
# {
#   "id": "gold:Gs0135149",
#   "name": "Bulk soil microbial communities from the East River watershed near Crested Butte, Colorado, United States",
#   "description": "This research project aimed to understand how snow accumulation and snowmelt influences the mobilization of nitrogen through the soil microbiome in a mountainous catchment at the East River Watershed in Colorado. This project sought to identify bacteria, archaea, and fungi that were associated with the microbial biomass bloom that occurs during winter and the biomass crash following snowmelt. This project also sought to understand whether the traits that govern microbial community assembly during and after snowmelt were phylogenetically conserved. Samples were collected during winter, the snowmelt period, and after snowmelt in spring, from an area that transitioned from an upland hillslope to a riparian floodplain.\n\nThis project is part of the Watershed Function Science Focus Area: https://watershed.lbl.gov/.\n",
#   "ecosystem": "Environmental",
#   "ecosystem_category": "Terrestrial",
#   "ecosystem_type": "Soil",
#   "ecosystem_subtype": "Meadow",
#   "specific_ecosystem": "Bulk soil",
#   "principal_investigator": {
#     "has_raw_value": "Eoin Brodie",
#     "profile_image_url": "https://portal.nersc.gov/project/m3408/profile_images/brodie_eoin.jpg"
#   },
#   "doi": {
#     "has_raw_value": "https://doi.org/10.25585/1488224"
#   },
#   "type": "nmdc:Study",
#   "publications": [
#     "https://doi.org/10.21952/WTR/1573029",
#     "PUBLICATION 1"
#   ],
#   "has_credit_associations": [
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Harry Beller",
#         "email": "hrbeller@lbl.gov",
#         "orcid": "orcid:0000-0001-9637-3650"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Shi Wang ",
#         "email": "ShiWang@lbl.gov",
#         "orcid": "orcid:0000-0002-2408-2544"
#       }
#     },
#     {
#       "applied_role": "Supervision",
#       "applies_to_person": {
#         "name": "Eoin Brodie",
#         "email": "elbrodie@lbl.gov",
#         "orcid": "orcid:0000-0002-8453-8435"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Rosalie Chu",
#         "email": "Rosalie.Chu@pnnl.gov",
#         "orcid": "orcid:0000-0001-7428-7647"
#       }
#     },
#     {
#       "applied_role": "Project administration",
#       "applies_to_person": {
#         "name": "Emiley Eloe-Fadrosh",
#         "email": "eaeloefadrosh@lbl.gov ",
#         "orcid": "orcid:0000-0002-8162-1276"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "David Hoyt ",
#         "email": "david.hoyt@pnnl.gov",
#         "orcid": "orcid:0000-0002-2857-719X"
#       }
#     },
#     {
#       "applied_role": "Formal Analysis",
#       "applies_to_person": {
#         "name": "Ulas Karaoz",
#         "email": "ukaraoz@lbl.gov",
#         "orcid": "orcid:0000-0002-8238-6757"
#       }
#     },
#     {
#       "applied_role": "Writing original draft",
#       "applies_to_person": {
#         "name": "Patrick Sorensen",
#         "email": "posorensen@lbl.gov",
#         "orcid": "orcid:0000-0002-0558-2789"
#       }
#     },
#     {
#       "applied_role": "Project administration",
#       "applies_to_person": {
#         "name": "Tijana Glavina del Rio",
#         "email": "tglavina@lbl.gov",
#         "orcid": "orcid:0000-0003-1411-9814"
#       }
#     },
#     {
#       "applied_role": "Investigation",
#       "applies_to_person": {
#         "name": "Malak Tfaily ",
#         "email": "tfaily@arizona.edu ",
#         "orcid": "orcid:0000-0002-3036-2833"
#       }
#     }
#   ],
#   "funding_sources": [
#     "This material is based upon work supported as part of the Watershed Function Scientific Focus Area funded by the U.S. Department of Energy, Office of Science, Office of Biological and Environmental Research under Award Number DE-AC02-05CH11231",
#     "A portion of this research was performed under the Facilities Integrating Collaborations for User Science (FICUS) program and used resources at the DOE Joint Genome Institute and the Environmental Molecular Sciences Laboratory (grid.436923.9), which are DOE Office of Science User Facilities. Both facilities are sponsored by the Biological and Environmental Research program and operated under Contract Nos. DE-AC02-05CH11231 (JGI) and DE-AC05-76RL01830 (EMSL)."
#   ],
#   "ess_dive_datasets": [
#     "doi:10.21952/WTR/1573029",
#     "doi:ESS_DIVE_1",
#     "doi:ESS_DIVE_2"
#   ],
#   "websites": [
#     "http://WEBSITE_1",
#     "http://WEBSITE_2"
#   ]
# }
# ------------------ ERRORS ------------------
